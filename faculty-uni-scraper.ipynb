# %%
from collections import defaultdict
from bs4 import BeautifulSoup, Tag
import pandas as pd
import requests
import re
import json
import datetime

BASE_URL = 'http://www.columbia.edu'

def subjUrl(letter):
    return BASE_URL + '/cu/bulletin/uwb/sel/subj-{}.html'.format(letter)

def getSubjects(letter):
    r = requests.get(subjUrl(letter))
    r.raise_for_status()
    soup = BeautifulSoup(r.text, 'lxml')
    table = soup.table
    rows = table.find_all('tr')[3:-2]
    return rows

subjPattern = re.compile('subj\/(\w{4})')
def getSubjectFromPath(p):
    matches = subjPattern.findall(p)
    if len(matches) == 0:
        return None
    return matches[0]

def parseForSection(contents):
    components = contents[2].contents
    section = {
         'number': contents[0].a.string.replace('Section ', ''),
    }
    header = None
    for component in components:
        if header is not None:
            text = component.strip()
            try:
                text = int(text)
            except ValueError:
                pass # This is expected since not all values are integers (e.g. instructor names)
            section[header] = text
            header = None
        if isinstance(component, Tag) and component.name == 'b':
            header = component.string.replace(':', '').strip()
    return section

CODE_PATTERN = re.compile(r'[A-Z]{1,2}\d{4}')
def getCoursesFromPath(p):
    r = requests.get(BASE_URL + p)
    r.raise_for_status()
    soup = BeautifulSoup(r.text, 'lxml')
    subject = getSubjectFromPath(p)
    course = None
    courseNumber = None
    courses = []
    for tr in soup.table.find_all('tr')[2:-1]:
        if tr.td.get('colspan') is not None:
            course = tr.td.b.contents[-1]
            courseNumber = CODE_PATTERN.search(tr.td.b.contents[0])
            if courseNumber is not None:
                courseNumber = courseNumber.group()
            continue
        section = parseForSection(tr.contents)
        section['course'] = course
        section['courseNumber'] = courseNumber
        section['subject'] = subject
        section['vergilLink'] = tr.find_all('td')[1].a['href']
        courses.append(section)
    return courses

def now(hours=True):
    f_string = '%Y-%m-%d'
    if hours:
        f_string += 'T%H:%M:%S'
    return datetime.datetime.now().strftime(f_string)

def main(semester):
    paths = []
    for c in range(65, 91):
        rows = getSubjects(chr(c))
        for row in rows:
            anchors = row.findAll('a')
            for a in anchors:
                href = a['href']
                if 'subj/AU' in href: # auditing
                    break
                if '__' in href: # seemingly invalid subjects
                    continue
                if semester not in href:
                    continue
                paths.append(href)

    print(f'Following {len(paths)} paths...')

    courses = []
    for p in paths:
        courses += getCoursesFromPath(p)

    print(f'Scanned {len(courses)} courses.')
    
    return courses

    with open(f'archive-{semester}/{now()}.json', 'w') as f:
        f.write(json.dumps(courses))

# %%
courses = main('Fall2019')
# Out:
# Following 265 paths...
# Scanned 7967 courses.

# %%
cours = [c for c in courses if c.get('Instructor', None) is not None]

# %%
s = BeautifulSoup(requests.get('https://vergil.registrar.columbia.edu/#/courses/ACCTB5001_001_2019_3').content)

# %%
s.find('div', {'class': 'course-section'}) is None
# Out:
# True

# %%
facultyUnis = {}

for c in courses:
    instructor = c.get('Instructor', None)
    if instructor is None:
        continue    
    if instructor in facultyUnis:
        continue
    
    vlink = c['vergilLink']
    
    print(c)
    facultyUnis[instructor] = 'hi'
# Out:
# {'number': '001', 'Call Number': 14677, 'Points': 3, 'Enrollment': '66 students (73 max) as of September  5, 2019', 'Instructor': 'Trevor S Harris', 'course': 'Accounting I: Financial Accoun', 'courseNumber': 'B5001', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB5001_001_2019_3'}
# {'number': 'XMT', 'Call Number': 18173, 'Points': 0, 'Enrollment': '1 student (5 max) as of September  5, 2019', 'Instructor': 'Jessica Soursourian', 'course': 'Accounting I: Financial Accoun', 'courseNumber': 'B5001', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB5001_XMT_2019_3'}
# {'number': '300', 'Call Number': 14679, 'Points': '1.5', 'Enrollment': '46 students (75 max) as of September  5, 2019', 'Instructor': 'Tim Baldenius', 'course': 'Financial Planning & Analysis', 'courseNumber': 'B5007', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB5007_300_2019_3'}
# {'number': '001', 'Call Number': 14784, 'Points': 3, 'Day/Time': 'MW 9:00am-10:30am', 'Location': '303 Uris Hall', 'Enrollment': '64 students (67 max) as of September  5, 2019', 'Instructor': 'Alon Kalay', 'course': 'Accounting I: Financial Accoun', 'courseNumber': 'B6001', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB6001_001_2019_3'}
# {'number': '003', 'Call Number': 14786, 'Points': 3, 'Day/Time': 'MW 2:15pm-3:45pm', 'Location': '303 Uris Hall', 'Enrollment': '62 students (67 max) as of September  5, 2019', 'Instructor': 'Mortiz Hiemannn', 'course': 'Accounting I: Financial Accoun', 'courseNumber': 'B6001', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB6001_003_2019_3'}
# {'number': '005', 'Call Number': 14788, 'Points': 3, 'Day/Time': 'MW 2:15pm-3:45pm', 'Location': '311 W & J Warren Hall', 'Enrollment': '60 students (68 max) as of September  5, 2019', 'Instructor': 'Matthias Breuer', 'course': 'Accounting I: Financial Accoun', 'courseNumber': 'B6001', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB6001_005_2019_3'}
# {'number': '008', 'Call Number': 14791, 'Points': 3, 'Day/Time': 'MW 9:00am-10:30am', 'Location': '207 W & J Warren Hall', 'Enrollment': '62 students (70 max) as of September  5, 2019', 'Instructor': 'Urooj Khan', 'course': 'Accounting I: Financial Accoun', 'courseNumber': 'B6001', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB6001_008_2019_3'}
# {'number': '001', 'Call Number': 14706, 'Points': 3, 'Enrollment': '37 students (60 max) as of September  5, 2019', 'Instructor': 'Jonathan Glover', 'course': 'Earnings Quality & Fundamental', 'courseNumber': 'B7008', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB7008_001_2019_3'}
# {'number': '001', 'Call Number': 14707, 'Points': 3, 'Enrollment': '34 students (60 max) as of September  5, 2019', 'Instructor': 'Amir Ziv', 'course': 'Financial Statement Analysis a', 'courseNumber': 'B7009', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB7009_001_2019_3'}
# {'number': '002', 'Call Number': 14708, 'Points': 3, 'Enrollment': '35 students (67 max) as of September  5, 2019', 'Instructor': 'Radha Radhakrishna', 'course': 'Financial Statement Analysis a', 'courseNumber': 'B7009', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB7009_002_2019_3'}
# {'number': '100', 'Call Number': 14709, 'Points': 3, 'Enrollment': '23 students (72 max) as of September  5, 2019', 'Instructor': 'Robert Stoumbos', 'course': 'Financial Statement Analysis a', 'courseNumber': 'B7009', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB7009_100_2019_3'}
# {'number': '001', 'Call Number': 14423, 'Points': 3, 'Day/Time': 'W 2:15pm-5:30pm', 'Location': 'To be announced', 'Enrollment': '51 students (66 max) as of September  5, 2019', 'Instructor': 'Thomas Bourveau', 'course': 'Financial Statement Analysis a', 'courseNumber': 'B8009', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB8009_001_2019_3'}
# {'number': '001', 'Call Number': 14775, 'Points': '1.5', 'Day/Time': 'T 9:00am-12:15pm', 'Location': '333 Uris Hall', 'Enrollment': '41 students (50 max) as of September  5, 2019', 'Instructor': 'Shivaram Rajgopal', 'course': 'Sovereign Risk Assessments', 'courseNumber': 'B8024', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB8024_001_2019_3'}
# {'number': '001', 'Call Number': 14750, 'Points': 3, 'Day/Time': 'W 4:00pm-7:15pm', 'Location': '209 W & J Warren Hall', 'Enrollment': '37 students (15 max) as of September  5, 2019 / Full', 'Instructor': 'Doron Nissim', 'course': '(PhD) Valuation and Financial', 'courseNumber': 'B9010', 'subject': 'ACCT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACCTB9010_001_2019_3'}
# {'number': '001', 'Call Number': 29262, 'Points': 3, 'Day/Time': 'W 2:40pm-5:25pm', 'Location': '717 Hamilton Hall', 'Enrollment': '48 students (55 max) as of September  5, 2019', 'Notes': 'PRIORITY TO ACTU STUDENTS ONLY', 'Instructor': 'Lina Xu', 'course': 'PREDICTIVE MODELING IN FINANCE & INSURAN', 'courseNumber': 'PS5840', 'subject': 'ACTU', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ACTUK5840_001_2019_3'}
# {'number': '081', 'Call Number': 14884, 'Points': 0, 'Enrollment': '83 students as of September  5, 2019', 'Instructor': 'Roseanna Graham', 'course': 'DENTAL ANATOMY & MORPHOLOGY', 'courseNumber': 'D5301', 'subject': 'ADDN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ADDND5301_081_2019_3'}
# {'number': '082', 'Call Number': 14887, 'Points': 0, 'Enrollment': '81 students as of September  5, 2019', 'Instructor': 'Candice B Zemnick', 'course': 'PRECLINICAL PROSTHODONTIC', 'courseNumber': 'D6303', 'subject': 'ADDN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ADDND6303_082_2019_3'}
# {'number': '082', 'Call Number': 14897, 'Points': 0, 'Enrollment': '0 students as of September  5, 2019', 'Instructor': 'Mona R Boside', 'course': 'PRECLINICAL DENTISTRY ENDODONTICS', 'courseNumber': 'D6308', 'subject': 'ADDN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ADDND6308_082_2019_3'}
# {'number': '082', 'Call Number': 14895, 'Points': 0, 'Enrollment': '0 students as of September  5, 2019', 'Instructor': "Christine O'Hea", 'course': 'PRECLINICAL DENTISTRY ORTHODONTICS', 'courseNumber': 'D6309', 'subject': 'ADDN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ADDND6309_082_2019_3'}
# {'number': '082', 'Call Number': 14898, 'Points': 0, 'Enrollment': '0 students as of September  5, 2019', 'Instructor': 'Shantanu Lal', 'course': 'PRECLIN PEDS THEORY & TECHNIQUE', 'courseNumber': 'D6310', 'subject': 'ADDN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ADDND6310_082_2019_3'}
# {'number': '082', 'Call Number': 14900, 'Points': 0, 'Enrollment': '81 students as of September  5, 2019', 'Instructor': 'Dana L Wolf', 'course': 'PRECLINICAL DENTISTRY PERIODONTICS', 'courseNumber': 'D6311', 'subject': 'ADDN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ADDND6311_082_2019_3'}
# {'number': '084', 'Call Number': 14976, 'Points': 0, 'Enrollment': '91 students as of September  5, 2019', 'Instructor': 'Joseph M Mc Manus Jr', 'course': 'PRACTICE MANAGEMENT', 'courseNumber': 'D8151', 'subject': 'ADDN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ADDND8151_084_2019_3'}
# {'number': '001', 'Call Number': 13534, 'Points': 4, 'Day/Time': 'TR 10:10am-12:00pm', 'Location': '206 Broadway Residence Hall', 'Enrollment': '7 students (22 max) as of September  5, 2019', 'Instructor': 'Elleni Zeleke', 'course': 'AFRICAN CIVILIZATION', 'courseNumber': 'UN1020', 'subject': 'AFCV', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFCVC1020_001_2019_3'}
# {'number': '001', 'Call Number': 10574, 'Points': 4, 'Day/Time': 'MW 1:10pm-2:25pm', 'Location': 'B60 ALFRED LERNE', 'Enrollment': '99 students (100 max) as of September  5, 2019', 'Instructor': 'Josef Sorett', 'course': 'INTRO TO AFRICAN-AMER STUDIES', 'courseNumber': 'UN1001', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASC1001_001_2019_3'}
# {'number': '002', 'Call Number': 13408, 'Points': 0, 'Day/Time': 'R 8:10am-9:00am', 'Location': '302 Hamilton Hall', 'Enrollment': '12 students (25 max) as of September  5, 2019', 'Notes': 'Ron Brown Instructor, RJB2197@columbia.edu', 'Instructor': 'Ronald J Brown', 'course': 'INTRO-AFR-AMER STUDIES - DISC', 'courseNumber': 'UN1010', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASC1010_002_2019_3'}
# {'number': '004', 'Call Number': 17817, 'Points': 0, 'Day/Time': 'W 11:10am-12:00pm', 'Location': '507 Hamilton Hall', 'Enrollment': '19 students (25 max) as of September  5, 2019', 'Instructor': 'Lisa del Sol', 'course': 'INTRO-AFR-AMER STUDIES - DISC', 'courseNumber': 'UN1010', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASC1010_004_2019_3'}
# {'number': '001', 'Call Number': 10527, 'Points': 3, 'Day/Time': 'R 2:10pm-4:00pm', 'Location': '758 EXT Schermerhorn Hall [SCH]', 'Enrollment': '14 students (15 max) as of September  5, 2019', 'Instructor': 'Kevin C Holt', 'course': 'AFRICAN-AMERICAN MUSIC', 'courseNumber': 'UN3030', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASW3030_001_2019_3'}
# {'number': '001', 'Call Number': 10662, 'Points': 4, 'Day/Time': 'T 4:10pm-6:00pm', 'Location': '758 EXT Schermerhorn Hall [SCH]', 'Enrollment': '13 students (13 max) as of September  5, 2019 / Full', 'Instructor': 'C. Daniel Dawson', 'course': 'TOPICS IN THE BLACK EXPERIENCE', 'courseNumber': 'UN3930', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASC3930_001_2019_3'}
# {'number': '002', 'Call Number': 10663, 'Points': 4, 'Day/Time': 'R 2:10pm-4:00pm', 'Location': '522D Kent Hall', 'Enrollment': '5 students (12 max) as of September  5, 2019', 'Instructor': 'Robert Gooding-Williams', 'course': 'TOPICS IN THE BLACK EXPERIENCE', 'courseNumber': 'UN3930', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASC3930_002_2019_3'}
# {'number': '001', 'Call Number': 17880, 'Points': 4, 'Day/Time': 'T 10:10am-12:00pm', 'Location': '758 EXT Schermerhorn Hall [SCH]', 'Enrollment': '3 students (15 max) as of September  5, 2019', 'Notes': 'AFAM Majors/Concentrators ONLY', 'Instructor': 'Vivaldi Jean-Marie', 'course': 'Senior Pro Seminar', 'courseNumber': 'UN3943', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASW3943_001_2019_3'}
# {'number': '001', 'Call Number': 10517, 'Points': '1-4', 'Enrollment': '0 students (10 max) as of September  5, 2019 / Full', 'Instructor': 'Kevin Fellezs', 'course': 'INDEPENDENT STUDY-NON AFAM', 'courseNumber': 'UN3997', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASC3997_001_2019_3'}
# {'number': '001', 'Call Number': 10575, 'Points': 4, 'Day/Time': 'W 12:10pm-2:00pm', 'Location': '758 EXT Schermerhorn Hall [SCH]', 'Enrollment': '5 students (14 max) as of September  5, 2019', 'Instructor': 'Obery Hendricks', 'course': 'TOPICS IN THE BLACK EXPERIENCE', 'courseNumber': 'GU4080', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASG4080_001_2019_3'}
# {'number': '003', 'Call Number': 14058, 'Points': 4, 'Day/Time': 'M 12:10pm-2:00pm', 'Location': '758 EXT Schermerhorn Hall [SCH]', 'Enrollment': '8 students (12 max) as of September  5, 2019', 'Instructor': 'Kalia Brooks', 'course': 'TOPICS IN THE BLACK EXPERIENCE', 'courseNumber': 'GU4080', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASG4080_003_2019_3'}
# {'number': '001', 'Call Number': 10513, 'Points': 4, 'Day/Time': 'W 2:10pm-4:00pm', 'Location': '758 EXT Schermerhorn Hall [SCH]', 'Enrollment': '6 students (12 max) as of September  5, 2019', 'Notes': 'Dept MA Required Course', 'Instructor': 'Farah Griffin', 'course': 'AF-AM: PRO SEMINAR', 'courseNumber': 'GR6100', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASG6100_001_2019_3'}
# {'number': '001', 'Call Number': 10514, 'Points': 4, 'Enrollment': '0 students (10 max) as of September  5, 2019 / Full', 'Instructor': 'Mabel O Wilson', 'course': 'THESIS RESEARCH-GRADUATE', 'courseNumber': 'GR6999', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASG6999_001_2019_3'}
# {'number': '002', 'Call Number': 10520, 'Points': 3, 'Enrollment': '0 students (10 max) as of September  5, 2019 / Full', 'Instructor': 'Steven Gregory', 'course': 'INDEPENDENT STUDY-GRADUATE', 'courseNumber': 'GR9900', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASG9900_002_2019_3'}
# {'number': '004', 'Call Number': 10522, 'Points': 3, 'Enrollment': '0 students (10 max) as of September  5, 2019 / Full', 'Instructor': 'Frank Guridy', 'course': 'INDEPENDENT STUDY-GRADUATE', 'courseNumber': 'GR9900', 'subject': 'AFAS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFASG9900_004_2019_3'}
# {'number': '001', 'Call Number': 6762, 'Points': 3, 'Day/Time': 'MW 11:40am-12:55pm', 'Location': '324 Milbank Hall (Barnard)', 'Enrollment': '38 students as of September  5, 2019', 'Instructor': 'Abosede A George', 'course': 'INTRODUCTN TO AFRICAN STUDIES', 'courseNumber': 'BC2004', 'subject': 'AFRS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFRSX2004_001_2019_3'}
# {'number': '001', 'Call Number': 6754, 'Points': 4, 'Day/Time': 'T 12:10pm-2:00pm', 'Location': '502 Diana Center', 'Enrollment': '8 students (18 max) as of September  5, 2019', 'Instructor': 'Kim F Hall', 'course': 'THE AFRICANA COLLOQUIUM', 'courseNumber': 'BC3110', 'subject': 'AFRS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFRSX3110_001_2019_3'}
# {'number': '001', 'Call Number': 6761, 'Points': 4, 'Day/Time': 'W 2:00pm-4:00pm', 'Location': '404 Barnard Hall', 'Enrollment': '10 students (15 max) as of September  5, 2019', 'Instructor': 'Kaiama L Glover', 'course': '"BLACKNESS" IN FRENCH', 'courseNumber': 'BC3567', 'subject': 'AFRS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFRSX3567_001_2019_3'}
# {'number': '001', 'Call Number': 6756, 'Points': 4, 'Day/Time': 'R 4:10pm-6:00pm', 'Location': '405 Barnard Hall', 'Enrollment': '10 students (15 max) as of September  5, 2019', 'Instructor': 'Rose Razaghian', 'course': 'POOR IN AMERICA: THE EXPERIENCE AND IMPA', 'courseNumber': 'BC3585', 'subject': 'AFRS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFRSX3585_001_2019_3'}
# {'number': '001', 'Call Number': 6757, 'Points': 4, 'Day/Time': 'T 10:10am-12:00pm', 'Location': '303 Altschul Hall (Barnard)', 'Enrollment': '6 students (15 max) as of September  5, 2019', 'Instructor': 'Colin Leach', 'course': 'SENIOR SEMINAR', 'courseNumber': 'BC3998', 'subject': 'AFRS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFRSX3998_001_2019_3'}
# {'number': '001', 'Call Number': 6763, 'Points': 4, 'Day/Time': 'T 2:10pm-4:00pm', 'Location': '113 MILSTEIN CEN', 'Enrollment': '31 students as of September  5, 2019', 'Instructor': 'Yvette Christianse', 'course': "BEFORE 'BLACK LIVES MATTER':READING INSU", 'courseNumber': 'BC3253', 'subject': 'AFEN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AFENX3253_001_2019_3'}
# {'number': '001', 'Call Number': 121, 'Points': 4, 'Day/Time': 'T 12:10pm-2:00pm', 'Location': '214 Milbank Hall (Barnard)', 'Enrollment': '19 students (22 max) as of September  5, 2019', 'Instructor': 'John Andrews', 'course': 'CRITICAL APPROACHES TO STUDY OF ETHNICIT', 'courseNumber': 'BC1041', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTX1041_001_2019_3'}
# {'number': '001', 'Call Number': 6830, 'Points': 4, 'Day/Time': 'R 4:10pm-6:00pm', 'Location': '214 Milbank Hall (Barnard)', 'Enrollment': '19 students (20 max) as of September  5, 2019', 'Notes': 'Perm given at 1st class;priority to BC AmerST majors', 'Instructor': 'Jennie Kassanoff', 'course': 'JUNIOR COLLOQUIUM IN AMERICAN STUDIES', 'courseNumber': 'BC3401', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTX3401_001_2019_3'}
# {'number': '002', 'Call Number': 6831, 'Points': 4, 'Day/Time': 'W 2:10pm-4:00pm', 'Location': '111 MILSTEIN CEN', 'Enrollment': '7 students (20 max) as of September  5, 2019', 'Notes': 'Perm given at 1st class;priority to BC AmerST majors', 'Instructor': 'Bernabe S Mendoza', 'course': 'JUNIOR COLLOQUIUM IN AMERICAN STUDIES', 'courseNumber': 'BC3401', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTX3401_002_2019_3'}
# {'number': '003', 'Call Number': 6834, 'Points': 4, 'Day/Time': 'T 4:10pm-6:00pm', 'Location': '214 Milbank Hall (Barnard)', 'Enrollment': '11 students (15 max) as of September  5, 2019', 'Instructor': 'Manu M Vimalassery', 'course': 'SENIOR FIELD ESSAY SEMINAR', 'courseNumber': 'BC3703', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTX3703_003_2019_3'}
# {'number': '001', 'Call Number': 10312, 'Points': 1, 'Enrollment': '8 students (10 max) as of September  5, 2019', 'Notes': 'REQUIRED FOR STUDENTS DOING SENIOR RES PROJECTS', 'Instructor': 'Casey Blake', 'course': 'SENIOR PROJECT COLLOQUIUM', 'courseNumber': 'UN3920', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTW3920_001_2019_3'}
# {'number': '001', 'Call Number': 62741, 'Points': 4, 'Day/Time': 'T 2:10pm-4:00pm', 'Location': '317 Hamilton Hall', 'Enrollment': '0 students (18 max) as of September  5, 2019 / Full', 'Notes': 'No preregistration. Join waitlist and attend 1st class', 'Instructor': 'Roosevelt Montas', 'course': 'TOPICS IN AMERICAN STUDIES', 'courseNumber': 'UN3930', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTW3930_001_2019_3'}
# {'number': '002', 'Call Number': 62736, 'Points': 4, 'Day/Time': 'R 2:10pm-4:00pm', 'Location': '317 Hamilton Hall', 'Enrollment': '18 students (18 max) as of September  5, 2019 / Full', 'Notes': 'No preregistration. Join waitlist and attend 1st class.', 'Instructor': 'Hilary-Anne Hallett', 'course': 'TOPICS IN AMERICAN STUDIES', 'courseNumber': 'UN3930', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTW3930_002_2019_3'}
# {'number': '003', 'Call Number': 62739, 'Points': 4, 'Day/Time': 'M 10:10am-12:00pm', 'Location': '317 Hamilton Hall', 'Enrollment': '0 students (18 max) as of September  5, 2019 / Full', 'Notes': 'No preregistration. Join waitlist and attend 1st class.', 'Instructor': 'Jessica H Lee', 'course': 'TOPICS IN AMERICAN STUDIES', 'courseNumber': 'UN3930', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTW3930_003_2019_3'}
# {'number': '004', 'Call Number': 62737, 'Points': 4, 'Day/Time': 'M 6:10pm-8:00pm', 'Location': '317 Hamilton Hall', 'Enrollment': '0 students (18 max) as of September  5, 2019 / Full', 'Notes': 'No preregistration. Join waitlist, attend 1st class', 'Instructor': 'Benjamin Rosenberg', 'course': 'TOPICS IN AMERICAN STUDIES', 'courseNumber': 'UN3930', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTW3930_004_2019_3'}
# {'number': '005', 'Call Number': 62738, 'Points': 4, 'Day/Time': 'W 4:10pm-6:00pm', 'Location': '317 Hamilton Hall', 'Enrollment': '17 students (18 max) as of September  5, 2019', 'Notes': 'No preregistration. Join waitlist and attend 1st class', 'Instructor': 'Valerie Paley', 'course': 'TOPICS IN AMERICAN STUDIES', 'courseNumber': 'UN3930', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTW3930_005_2019_3'}
# {'number': '007', 'Call Number': 10469, 'Points': 4, 'Day/Time': 'R 12:10pm-2:00pm', 'Location': '317 Hamilton Hall', 'Enrollment': '19 students (18 max) as of September  5, 2019 / Full', 'Notes': 'No preregistration. Join waitlist and attend 1st class', 'Instructor': 'Jeremy Dauber', 'course': 'TOPICS IN AMERICAN STUDIES', 'courseNumber': 'UN3930', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTW3930_007_2019_3'}
# {'number': '009', 'Call Number': 10582, 'Points': 4, 'Day/Time': 'W 12:10pm-2:00pm', 'Location': '317 Hamilton Hall', 'Enrollment': '9 students (18 max) as of September  5, 2019', 'Notes': 'No preregistration. Join waitlist and attend 1st class.', 'Instructor': 'Luke Mayville', 'course': 'TOPICS IN AMERICAN STUDIES', 'courseNumber': 'UN3930', 'subject': 'AMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/AMSTW3930_009_2019_3'}
# {'number': '001', 'Call Number': 7295, 'Points': 3, 'Day/Time': 'M 1:00pm-5:00pm', 'Location': '1115 Altschul Hall (Barnard)', 'Enrollment': '7 students (16 max) as of September  5, 2019', 'Notes': 'ANAT BC2573 Applied Anatomy of Human Movement is pre/co-req', 'Instructor': 'Chisa Hidaka', 'course': 'LABORATORY IN HUMAN ANATOMY', 'courseNumber': 'BC2574', 'subject': 'ANAT', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANATX2574_001_2019_3'}
# {'number': '001', 'Call Number': 48716, 'Points': 3, 'Day/Time': 'F 2:10pm-4:00pm', 'Location': '613 Hamilton Hall', 'Enrollment': '5 students (20 max) as of September  5, 2019', 'Instructor': 'Marcus Folch', 'course': 'THE MAJOR SEMINAR', 'courseNumber': 'UN3996', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3996_001_2019_3'}
# {'number': '001', 'Call Number': 48642, 'Points': 3, 'Enrollment': '0 students (5 max) as of September  5, 2019 / Full', 'Instructor': 'Elizabeth K Irwin', 'course': 'DIRCTD READING-ANCIENT STUDIES', 'courseNumber': 'UN3997', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3997_001_2019_3'}
# {'number': '002', 'Call Number': 48643, 'Points': 3, 'Enrollment': '0 students (5 max) as of September  5, 2019 / Full', 'Instructor': 'Deborah Steiner', 'course': 'DIRCTD READING-ANCIENT STUDIES', 'courseNumber': 'UN3997', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3997_002_2019_3'}
# {'number': '004', 'Call Number': 48645, 'Points': 3, 'Enrollment': '0 students (5 max) as of September  5, 2019 / Full', 'Instructor': 'Elizabeth W Scharffenberger', 'course': 'DIRCTD READING-ANCIENT STUDIES', 'courseNumber': 'UN3997', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3997_004_2019_3'}
# {'number': '005', 'Call Number': 48646, 'Points': 3, 'Enrollment': '0 students (5 max) as of September  5, 2019 / Full', 'Instructor': 'Paraskevi Martzavou', 'course': 'DIRCTD READING-ANCIENT STUDIES', 'courseNumber': 'UN3997', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3997_005_2019_3'}
# {'number': '006', 'Call Number': 48647, 'Points': 3, 'Enrollment': '0 students (5 max) as of September  5, 2019 / Full', 'Instructor': 'John T Ma', 'course': 'DIRCTD READING-ANCIENT STUDIES', 'courseNumber': 'UN3997', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3997_006_2019_3'}
# {'number': '007', 'Call Number': 48648, 'Points': 3, 'Enrollment': '0 students (5 max) as of September  5, 2019 / Full', 'Instructor': 'Kathy H Eden', 'course': 'DIRCTD READING-ANCIENT STUDIES', 'courseNumber': 'UN3997', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3997_007_2019_3'}
# {'number': '008', 'Call Number': 48649, 'Points': 3, 'Enrollment': '0 students (5 max) as of September  5, 2019 / Full', 'Instructor': 'Gareth Williams', 'course': 'DIRCTD READING-ANCIENT STUDIES', 'courseNumber': 'UN3997', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3997_008_2019_3'}
# {'number': '009', 'Call Number': 48650, 'Points': 3, 'Enrollment': '0 students (5 max) as of September  5, 2019 / Full', 'Instructor': 'Joseph A Howley', 'course': 'DIRCTD READING-ANCIENT STUDIES', 'courseNumber': 'UN3997', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3997_009_2019_3'}
# {'number': '010', 'Call Number': 48651, 'Points': 3, 'Enrollment': '0 students (5 max) as of September  5, 2019 / Full', 'Instructor': 'Darcy Krasne', 'course': 'DIRCTD READING-ANCIENT STUDIES', 'courseNumber': 'UN3997', 'subject': 'ANCS', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANCSV3997_010_2019_3'}
# {'number': '001', 'Call Number': 45160, 'Points': 3, 'Day/Time': 'TR 1:10pm-2:25pm', 'Location': '614 Schermerhorn Hall [SCH]', 'Enrollment': '114 students (120 max) as of September  5, 2019', 'Instructor': 'Audra Simpson', 'course': 'THE INTERPRETATION OF CULTURE', 'courseNumber': 'UN1002', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHV1002_001_2019_3'}
# {'number': '001', 'Call Number': 6909, 'Points': 3, 'Day/Time': 'TR 2:40pm-3:55pm', 'Location': '304 Barnard Hall', 'Enrollment': '163 students as of September  5, 2019', 'Instructor': 'Severin Fowles', 'course': 'THE ORIGINS OF HUMAN SOCIETY', 'courseNumber': 'UN1007', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHV1007_001_2019_3'}
# {'number': '002', 'Call Number': 6910, 'Points': 3, 'Day/Time': 'TR 10:00am-11:25am', 'Location': '324 Milbank Hall (Barnard)', 'Enrollment': '37 students (120 max) as of September  5, 2019', 'Instructor': 'Gretchen Pfeil', 'course': 'INTRO TO LANGUAGE & CULTURE', 'courseNumber': 'UN1009', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW1009_002_2019_3'}
# {'number': '001', 'Call Number': 45118, 'Points': 3, 'Day/Time': 'MW 1:10pm-2:25pm', 'Location': '614 Schermerhorn Hall [SCH]', 'Enrollment': '83 students (100 max) as of September  5, 2019', 'Instructor': 'John Pemberton', 'course': 'INTRO TO SOC & CULTURAL THEORY', 'courseNumber': 'UN2004', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHV2004_001_2019_3'}
# {'number': '001', 'Call Number': 45171, 'Points': 3, 'Day/Time': 'TR 4:10pm-5:25pm', 'Location': '467 EXT Schermerhorn Hall [SCH]', 'Enrollment': '24 students (30 max) as of September  5, 2019', 'Instructor': 'Maria Jos de Abreu', 'course': 'ON PRECARITY', 'courseNumber': 'UN2026', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW2026_001_2019_3'}
# {'number': '001', 'Call Number': 45265, 'Points': 3, 'Day/Time': 'TR 2:40pm-3:55pm', 'Location': '307 Pupin Laboratories', 'Enrollment': '12 students (30 max) as of September  5, 2019', 'Instructor': 'Myron L Cohen', 'course': 'RELIGION IN CHINESE SOCIETY', 'courseNumber': 'UN3035', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHV3035_001_2019_3'}
# {'number': '001', 'Call Number': 6911, 'Points': 4, 'Day/Time': 'MW 10:00am-11:25am', 'Location': '307 Milbank Hall (Barnard)', 'Enrollment': '15 students (40 max) as of September  5, 2019', 'Notes': 'Makeup session Friday, September 20, 2019 10:00am-12:00pm', 'Instructor': 'Lesley Sharp', 'course': 'ANTHROPOLOGICAL THEORY', 'courseNumber': 'UN3040', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3040_001_2019_3'}
# {'number': '001', 'Call Number': 10354, 'Points': 4, 'Day/Time': 'F 1:10pm-3:40pm', 'Location': '652 Schermerhorn Hall [SCH]', 'Enrollment': '10 students (15 max) as of September  5, 2019', 'Instructor': 'Jeffrey L Benjamin', 'course': 'Art in Archaeological Practice', 'courseNumber': 'UN3662', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3662_001_2019_3'}
# {'number': '001', 'Call Number': 14880, 'Points': 4, 'Day/Time': 'W 10:10am-12:00pm', 'Location': '303 Hamilton Hall', 'Enrollment': '12 students (20 max) as of September  5, 2019', 'Instructor': 'Camilla Sturm', 'course': 'The Ancient Table: Archaeology of Cookin', 'courseNumber': 'UN3663', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3663_001_2019_3'}
# {'number': '001', 'Call Number': 10341, 'Points': 4, 'Day/Time': 'F 2:10pm-4:00pm', 'Location': '963 EXT Schermerhorn Hall [SCH]', 'Enrollment': '14 students (15 max) as of September  5, 2019', 'Notes': "Priorities:  ANTH Majors. Others by instructor's permission", 'Instructor': 'Jonathan Robinson-Appels', 'course': 'AIDS, The Arts, Body Culture', 'courseNumber': 'UN3763', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3763_001_2019_3'}
# {'number': '001', 'Call Number': 45266, 'Points': 4, 'Day/Time': 'T 12:10pm-2:00pm', 'Location': '963 EXT Schermerhorn Hall [SCH]', 'Enrollment': '15 students (18 max) as of September  5, 2019', 'Notes': 'Permission required.  email vaj2116@columbia.edu', 'Instructor': 'Vanessa L Agard-Jones', 'course': 'TOXIC', 'courseNumber': 'UN3811', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHV3811_001_2019_3'}
# {'number': '001', 'Call Number': 45251, 'Points': 4, 'Day/Time': 'M 4:10pm-6:00pm', 'Location': '951 Schermerhorn Hall [SCH]', 'Enrollment': '14 students (15 max) as of September  5, 2019', 'Instructor': "Terence N D'Altroy", 'course': 'ARCH ENGAGE: PAST IN PUB EYE', 'courseNumber': 'UN3823', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3823_001_2019_3'}
# {'number': '001', 'Call Number': 85, 'Points': 4, 'Day/Time': 'W 4:10pm-6:00pm', 'Location': '467 EXT Schermerhorn Hall [SCH]', 'Enrollment': '19 students (20 max) as of September  5, 2019', 'Notes': 'By Permission of Instructor', 'Instructor': 'Patrick F Nason', 'course': 'ANTHROP OF THE ANTHROPOCENE', 'courseNumber': 'UN3861', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHV3861_001_2019_3'}
# {'number': '001', 'Call Number': 45267, 'Points': 4, 'Day/Time': 'W 2:10pm-4:00pm', 'Location': '467 EXT Schermerhorn Hall [SCH]', 'Enrollment': '17 students (20 max) as of September  5, 2019', 'Notes': "Instructor's permission is required", 'Instructor': 'Marilyn Ivy', 'course': 'ECOCRITICISM FOR THE END TIMES', 'courseNumber': 'UN3888', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHV3888_001_2019_3'}
# {'number': '001', 'Call Number': 6902, 'Points': 4, 'Day/Time': 'M 2:10pm-4:00pm', 'Location': '227 Milbank Hall (Barnard)', 'Enrollment': '20 students (30 max) as of September  5, 2019', 'Notes': 'By Permission of Instructor', 'Instructor': 'J.C. Salyer', 'course': 'SOCIAL CONTEXTS IMMIGRATN LAW', 'courseNumber': 'BC3911', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHX3911_001_2019_3'}
# {'number': '001', 'Call Number': 45268, 'Points': 4, 'Day/Time': 'M 4:10pm-6:00pm', 'Location': '304 Hamilton Hall', 'Enrollment': '36 students (45 max) as of September  5, 2019 / Full', 'Instructor': 'Michael Taussig', 'course': 'TABOO AND TRANSGRESSION', 'courseNumber': 'UN3952', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHV3952_001_2019_3'}
# {'number': '001', 'Call Number': 45269, 'Points': 4, 'Day/Time': 'R 2:10pm-4:00pm', 'Location': '963 EXT Schermerhorn Hall [SCH]', 'Enrollment': '15 students (15 max) as of September  5, 2019 / Full', 'Instructor': 'Rosalind Morris', 'course': 'ETHNOGRAPHY OF THE EVERYDAY', 'courseNumber': 'UN3957', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHV3957_001_2019_3'}
# {'number': '001', 'Call Number': 45215, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Brian Boyd', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_001_2019_3'}
# {'number': '004', 'Call Number': 45218, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Zoe Crossland', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_004_2019_3'}
# {'number': '006', 'Call Number': 45220, 'Points': '2-6', 'Enrollment': '1 student (10 max) as of September  5, 2019', 'Instructor': 'Paige West', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_006_2019_3'}
# {'number': '008', 'Call Number': 45222, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Catherine Fennell', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_008_2019_3'}
# {'number': '014', 'Call Number': 45224, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Ellen Marakowitz', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_014_2019_3'}
# {'number': '015', 'Call Number': 45225, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Naor H Ben-Yehoyada', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_015_2019_3'}
# {'number': '018', 'Call Number': 45228, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Elizabeth Povinelli', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_018_2019_3'}
# {'number': '019', 'Call Number': 45229, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Nan A Rothschild', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_019_2019_3'}
# {'number': '021', 'Call Number': 45230, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Partha Chatterjee', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_021_2019_3'}
# {'number': '022', 'Call Number': 45231, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Karen Seeley', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_022_2019_3'}
# {'number': '026', 'Call Number': 45234, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Lila Abu-Lughod', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_026_2019_3'}
# {'number': '029', 'Call Number': 45235, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Ralph L Holloway', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_029_2019_3'}
# {'number': '032', 'Call Number': 45237, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Brinkley Messick', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_032_2019_3'}
# {'number': '033', 'Call Number': 45238, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Mahmood Mamdani', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_033_2019_3'}
# {'number': '034', 'Call Number': 45239, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'David Scott', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_034_2019_3'}
# {'number': '035', 'Call Number': 45240, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Nadia Abu El-Haj', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_035_2019_3'}
# {'number': '036', 'Call Number': 45241, 'Points': '2-6', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Claudio Lomnitz', 'course': 'SUPERVISED INDIVIDUAL RESEARCH', 'courseNumber': 'UN3997', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHW3997_036_2019_3'}
# {'number': '001', 'Call Number': 45126, 'Points': 3, 'Day/Time': 'F 2:10pm-4:00pm', 'Location': '467 EXT Schermerhorn Hall [SCH]', 'Enrollment': '10 students (14 max) as of September  5, 2019', 'Notes': 'Permission needed for undergrads & students not in MUSA pro', 'Instructor': 'Sally Yerkovich', 'course': 'ETHICAL ISSUES IN MUSEUMS', 'courseNumber': 'GR5361', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHG5361_001_2019_3'}
# {'number': '001', 'Call Number': 45244, 'Points': 3, 'Day/Time': 'W 10:10am-12:00pm', 'Location': '467 EXT Schermerhorn Hall [SCH]', 'Enrollment': '19 students (20 max) as of September  5, 2019', 'Instructor': 'Elizabeth H Turk', 'course': 'MAKING ETHNOG:METHOD & WRITING', 'courseNumber': 'GR6070', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHG6070_001_2019_3'}
# {'number': '001', 'Call Number': 16315, 'Points': 3, 'Day/Time': 'M 12:10pm-2:00pm', 'Location': '963 EXT Schermerhorn Hall [SCH]', 'Enrollment': '0 students (12 max) as of September  5, 2019 / Full', 'Notes': 'Grad students only & instructor   s approval  is REQUIRED', 'Instructor': 'Talal Asad', 'course': 'Exploring the Idea of Secular Reason', 'courseNumber': 'GR6173', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHG6173_001_2019_3'}
# {'number': '001', 'Call Number': 45129, 'Points': 3, 'Day/Time': 'R 4:10pm-6:00pm', 'Location': '963 EXT Schermerhorn Hall [SCH]', 'Enrollment': '6 students (15 max) as of September  5, 2019', 'Instructor': 'Marco Castro', 'course': 'MUSA DIGITAL MEDIA,MATERIALITY&PRACTICE', 'courseNumber': 'GR6652', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHG6652_001_2019_3'}
# {'number': '009', 'Call Number': 45181, 'Points': '3-9', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Brian Larkin', 'course': 'RSCH IN SOCIAL/CULTURAL ANTHRO', 'courseNumber': 'GR9101', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHG9101_009_2019_3'}
# {'number': '029', 'Call Number': 45153, 'Points': '3-9', 'Enrollment': '0 students (10 max) as of September  5, 2019', 'Instructor': 'Elizabeth M Green', 'course': 'RESEARCH IN SPECIAL FIELDS', 'courseNumber': 'GR9105', 'subject': 'ANTH', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/ANTHG9105_029_2019_3'}
# {'number': '003', 'Call Number': 10096, 'Points': 3, 'Day/Time': 'M 6:10pm-8:00pm', 'Location': 'LL103 Diana Center', 'Enrollment': '50 students (50 max) as of September  5, 2019 / Full', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Wajahat Gilani', 'course': 'APPL ANALYTICS IN ORGANIZATIONAL CONTEXT', 'courseNumber': 'PS5100', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5100_003_2019_3'}
# {'number': '004', 'Call Number': 10097, 'Points': 3, 'Day/Time': 'T 8:10pm-10:00pm', 'Location': '503 Hamilton Hall', 'Enrollment': '40 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Arunava Bhattacharyya', 'course': 'APPL ANALYTICS IN ORGANIZATIONAL CONTEXT', 'courseNumber': 'PS5100', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5100_004_2019_3'}
# {'number': '005', 'Call Number': 10098, 'Points': 3, 'Day/Time': 'W 8:10pm-10:00pm', 'Location': '603 Hamilton Hall', 'Enrollment': '44 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Lori Cenci', 'course': 'APPL ANALYTICS IN ORGANIZATIONAL CONTEXT', 'courseNumber': 'PS5100', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5100_005_2019_3'}
# {'number': '006', 'Call Number': 10099, 'Points': 3, 'Day/Time': 'R 6:10pm-8:00pm', 'Location': '703 Hamilton Hall', 'Enrollment': '50 students (50 max) as of September  5, 2019 / Full', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Cory E Labanow', 'course': 'APPL ANALYTICS IN ORGANIZATIONAL CONTEXT', 'courseNumber': 'PS5100', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5100_006_2019_3'}
# {'number': '007', 'Call Number': 10100, 'Points': 3, 'Day/Time': 'R 6:10pm-8:00pm', 'Location': '411 Riverside Church', 'Enrollment': '48 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'David Kreutter', 'course': 'APPL ANALYTICS IN ORGANIZATIONAL CONTEXT', 'courseNumber': 'PS5100', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5100_007_2019_3'}
# {'number': '009', 'Call Number': 10102, 'Points': 3, 'Day/Time': 'F 2:10pm-4:00pm', 'Location': '503 Hamilton Hall', 'Enrollment': '48 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Joseph R Schlosser', 'course': 'APPL ANALYTICS IN ORGANIZATIONAL CONTEXT', 'courseNumber': 'PS5100', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5100_009_2019_3'}
# {'number': '010', 'Call Number': 10103, 'Points': 3, 'Day/Time': 'S 12:10pm-2:00pm', 'Location': '627 Seeley W. Mudd Building', 'Enrollment': '41 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Anjana Bhattacharyya', 'course': 'APPL ANALYTICS IN ORGANIZATIONAL CONTEXT', 'courseNumber': 'PS5100', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5100_010_2019_3'}
# {'number': 'D01', 'Call Number': 10078, 'Points': 3, 'Day/Time': 'M 8:10pm-10:00pm', 'Location': 'ONLINE ONLY', 'Enrollment': '42 students (50 max) as of September  5, 2019', 'Notes': 'MEETS ONLINE. APAN STUDENTS ONLY', 'Instructor': 'Hany S Saleeb', 'course': 'APPL ANALYTICS IN ORGANIZATIONAL CONTEXT', 'courseNumber': 'PS5100', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5100_D01_2019_3'}
# {'number': 'D01', 'Call Number': 10044, 'Points': 3, 'Day/Time': 'M 6:10pm-8:00pm', 'Location': 'ONLINE ONLY', 'Enrollment': '23 students (50 max) as of September  5, 2019', 'Notes': 'MEETS ONLINE, APAN STUDENTS ONLY', 'Instructor': 'Steven Hoberman', 'course': 'DATA MODELING', 'courseNumber': 'PS5160', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5160_D01_2019_3'}
# {'number': '003', 'Call Number': 29531, 'Points': 3, 'Day/Time': 'M 6:10pm-8:00pm', 'Location': '603 Hamilton Hall', 'Enrollment': '47 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Guilherme de Oliveira', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHODS I', 'courseNumber': 'PS5200', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5200_003_2019_3'}
# {'number': '004', 'Call Number': 16229, 'Points': 3, 'Day/Time': 'T 12:10pm-2:00pm', 'Location': '627 Seeley W. Mudd Building', 'Enrollment': '50 students (50 max) as of September  5, 2019 / Full', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Kitty K Chan', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHODS I', 'courseNumber': 'PS5200', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5200_004_2019_3'}
# {'number': '005', 'Call Number': 29530, 'Points': 3, 'Day/Time': 'W 6:10pm-8:00pm', 'Location': '520 Mathematics Building', 'Enrollment': '45 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Francois Scharffe', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHODS I', 'courseNumber': 'PS5200', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5200_005_2019_3'}
# {'number': '006', 'Call Number': 29529, 'Points': 3, 'Day/Time': 'R 6:10pm-8:00pm', 'Location': 'K306 JEWISH THEOL', 'Enrollment': '48 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Birol Emir', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHODS I', 'courseNumber': 'PS5200', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5200_006_2019_3'}
# {'number': '007', 'Call Number': 29528, 'Points': 3, 'Day/Time': 'F 10:10am-12:00pm', 'Location': '603 Hamilton Hall', 'Enrollment': '50 students (50 max) as of September  5, 2019 / Full', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Vishal Lala', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHODS I', 'courseNumber': 'PS5200', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5200_007_2019_3'}
# {'number': '008', 'Call Number': 29527, 'Points': 3, 'Day/Time': 'W 8:10pm-10:00pm', 'Location': '214 Pupin Laboratories', 'Enrollment': '47 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Matteo Rinaldi', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHODS I', 'courseNumber': 'PS5200', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5200_008_2019_3'}
# {'number': '009', 'Call Number': 29526, 'Points': 3, 'Day/Time': 'S 10:10am-12:00pm', 'Location': '627 Seeley W. Mudd Building', 'Enrollment': '48 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Bradley B Meyer', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHODS I', 'courseNumber': 'PS5200', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5200_009_2019_3'}
# {'number': '010', 'Call Number': 10056, 'Points': 3, 'Day/Time': 'F 12:10pm-2:00pm', 'Location': '516 Hamilton Hall', 'Enrollment': '49 students (50 max) as of September  5, 2019', 'Notes': 'APAN STUDENTS ONLY', 'Instructor': 'Joseph Egbulefu', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHODS I', 'courseNumber': 'PS5200', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5200_010_2019_3'}
# {'number': 'D01', 'Call Number': 29525, 'Points': 3, 'Day/Time': 'R 8:10pm-10:00pm', 'Location': 'ONLINE ONLY', 'Enrollment': '31 students (50 max) as of September  5, 2019', 'Notes': 'MEETS ONLINE, APAN STUDENTS ONLY', 'Instructor': 'Grant Case', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHODS I', 'courseNumber': 'PS5200', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5200_D01_2019_3'}
# {'number': '002', 'Call Number': 10059, 'Points': 3, 'Day/Time': 'M 6:10pm-8:00pm', 'Location': '507 Lewisohn Hall', 'Enrollment': '11 students (20 max) as of September  5, 2019', 'Notes': 'APAN ONLY. PREREQS: tinyurl.com/y73nqj67', 'Instructor': 'David Shilane', 'course': 'APPLIED ANALYTICS FRAMEWORKS & METHDS II', 'courseNumber': 'PS5205', 'subject': 'APAN', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/APANK5205_002_2019_3'}
# ...
# {'number': '001', 'Call Number': 44400, 'Points': 5, 'Day/Time': 'MTWR 10:10am-11:15am', 'Location': '425 Pupin Laboratories', 'Enrollment': '6 students (15 max) as of September  5, 2019', 'Instructor': 'Chung Nguyen', 'course': 'FIRST YEAR VIETNAMESE I', 'courseNumber': 'UN1101', 'subject': 'VIET', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIETW1101_001_2019_3'}
# {'number': '001', 'Call Number': 10332, 'Points': 5, 'Day/Time': 'MTR 1:10pm-2:25pm', 'Location': '624 Kent Hall', 'Enrollment': '2 students (15 max) as of September  5, 2019', 'Instructor': 'Vinh Nguyen', 'course': 'Third Year Vietnamese I', 'courseNumber': 'UN3101', 'subject': 'VIET', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIETW3101_001_2019_3'}
# {'number': '001', 'Call Number': 98842, 'Points': 3, 'Day/Time': 'MW 9:30am-12:00pm', 'Location': '501 Dodge Hall', 'Enrollment': '19 students (19 max) as of September  5, 2019 / Full', 'Instructor': 'Peter J Labier', 'course': 'BASIC DRAWING', 'courseNumber': 'UN1000', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR1000_001_2019_3'}
# {'number': '002', 'Call Number': 98841, 'Points': 3, 'Day/Time': 'MW 2:00pm-4:30pm', 'Location': '501 Dodge Hall', 'Enrollment': '18 students (19 max) as of September  5, 2019', 'Instructor': 'Carolyn H Hulbert', 'course': 'BASIC DRAWING', 'courseNumber': 'UN1000', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR1000_002_2019_3'}
# {'number': '003', 'Call Number': 98840, 'Points': 3, 'Day/Time': 'R 10:00am-4:00pm', 'Location': '501 Dodge Hall', 'Enrollment': '17 students (19 max) as of September  5, 2019', 'Instructor': 'Carrie Gundersdorf', 'course': 'BASIC DRAWING', 'courseNumber': 'UN1000', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR1000_003_2019_3'}
# {'number': '001', 'Call Number': 98839, 'Points': 3, 'Day/Time': 'MW 9:30am-12:00pm', 'Location': '109 Watson Hall', 'Enrollment': '15 students (15 max) as of September  5, 2019', 'Instructor': 'Renee Cox', 'course': 'PHOTOGRAPHY: PHOTO I', 'courseNumber': 'UN1700', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR1700_001_2019_3'}
# {'number': '002', 'Call Number': 98838, 'Points': 3, 'Day/Time': 'MW 2:00pm-4:30pm', 'Location': '109 Watson Hall', 'Enrollment': '14 students (15 max) as of September  5, 2019', 'Instructor': 'Rola Khayyat', 'course': 'PHOTOGRAPHY: PHOTO I', 'courseNumber': 'UN1700', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR1700_002_2019_3'}
# {'number': '003', 'Call Number': 98837, 'Points': 3, 'Day/Time': 'TR 9:30am-12:00pm', 'Location': '109 Watson Hall', 'Enrollment': '12 students (15 max) as of September  5, 2019', 'Instructor': 'Emile Askey', 'course': 'PHOTOGRAPHY: PHOTO I', 'courseNumber': 'UN1700', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR1700_003_2019_3'}
# {'number': '001', 'Call Number': 98892, 'Points': 3, 'Day/Time': 'F 10:00am-4:00pm', 'Location': '501 Dodge Hall', 'Enrollment': '19 students (19 max) as of September  5, 2019', 'Instructor': 'Susanna Coffey', 'course': 'DRAWING II', 'courseNumber': 'UN2001', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2001_001_2019_3'}
# {'number': '001', 'Call Number': 98836, 'Points': 3, 'Day/Time': 'W 10:00am-4:00pm', 'Location': '401 Dodge Hall', 'Enrollment': '16 students (16 max) as of September  5, 2019', 'Instructor': 'Esteban Cabeza de Baca', 'course': 'PAINTING I', 'courseNumber': 'AV2100', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2100_001_2019_3'}
# {'number': '002', 'Call Number': 98835, 'Points': 3, 'Day/Time': 'F 10:00am-4:00pm', 'Location': '401 Dodge Hall', 'Enrollment': '16 students (16 max) as of September  5, 2019', 'Instructor': 'Thomas White', 'course': 'PAINTING I', 'courseNumber': 'AV2100', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2100_002_2019_3'}
# {'number': '003', 'Call Number': 98834, 'Points': 3, 'Day/Time': 'M 10:00am-4:00pm', 'Location': '401 Dodge Hall', 'Enrollment': '12 students (16 max) as of September  5, 2019', 'Instructor': 'Dana M Deguilio', 'course': 'PAINTING I', 'courseNumber': 'AV2100', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2100_003_2019_3'}
# {'number': '001', 'Call Number': 98891, 'Points': 3, 'Day/Time': 'R 10:00am-4:00pm', 'Location': '315 Prentis Hall at 632 W 125th St', 'Enrollment': '8 students (9 max) as of September  5, 2019', 'Instructor': 'Joseph J Peet', 'course': 'CERAMICS I', 'courseNumber': 'UN2200', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2200_001_2019_3'}
# {'number': '001', 'Call Number': 98833, 'Points': 3, 'Day/Time': 'F 10:00am-4:00pm', 'Location': '315 Prentis Hall at 632 W 125th St', 'Enrollment': '8 students (8 max) as of September  5, 2019', 'Instructor': 'Jon Kessler', 'course': 'SCULPTURE I', 'courseNumber': 'UN2300', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2300_001_2019_3'}
# {'number': '002', 'Call Number': 98832, 'Points': 3, 'Day/Time': 'T 10:00am-4:00pm', 'Location': '315 Prentis Hall at 632 W 125th St', 'Enrollment': '8 students (8 max) as of September  5, 2019 / Full', 'Instructor': 'Gabriel Camnitzer', 'course': 'SCULPTURE I', 'courseNumber': 'UN2300', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2300_002_2019_3'}
# {'number': '001', 'Call Number': 98901, 'Points': 3, 'Day/Time': 'MW 2:30pm-5:00pm', 'Location': '210 Dodge Hall', 'Enrollment': '9 students (9 max) as of September  5, 2019', 'Instructor': 'Jennifer Nuss', 'course': 'PRINTMAKING I: INTAGLIO', 'courseNumber': 'UN2420', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2420_001_2019_3'}
# {'number': '001', 'Call Number': 98831, 'Points': 3, 'Day/Time': 'MW 9:30am-12:00pm', 'Location': '210 Dodge Hall', 'Enrollment': '10 students (9 max) as of September  5, 2019 / Full', 'Instructor': 'Nathan N Catlin', 'course': 'PRINTMAKING I: RELIEF', 'courseNumber': 'UN2430', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2430_001_2019_3'}
# {'number': '001', 'Call Number': 98789, 'Points': 3, 'Day/Time': 'TR 2:00pm-4:30pm', 'Location': '109 Watson Hall', 'Enrollment': '15 students (15 max) as of September  5, 2019', 'Instructor': 'Alexandra Strada', 'course': 'PHOTOGRAPHY: PHOTO II', 'courseNumber': 'UN2701', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR2701_001_2019_3'}
# {'number': '001', 'Call Number': 98900, 'Points': 3, 'Day/Time': 'T 10:00am-4:00pm', 'Location': '501 Dodge Hall', 'Enrollment': '8 students (16 max) as of September  5, 2019', 'Instructor': 'Diana Cooper', 'course': 'COLLAGE: MIXED MEDIA', 'courseNumber': 'UN3010', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR3010_001_2019_3'}
# {'number': '001', 'Call Number': 98830, 'Points': 3, 'Day/Time': 'T 10:00am-4:00pm', 'Location': '401 Dodge Hall', 'Enrollment': '16 students (16 max) as of September  5, 2019 / Full', 'Instructor': 'Gregory Amenoff', 'course': 'PAINTING II', 'courseNumber': 'UN3101', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARQ3101_001_2019_3'}
# {'number': '001', 'Call Number': 10604, 'Points': 3, 'Day/Time': 'R 10:00am-4:00pm', 'Location': '401 Dodge Hall', 'Enrollment': '5 students (16 max) as of September  5, 2019', 'Instructor': 'Dylan R Vandenhoeck', 'course': 'Color: Theory and Practice', 'courseNumber': 'UN3133', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARW3133_001_2019_3'}
# {'number': '001', 'Call Number': 98890, 'Points': 3, 'Day/Time': 'R 10:00am-4:00pm', 'Location': '210 Dodge Hall', 'Enrollment': '8 students (12 max) as of September  5, 2019', 'Instructor': 'Craig Zammiello', 'course': 'PRINTMAKING I: PHOTOGRAVURE', 'courseNumber': 'UN3410', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR3410_001_2019_3'}
# {'number': '001', 'Call Number': 98889, 'Points': 3, 'Day/Time': 'T 10:00am-4:00pm', 'Location': '210 Dodge Hall', 'Enrollment': '10 students (10 max) as of September  5, 2019', 'Instructor': 'Tomas Vu Daniel', 'course': 'PRINTMAKING:DRAWING INTO PRINT', 'courseNumber': 'UN3412', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARQ3412_001_2019_3'}
# {'number': '001', 'Call Number': 98827, 'Points': 3, 'Day/Time': 'T 10:00am-4:00pm', 'Location': 'To be announced', 'Enrollment': '11 students (12 max) as of September  5, 2019', 'Notes': 'FIRST CLASS WILL MEET IN 101 PRENTIS HALL.', 'Instructor': 'Shelly Silver', 'course': 'BEGINNING VIDEO', 'courseNumber': 'UN3500', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR3500_001_2019_3'}
# {'number': '001', 'Call Number': 98825, 'Points': 2, 'Day/Time': 'W 5:15pm-10:00pm', 'Location': '106 Watson Hall', 'Enrollment': '19 students (18 max) as of September  5, 2019 / Full', 'Notes': 'DEPARTMENT APPROVAL REQUIRED', 'Instructor': 'Emily C Henretta', 'course': 'VISITING CRITIC I', 'courseNumber': 'UN3910', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR3910_001_2019_3'}
# {'number': '001', 'Call Number': 98884, 'Points': '1-3', 'Enrollment': '0 students (2 max) as of September  5, 2019', 'Notes': 'DEPARTMENT APPROVAL REQUIRED', 'Instructor': 'Matthew E Buckingham', 'course': 'INDEPENDENT STUDY', 'courseNumber': 'UN3932', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR3932_001_2019_3'}
# {'number': '008', 'Call Number': 98877, 'Points': '1-3', 'Enrollment': '1 student (1 max) as of September  5, 2019 / Full', 'Notes': 'DEPARTMENT APPROVAL REQUIRED', 'Instructor': 'Rirkrit Tiravanija', 'course': 'INDEPENDENT STUDY', 'courseNumber': 'UN3932', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR3932_008_2019_3'}
# {'number': '001', 'Call Number': 98870, 'Points': 3, 'Day/Time': 'F 10:00am-4:00pm', 'Location': '101 Prentis Hall at 632 W 125th St', 'Enrollment': '17 students (16 max) as of September  5, 2019', 'Instructor': 'Kembra Pfahler', 'course': 'Performance Art; Developing a Visual Lex', 'courseNumber': 'GU4600', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR4600_001_2019_3'}
# {'number': '001', 'Call Number': 98796, 'Points': 3, 'Day/Time': 'R 10:00am-1:00pm', 'Location': '101 Prentis Hall at 632 W 125th St', 'Enrollment': '12 students (12 max) as of September  5, 2019 / Full', 'Notes': 'VISUAL ARTS MFA STUDENTS ONLY', 'Instructor': 'Jackie Battenfield', 'course': 'PROFESSIONAL PRACTICE', 'courseNumber': 'AV8000', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR8000_001_2019_3'}
# {'number': '001', 'Call Number': 98792, 'Points': 3, 'Day/Time': 'F 2:00pm-5:00pm', 'Location': '106 Watson Hall', 'Enrollment': '2 students (12 max) as of September  5, 2019', 'Notes': 'VIS ARTS STUDENTS ONLY DEPT APPROVAL REQ 2ND YR PRIORITY', 'Instructor': 'Laimah Osman', 'course': 'SEM IN PRINTMAKING AND RELATED MEDIA', 'courseNumber': 'AV8202', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR8202_001_2019_3'}
# {'number': '001', 'Call Number': 98791, 'Points': 3, 'Day/Time': 'M 11:00am-1:00pm', 'Location': '101 Prentis Hall at 632 W 125th St', 'Enrollment': '14 students (14 max) as of September  5, 2019 / Full', 'Notes': 'VISUAL ARTS MFA STUDENTS ONLY', 'Instructor': 'Tyler S Coburn', 'course': 'CRITICAL ISSUES METHODOLOGIES', 'courseNumber': 'AV8301', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR8301_001_2019_3'}
# {'number': '001', 'Call Number': 98897, 'Points': 3, 'Day/Time': 'T 10:00am-12:00pm', 'Location': '106 Watson Hall', 'Enrollment': '4 students (14 max) as of September  5, 2019', 'Notes': 'VISUAL ARTS MFA STUDENTS ONLY', 'Instructor': 'Tyler Rowland', 'course': 'CRITICAL ISSUES GENEALOGY', 'courseNumber': 'AV8311', 'subject': 'VIAR', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/VIARR8311_001_2019_3'}
# {'number': '001', 'Call Number': 41256, 'Points': 4, 'Day/Time': 'MTWR 12:10pm-1:00pm', 'Location': '609 Hamilton Hall', 'Enrollment': '3 students (15 max) as of September  5, 2019', 'Instructor': 'Mariame S Sy', 'course': 'ELEMENTARY WOLOF I', 'courseNumber': 'UN1101', 'subject': 'WLOF', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/WLOFW1101_001_2019_3'}
# {'number': '001', 'Call Number': 9909, 'Points': 3, 'Day/Time': 'MW 4:10pm-5:25pm', 'Location': '304 Barnard Hall', 'Enrollment': '117 students (120 max) as of September  5, 2019', 'Instructor': 'Rebecca M Young', 'course': 'WOMEN AND HEALTH', 'courseNumber': 'BC1050', 'subject': 'WMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/WMSTX1050_001_2019_3'}
# {'number': '001', 'Call Number': 9913, 'Points': 4, 'Day/Time': 'R 4:10pm-6:00pm', 'Location': 'LL016 MILSTEIN CEN', 'Enrollment': '14 students (20 max) as of September  5, 2019', 'Instructor': 'Alexander Pittman', 'course': 'FEMINIST THEORY', 'courseNumber': 'UN3311', 'subject': 'WMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/WMSTW3311_001_2019_3'}
# {'number': '001', 'Call Number': 9906, 'Points': 4, 'Day/Time': 'T 10:10am-12:00pm', 'Location': '222 Milbank Hall (Barnard)', 'Enrollment': '17 students (20 max) as of September  5, 2019', 'Instructor': 'Kimberly Springer', 'course': 'THEORIZING ACTIVISM', 'courseNumber': 'V3312', 'subject': 'WMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/WMSTV3312_001_2019_3'}
# {'number': '001', 'Call Number': 10573, 'Points': 3, 'Day/Time': 'R 2:10pm-4:00pm', 'Location': '754 EXT Schermerhorn Hall [SCH]', 'Enrollment': '23 students (25 max) as of September  5, 2019', 'Instructor': 'Suzanne Goldberg', 'course': 'TPCS IN SEXUALITY AND GENDER LAW', 'courseNumber': 'UN3450', 'subject': 'WMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/WMSTW3450_001_2019_3'}
# {'number': '001', 'Call Number': 9912, 'Points': 4, 'Day/Time': 'W 2:10pm-4:00pm', 'Location': '214 Milbank Hall (Barnard)', 'Enrollment': '13 students (16 max) as of September  5, 2019', 'Instructor': 'Janet Jakobsen', 'course': 'CRITICAL ANIMAL STUDIES', 'courseNumber': 'BC3513', 'subject': 'WMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/WMSTX3513_001_2019_3'}
# {'number': '001', 'Call Number': 63377, 'Points': 4, 'Day/Time': 'W 2:10pm-4:00pm', 'Location': '754 EXT Schermerhorn Hall [SCH]', 'Enrollment': '4 students (20 max) as of September  5, 2019', 'Instructor': 'Saidiya Hartman', 'course': 'SENIOR SEMINAR I', 'courseNumber': 'UN3521', 'subject': 'WMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/WMSTV3521_001_2019_3'}
# {'number': '001', 'Call Number': 9907, 'Points': 4, 'Day/Time': 'W 10:10am-12:00pm', 'Location': '501 Diana Center', 'Enrollment': '12 students as of September  5, 2019', 'Notes': 'Barnard Students only.', 'Instructor': 'Manijeh Moradian', 'course': 'SEN SEM:KNWLDG PRCTCE POWER', 'courseNumber': 'UN3525', 'subject': 'WMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/WMSTV3525_001_2019_3'}
# {'number': '001', 'Call Number': 63378, 'Points': 4, 'Day/Time': 'R 10:10am-12:00pm', 'Location': '754 EXT Schermerhorn Hall [SCH]', 'Enrollment': '21 students (25 max) as of September  5, 2019', 'Instructor': 'Selina Makana', 'course': 'GENDER & POWER TRANSNATL PERSP', 'courseNumber': 'UN3915', 'subject': 'WMST', 'vergilLink': 'https://vergil.registrar.columbia.edu/#/courses/WMSTW3915_001_2019_3'}

# %%
instructors = [c['Instructors'] for c in courses if c.get('Instructors', None) is not None]

# %%
[i.split(' and ') for i in instructors]
# Out:
# [['Anne Katcher', 'Lina Xu'],
#  ['Hengyong Mo', 'Lina Xu', 'Yuhong Xue'],
#  ['Dariush Akhtari', 'Lina Xu'],
#  ['Yubo Wang', 'Lina Xu'],
#  ['Abraham Weishaus', 'Lina Xu'],
#  ['Abraham Weishaus', 'Lina Xu'],
#  ['Abraham Weishaus', 'Lina Xu'],
#  ['Yubo Wang', 'Lina Xu'],
#  ['Yubo Wang', 'Lina Xu'],
#  ['Gary Venter', 'Lina Xu'],
#  ['Donald F Mango', 'Lina Xu', 'James Maher'],
#  ['Maria C McCormack', 'Lina Xu'],
#  ['John N Vitucci', 'Lina Xu'],
#  ['Daniel Fleming', 'Stephane A Charitos'],
#  ['Craig D Blinderman', 'Robert E Pollack', 'Brigid M Connelly'],
#  ['Saundra Curry', 'Helen Velazquez'],
#  ['Saundra Curry', 'Helen Velazquez'],
#  ['Saundra Curry', 'Helen Velazquez'],
#  ['Saundra Curry', 'Helen Velazquez'],
#  ['Lesley Sharp', 'Nadia Abu El-Haj', 'Severin Fowles'],
#  ['Akeel Bilgrami', 'Partha Chatterjee'],
#  ['Stephen L Ostrow', 'Marco Zaider'],
#  ['Anna Rozenshtein', 'Monique C Katz', 'Matthew P Moy'],
#  ['Karen Fairbanks', 'Joeb Moore'],
#  ['Danielle S Smoller', 'David E Benjamin'],
#  ['Carol A Willis', 'Rosalie Genevro'],
#  ['Kate J Ascher', 'Christoph Kumpusch'],
#  ['Mark Rakatansky', 'Kimberly K Yao'],
#  ['Andrew S Dolkart', 'Claudia Kavenagh'],
#  ['Joseph A Brennan', 'Phillip W Crupi'],
#  ['John D Cerone', 'Mark T Green'],
#  ['Michael Rock', 'Whitney B Dow'],
#  ['Mark Rakatansky', 'Kimberly K Yao'],
#  ['Ada Tolla', 'Giuseppe Lignano'],
#  ['Norman R Weiss', 'John Walsh'],
#  ['Gabrielle Brainard', 'Violet Whitney'],
#  ['Matthew L Keegan', 'Jealool Amari'],
#  ['Matthew L Keegan', 'Alaa A El-Shafei'],
#  ['Matthew L Keegan', "Erik A Blackthorne-O'Barr"],
#  ['Matthew L Keegan', 'Jealool Amari'],
#  ['Matthew L Keegan', 'Alaa A El-Shafei'],
#  ['Matthew L Keegan', "Erik A Blackthorne-O'Barr"],
#  ['Sylvie R Honig', 'Sarit Abramowicz'],
#  ['Sylvie R Honig', 'Sarit Abramowicz'],
#  ['Skye Cleary', 'Sarit Abramowicz'],
#  ['Sylvie R Honig', 'Sarit Abramowicz'],
#  ['John Hunt', 'Arthur Palmer'],
#  ['Diana L Heller', 'Henry Truong'],
#  ['Diana L Heller', 'Henry Truong'],
#  ['Diana L Heller', 'Henry Truong'],
#  ['Paul E Hertz', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Jessica Goldstein', 'James P Casey'],
#  ['Deborah Mowshowitz', 'Lawrence A Chasin', 'Marko Jovanovic'],
#  ['Deborah Mowshowitz', 'Lawrence A Chasin', 'Marko Jovanovic'],
#  ['Deborah Mowshowitz', 'Lawrence A Chasin', 'Marko Jovanovic'],
#  ['Guy Sella', 'Peter Andolfatto'],
#  ['Jessica Goldstein', 'Alison Pischedda', 'Jj L Miranda'],
#  ['Alison Pischedda', 'Jessica Goldstein', 'Jj L Miranda'],
#  ['Jj L Miranda', 'Jessica Goldstein', 'Alison Pischedda'],
#  ['Daniel D Kalderon', 'Lawrence A Chasin'],
#  ['James L Manley', 'Carol L Prives', 'Songtao Jia', 'Marko Jovanovic'],
#  ['Katherine Reuther', 'Aaron M Kyle'],
#  ['Elizabeth Olson', 'Qi Wang'],
#  ['Yufeng Shen', 'Peter A Sims', 'Chaolin Zhang'],
#  ['Daichi Shimbo', 'David J Lederer'],
#  ['Bin Cheng', 'Michaeline A Bresnahan', 'Lillian Morales', 'Qixuan Chen'],
#  ['Yu Yu Khaing', 'Stephane A Charitos'],
#  ['Geraldine A Wu', 'Jenny Fielding'],
#  ['Fiona Hui', 'Stephane A Charitos'],
#  ['Fiona Hui', 'Stephane A Charitos'],
#  ['Fiona Hui', 'Stephane A Charitos'],
#  ['Ronald Liem', 'Zaia Sivo'],
#  ['Ronald Liem', 'Zaia Sivo'],
#  ['Scott Banta', 'Robert G Bozic'],
#  ['Scott Banta', 'Robert G Bozic'],
#  ['Scott Banta', 'Robert G Bozic'],
#  ['Scott Banta', 'Robert G Bozic'],
#  ['Vivian F McNeill', 'Aghavni Bedrossian'],
#  ['Sarah J Hansen', 'Joseph C Ulichny'],
#  ['Joseph C Ulichny', 'Sarah J Hansen'],
#  ['Joseph C Ulichny', 'Sarah J Hansen'],
#  ['Joseph C Ulichny', 'Sarah J Hansen'],
#  ['Joseph C Ulichny', 'Sarah J Hansen'],
#  ['Joseph C Ulichny', 'Sarah J Hansen'],
#  ['Suqing Liu', 'Subhasish Chatterjee', 'Akbar Mahdavi Shakib'],
#  ['Suqing Liu', 'Craig Allen', 'Bu Fei'],
#  ['Suqing Liu', 'Andrew C Crowther', 'Subhasish Chatterjee'],
#  ['Suqing Liu', 'Subhasish Chatterjee', 'Akbar Mahdavi Shakib'],
#  ['Suqing Liu', 'Judith M Kamm', 'Jonelle White'],
#  ['Suqing Liu', 'Subhasish Chatterjee'],
#  ['Raymundo   Jr. Pantoja', 'Talha Siddiqui'],
#  ['Raymundo   Jr. Pantoja', 'Talha Siddiqui'],
#  ['Raymundo   Jr. Pantoja', 'Talha Siddiqui'],
#  ['Raymundo   Jr. Pantoja', 'Talha Siddiqui'],
#  ['Raymundo   Jr. Pantoja', 'Talha Siddiqui'],
#  ['Raymundo   Jr. Pantoja', 'Talha Siddiqui'],
#  ['Raymundo   Jr. Pantoja', 'Talha Siddiqui'],
#  ['Raymundo   Jr. Pantoja', 'Talha Siddiqui'],
#  ['Jean Vadakkan', 'Craig Allen'],
#  ['Jean Vadakkan', 'Craig Allen', 'Akbar Mahdavi Shakib'],
#  ['Dalibor Sames', 'Tomislav Rovis'],
#  ['Angelo Cacciuto', 'Bruce Berne'],
#  ['Raymond P Daddazio', 'Virginia Mosquera'],
#  ['Robert D Mutch', 'Richard Carbonaro'],
#  ['Robert D Mutch', 'Richard Carbonaro'],
#  ['David Albert', 'C Kunzel'],
#  ['Bernard Harcourt', 'Alexis Hoag'],
#  ['Gayatri C Spivak', 'Rosalind Morris'],
#  ['Xiaolu Guo', 'Karen R Van Dyck'],
#  ['Bruce Robbins', 'Orhan Pamuk'],
#  ['Zeynep Celik', 'Stefan Andriopoulos'],
#  ['Alexandros Biliris', 'Eran Tromer'],
#  ['Michael Theobald', 'Franjo Ivancic'],
#  ['Todd E Mayo', 'Mark W Hildreth'],
#  ['John B Parkinson', 'James Murphy'],
#  ['Awi Federgruen', 'Cyrus Mohebbi'],
#  ['Charles R Guetta', 'Brett Martin'],
#  ['C Kunzel', 'James B Fine'],
#  ['Upmanu Lall', 'Athanasios Bourtsalas'],
#  ['Xi Chen', 'Athanasios Bourtsalas'],
#  ['Jerry F McManus', 'Adam H Sobel'],
#  ['Maria Tolstoy', 'Jonathan Kingslake'],
#  ['John C Mutter', 'Ruth Defries'],
#  ['Arnold L Gordon', 'Ryan P Abernathey'],
#  ['James Gaherty', 'Donna J Shillington'],
#  ['Mingfang Ting', 'Simon Mason'],
#  ['Ben Orlove', 'Catherine L Vaughan'],
#  ['Ryan P Abernathey', 'Kerry Key'],
#  ['Galen A McKinley', 'Arlene M Fiore'],
#  ['Maureen Raymo', 'Jacqueline Austermann'],
#  ['Goran Ekstrom', 'Spahr C Webb', 'Meredith Nettles', 'James Gaherty'],
#  ['James Gaherty', 'Goran Ekstrom', 'Meredith Nettles'],
#  ['Yuqing Luo', 'Xiao Xiao'],
#  ['Shahid Naeem', 'Andres Bendesky'],
#  ['Dustin Rubenstein', 'Darcy B Kelley'],
#  ['Matthew I Palmer', 'Suzanne Macey'],
#  ['Matthew I Palmer', 'Suzanne Macey'],
#  ['Marya Pollack', 'Robert E Pollack'],
#  ['Deren Eaton', 'Joel L Cracraft'],
#  ['Maria Diuk-Wasser', 'Shahid Naeem'],
#  ['Sonia Pereira', 'Qasim Abbas'],
#  ['Belinda Archibong', 'Dan Poniachik'],
#  ['Randall Reback', 'Asutosh Nanda'],
#  ['Lalith Munasinghe', 'Qasim Abbas'],
#  ['Martina Jasova', 'Martha Susana Jaimes Builes'],
#  ['Elizabeth O Ananat', 'John Park'],
#  ['Lalith Munasinghe', 'John Park'],
#  ['Andre Burgstaller', 'Mohamed Obaidy'],
#  ["Brendan O'Flaherty", 'Lena Edlund'],
#  ['Evan D Sadler', 'Mark Dean'],
#  ['Xavier Sala-I-Martin', "Jennifer La'O"],
#  ['Simon Lee', 'Jose L Montiel Olea'],
#  ['Simon Lee', 'Serena Ng'],
#  ['Martin Uribe', 'Stephanie Schmitt-Grohe'],
#  ['Michael C Best', 'Eric A Verhoogen'],
#  ['Donald R Davis', 'Reka Juhasz'],
#  ['Navin Kartik', 'Yeon-Koo Che'],
#  ['Michael C Best', 'Miguel S Urquiola'],
#  ['Michael D Woodford', "Jennifer La'O", 'Hassan Afrouzi Khosroshahi'],
#  ['Harrison Hong', 'Matthieu Gomez'],
#  ['Jacopo Perego', 'Evan D Sadler'],
#  ['Donald R Davis', 'Amit K Khandelwal'],
#  ['Jack J Willis', 'Cristian Pop-Eleches'],
#  ['Simon Lee', 'Jose L Montiel Olea'],
#  ['Charles Angelucci', 'Fanyin Zheng'],
#  ['Jonah Rockoff', 'Michael C Best'],
#  ['Faculty', 'Chandler Miranda'],
#  ['Faculty', 'Chandler Miranda'],
#  ['Corinne D Kentor', 'Erika Kitzmiller'],
#  ['Corinne D Kentor', 'Erika Kitzmiller'],
#  ['Marc Leblanc', 'Stephane A Charitos'],
#  ['Bodhisatwa Sadhu', 'Wooram Lee'],
#  ['Bodhisatwa Sadhu', 'Wooram Lee'],
#  ['Krishnan Sabnani', 'Thomas Woo'],
#  ['Chong Li', 'Lei Zhang'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Eleni Drinea', 'Adam Kelleher', 'Sining Chen'],
#  ['Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Janet Kayfetz', 'Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Janet Kayfetz', 'Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Janet Kayfetz', 'Jenny S Mak', 'Elizabeth M Strauss'],
#  ['Lydia Fass', 'Frances A Boyd', 'Sarah Custen'],
#  ['Christopher Collins', 'Janice S Weinreb', 'Judy L Miller'],
#  ['Leila M May-Landy', 'Elizabeth Bottcher', 'Michael Roberts'],
#  ['Brittany Ober', 'Elizabeth Bottcher', 'Tristan Thorne'],
#  ['Carolyn Dunn', 'Nadia Green', 'Michael Roberts'],
#  ['Linda Britton', 'Susan K Cafetz', 'Sarah Custen'],
#  ['Barbara Kruchin', 'Timothy F McLaughlin', 'Csilla Borbala Korbl'],
#  ['Michele Lewis', 'Julie Lee'],
#  ['Pamela Cobrin', 'Daniela Kempf'],
#  ['Jennie Kassanoff', 'Alexandra C Horowitz'],
#  ['John Burkhardt', 'Rich Lauria'],
#  ['Sara Constantino', 'Rossano Rossi'],
#  ['John J Doyle', 'Nicolle M Gatto', 'Ulka B Campbell'],
#  ['Ruth Ottman', 'Christiane Reitz'],
#  ['Katherine M Keyes', 'Ezra S Susser'],
#  ['Charles Branas', 'Theodore E Alcorn'],
#  ['Guohua Li', 'Thelma Mielenz'],
#  ['Lisa Bates', 'Lillian Morales'],
#  ['Richard Neugebauer', 'Francine Cournos'],
#  ['Larkin S McReynolds', 'Lillian Morales'],
#  ['Larkin S McReynolds', 'Lillian Morales'],
#  ['Agnes Magtoto', 'Stephane A Charitos'],
#  ['Luis Francia', 'Stephane A Charitos'],
#  ['Robert King', 'Lance Weiler'],
#  ['Esther Imperio Hamburger', 'Carlos Machado Calil'],
#  ['Ira Deutchman', 'Mary Jane Skalski'],
#  ['Ethan Namvar', 'Charles Jones'],
#  ['Richard Wolfe', 'Jennifer M Morgan'],
#  ['Jeffrey Gordon', 'Patrick Bolton'],
#  ['Kevin Oro-Hahn', 'Rishi Renjen'],
#  ['Mark A Cooper', 'Jonathon D Luft'],
#  ['Scott M Hendrickson', 'Michael B Kimpel'],
#  ['Daniel Yarsky', 'Keith W Luh'],
#  ['Adam M Birnbaum', 'Shayan S Mozaffar'],
#  ['Grant W Bowman', 'Brian P Waterhouse'],
#  ['Brian P Lancaster', 'Zachary D Aarons'],
#  ['Neng Wang', 'Patrick Bolton'],
#  ['Neng Wang', 'Patrick Bolton'],
#  ['Amanda Bergner', 'Ilana Chilton'],
#  ['Amanda Bergner', 'Jessica Giordano'],
#  ['Timothy H Bestor', 'Kimberly S Warren'],
#  ['Michael M Shen', 'Kimberly S Warren'],
#  ['Luke Berchowitz', 'Kimberly S Warren'],
#  ['Michael M Shen', 'Kimberly S Warren'],
#  ['Michael M Shen', 'Kimberly S Warren'],
#  ['Kim Hekimian', 'Neil Schluger'],
#  ['Kim Hekimian', 'Neil Schluger'],
#  ['Wynnie Lamour', 'Stephane A Charitos'],
#  ['Arthur Klein', 'Amina Williams'],
#  ['Catherine Foster', 'Rebecca R Sale'],
#  ['Catherine Foster', 'Rebecca R Sale'],
#  ['Catherine Foster', 'Rebecca R Sale'],
#  ['Catherine Foster', 'Rebecca R Sale'],
#  ['John Rowe', 'Catherine Foster'],
#  ['Tunc Sen', 'Zeynep Celik'],
#  ['Manan Ahmed', 'Karl Jacoby'],
#  ['Marwa Elshakry', 'Mae M Ngai'],
#  ['Malgorzata Mazurek', 'Gregory Mann'],
#  ['Paul T Chamberlin', 'Line Lillevik'],
#  ['Steven I Safier', 'Aaron S Wallen'],
#  ['Jason Wingard', 'Reshan Richards'],
#  ['Yvette Burton', 'Aaron S Wallen'],
#  ['Jo Becker', 'Michael G Bochenek'],
#  ['John S Cavallaro', 'James B Fine'],
#  ['James B Fine', 'Dennis P Tarnow'],
#  ['James B Fine', 'Dennis P Tarnow'],
#  ['James B Fine', 'Dennis P Tarnow'],
#  ['Dennis P Tarnow', 'James B Fine'],
#  ['Dennis P Tarnow', 'James B Fine'],
#  ['Dennis P Tarnow', 'James B Fine'],
#  ['Dennis P Tarnow', 'James B Fine'],
#  ['Dennis P Tarnow', 'James B Fine'],
#  ['Dennis P Tarnow', 'James B Fine', 'Gary Greenstein'],
#  ['Brett Vintch', 'Brianne Cortese'],
#  ['Michael Miller', 'Sebastien Donadio'],
#  ['Ali Hirsa', 'Carmen Ng'],
#  ['Mary Abraham', 'Edward J Hoffman'],
#  ['Mary Abraham', 'Edward J Hoffman'],
#  ['Mary Abraham', 'Edward J Hoffman'],
#  ['Mary Abraham', 'Edward J Hoffman', 'Larry Prusak'],
#  ['Rachel Chung', 'Jo Ann Cavallo'],
#  ['Christine M Mangle', 'Sarita D Martinez', 'Kimya M Gittens'],
#  ['Laureen A Zubiaurre Bitzer', 'Dana L Wolf'],
#  ['Dana L Wolf', 'Sandra Bernal-Garcia'],
#  ['Nancy M Chang', 'Kimya M Gittens', 'Anita Softness'],
#  ['Nancy M Chang', 'Kimya M Gittens', 'Anita Softness'],
#  ['Nancy M Chang', 'Kimya M Gittens', 'Anita Softness'],
#  ['Nancy M Chang', 'Kimya M Gittens', 'Anita Softness'],
#  ['David A Albert', 'Lynn M Tepper'],
#  ['Adam H Cannon', 'Scarlett Swerdlow'],
#  ['Louise Burke', 'Mark Schwartz'],
#  ['Willem Buiter', 'Anne Sibert'],
#  ['Natasha N Goldstein', 'Ana M Aristizabal'],
#  ['William B Eimicke', 'Howard W Buffett'],
#  ['Michael Gaouette', 'Adam Day'],
#  ['Rainer Braun', 'Judith A Gearhart'],
#  ['Jason Healey', 'Evan Wolff'],
#  ["Padraig O'Cearuil", 'Stephane A Charitos'],
#  ["Padraig O'Cearuil", 'Stephane A Charitos'],
#  ['William Cobb', 'Samuel G Freedman'],
#  ['Lynnell Hancock', 'Joanne Faryon'],
#  ['Dale Maharidge', 'Maria V Alvarez'],
#  ['Keith A Gessen', 'Nina J Berman', 'Duy Linh N Tu'],
#  ['Duy Linh N Tu', 'Nina J Berman'],
#  ['Justin Elliott', 'Jessica L Huseman'],
#  ['Christopher Harwood', 'Elena D Neascu'],
#  ['Anar Patel', 'Hunter Whaley'],
#  ['Sophia Bernhardt', 'Mariana Newman'],
#  ['Jared E Ruocco', 'Elena D Neascu'],
#  ['Amy McCamphill', 'Mariana Newman'],
#  ['Elizabeth F Bernhardt', 'Alice Izumo'],
#  ['David S Louk', 'Hunter Whaley'],
#  ['David S Louk', 'Hunter Whaley'],
#  ['Tanya M Hajjar', 'Elena D Neascu'],
#  ['Jessica Jimenez', 'Alice Izumo'],
#  ['Gerald Lebovits', 'Hunter Whaley'],
#  ['Elizabeth L Smith', 'Elena D Neascu'],
#  ['Jessica Jimenez', 'Alice Izumo'],
#  ['Dan Berger', 'Hunter Whaley'],
#  ['Eric S Askanase', 'Elena D Neascu'],
#  ['Evan R Kreiner', 'Hunter Whaley'],
#  ['Christopher S Cogburn', 'Alice Izumo'],
#  ['Kimberle Crenshaw', 'Barbara Arnwine'],
#  ['Martin Glenn', 'Michael Gerber'],
#  ['Frances Weiner', 'Courtney Hogg'],
#  ['Frances Weiner', 'Courtney Hogg'],
#  ['Lawrence R Glosten', 'Merritt B Fox'],
#  ['George A Bermann', 'Kabir Duggal'],
#  ['Jody Kraus', 'Christina M Duffy Ponsa'],
#  ['Noah Smith-Drelich', 'Mariana Newman'],
#  ['Joel G Kosman', 'Hunter Whaley'],
#  ['Noah Smith-Drelich', 'Mariana Newman'],
#  ['Minhao Benjamin Chen', 'Hunter Whaley'],
#  ['Andrew D Friedman', 'Kumar Rao', 'Dmitri Holtzman'],
#  ['Andrew D Friedman', 'Kumar Rao', 'Dmitri Holtzman'],
#  ['Michael Gerber', 'Shawn G Crowley'],
#  ['Scott E Kessler', 'Brenna Strype'],
#  ['Scott E Kessler', 'Brenna Strype'],
#  ['Monica Wagner', 'Lisa Landau'],
#  ['Monica Wagner', 'Lisa Landau'],
#  ['Nicholas G Esq Garaufis', 'Allon Lifshitz'],
#  ['Nicholas G Esq Garaufis', 'Allon Lifshitz'],
#  ['Matthew Knecht', 'Seth Steed'],
#  ['Matthew Knecht', 'Seth Steed'],
#  ['Carl S Kaplan', 'Mark Zeno'],
#  ['Carl S Kaplan', 'Mark Zeno'],
#  ['Corrine A Irish', 'George Kendall', 'Jenay Nurse'],
#  ['Corrine A Irish', 'George Kendall', 'Jenay Nurse'],
#  ['Shannon Cumberbatch', 'Daniel Kay'],
#  ['Shannon Cumberbatch', 'Daniel Kay'],
#  ['David Marriott', 'David Kappos'],
#  ['David Kappos', 'David Marriott'],
#  ['Karen Cacace', 'Young Lee'],
#  ['Karen Cacace', 'Young Lee'],
#  ['Jeffrey Gordon', 'Patrick Bolton'],
#  ['Alexander Krulic', 'Kira Antell'],
#  ['James Liebman', 'Elizabeth M Chu'],
#  ['Elizabeth M Chu', 'James Liebman', 'Kimberly Austin'],
#  ['Elizabeth M Chu', 'James Liebman', 'Kimberly Austin'],
#  ['George P Fletcher', 'Michel Paradis'],
#  ['Blake Reese', "Karen O'Connell"],
#  ['William Savitt', 'Ryan McLeod'],
#  ['Merit E Janow', 'Petros C Mavroidis'],
#  ['Kenneth Rivlin', 'Matthew G Morreale'],
#  ['Susan P Sturm', 'Richard W Gray', 'Elizabeth F Emens'],
#  ['Petros C Mavroidis', 'Jennifer Rodgers'],
#  ['Charles Nathan', 'Samuel Liss'],
#  ['Fred T Magaziner', 'Kathleen Massey'],
#  ['Richard Zabel', 'Brendan McGuire'],
#  ['Daniel Richman', 'Matthew Waxman'],
#  ['Kathryn E Judge', 'Kristen Underhill'],
#  ['John C Jr Coffee', 'Jed S Rakoff'],
#  ['Benjamin Hoffman', 'Sarah Knuckey'],
#  ['Benjamin Hoffman', 'Sarah Knuckey'],
#  ['Stephen Kotran', 'Uday K Veeraraghavan'],
#  ['Trevor S Norwitz', 'Igor Kirman'],
#  ['Arthur Kaufman', 'Engla C Sandberg'],
#  ['Edward Lloyd', 'Jennifer Danis'],
#  ['Edward Lloyd', 'Jennifer Danis'],
#  ['Edward Lloyd', 'Jennifer Danis'],
#  ['Elora Mukherjee', 'Amelia Wilson'],
#  ['Teri D Silvers', 'Karen M Sandler'],
#  ['Teri D Silvers', 'Karen M Sandler'],
#  ['Brian J Donnelly', 'Conrad A Johnson', 'Mary M Zulack'],
#  ['Brian J Donnelly', 'Conrad A Johnson', 'Mary M Zulack'],
#  ['Timothy S Wu', 'Vincent A Blasi', 'Donald B Jr Verrilli'],
#  ['Edward Lloyd', 'Jennifer Danis', 'Amelia Wilson'],
#  ['Brian J Donnelly', 'Conrad A Johnson', 'Mary M Zulack'],
#  ['George P Fletcher', 'Saul J Berman'],
#  ['Bryan L Bloom', 'Amy McFarlane'],
#  ['Bryan L Bloom', 'Amy McFarlane'],
#  ['Meredith Landman', 'John H McWhorter'],
#  ['Robert N Bontempo', 'William M Klepper'],
#  ['Brendan M Burns', 'David B Lerner'],
#  ['Jack McGourty', "William O'Farrell"],
#  ['Silvia Bellezza', 'Andrey Simonov'],
#  ['Silvia Bellezza', 'Andrey Simonov'],
#  ['Ran Kivetz', 'Andrey Simonov'],
#  ['Bernd H Schmitt', 'Matthew J Quint'],
#  ['Rajeev Kohli', 'Alonso Martinez'],
#  ['Rajeev Kohli', 'Alonso Martinez'],
#  ['Sunil K Gulati', 'Jonathan A Knee'],
#  ['Kamel Jedidi', 'Robert Morais'],
#  ['Rajeev Kohli', 'Alonso Martinez'],
#  ['Beatrice D Ellerin', 'Maqbul Jamil'],
#  ['Michelle Greenwald', 'Elizabeth Elam'],
#  ['Alonso Martinez', 'Elizabeth Elam'],
#  ['Lillian Morales', 'Carlos Correa'],
#  ['Lillian Morales', 'Carlos Correa'],
#  ['Delphine S Taylor',
#   'Michael J Devlin',
#   'Sarita D Martinez',
#   'Urmi A Desai'],
#  ['Michael J Devlin',
#   'Delphine S Taylor',
#   'Sarita D Martinez',
#   'Stephanie Jala'],
#  ['Thomas J Garrett', 'Sarita D Martinez', 'Camilla Smith'],
#  ['Katherine G Nickerson', 'Thea Ogunusi'],
#  ['Katherine G Nickerson', 'Thea Ogunusi'],
#  ['Katherine G Nickerson', 'Thea Ogunusi'],
#  ['Katherine G Nickerson', 'Thea Ogunusi'],
#  ['Katherine G Nickerson', 'Thea Ogunusi'],
#  ['Katherine G Nickerson', 'Thea Ogunusi'],
#  ['Katherine G Nickerson', 'Thea Ogunusi'],
#  ['Katherine G Nickerson', 'Thea Ogunusi'],
#  ['Mahir Cetiz', 'Georg Friedrich Haas'],
#  ['Maura L Spiegel', 'Ssanyu N Birigwa'],
#  ['Craig Irvine', 'Ssanyu N Birigwa'],
#  ['Danielle R Spencer', 'Saljooq M Asif'],
#  ['Marsha Hurst', 'Deborah Starr'],
#  ['Catherine G Rogers', 'Courtney Gillette'],
#  ['Beth Fisher-Yoshida', 'Camilo Azcarate'],
#  ['Franck Polleux', 'Alla Kerzhner'],
#  ['Kenneth D Miller', 'Alla Kerzhner'],
#  ['Randy Bruno', 'Alla Kerzhner'],
#  ['Rene Hen', 'Sergey Kalachikov', 'Alla Kerzhner'],
#  ['Christoph B Kellendonk', 'Alla Kerzhner'],
#  ['Aniruddha Das', 'Alla Kerzhner', 'Ulrich Hengst'],
#  ['Wesley B Grueber', 'Alla Kerzhner', 'Ulrich Hengst'],
#  ['Comana M Cioroiu', 'Emerita Verdejo', 'Chavelle Barnett', 'Ashley Chang'],
#  ['Comana M Cioroiu', 'Emerita Verdejo', 'Chavelle Barnett', 'Ashley Chang'],
#  ['Comana M Cioroiu', 'Emerita Verdejo', 'Chavelle Barnett', 'Ashley Chang'],
#  ['Comana M Cioroiu', 'Emerita Verdejo', 'Chavelle Barnett', 'Ashley Chang'],
#  ['Latisha M Hanson', 'Heidi Hahn-Schroeder'],
#  ['Latisha M Hanson', 'Heidi Hahn-Schroeder'],
#  ['Latisha M Hanson', 'Heidi Hahn-Schroeder'],
#  ['Latisha M Hanson', 'Heidi Hahn-Schroeder'],
#  ['Latisha M Hanson', 'Heidi Hahn-Schroeder'],
#  ['Latisha M Hanson', 'Heidi Hahn-Schroeder'],
#  ['Kathleen Mullen', 'Heidi Hahn-Schroeder'],
#  ['Kathleen Mullen', 'Heidi Hahn-Schroeder'],
#  ['Kathleen Mullen', 'Heidi Hahn-Schroeder'],
#  ['Kathleen Mullen', 'Heidi Hahn-Schroeder'],
#  ['Kathleen Mullen', 'Heidi Hahn-Schroeder'],
#  ['Kathleen Mullen', 'Heidi Hahn-Schroeder'],
#  ['Jeanne N Churchill', 'Heidi Hahn-Schroeder'],
#  ['Jeanne N Churchill', 'Heidi Hahn-Schroeder'],
#  ['Jeanne N Churchill', 'Heidi Hahn-Schroeder'],
#  ['Jeanne N Churchill', 'Heidi Hahn-Schroeder'],
#  ['Jeanne N Churchill', 'Heidi Hahn-Schroeder'],
#  ['Jeanne N Churchill', 'Heidi Hahn-Schroeder'],
#  ['Karol Dibello', 'Heidi Hahn-Schroeder'],
#  ['Ana Kelly', 'Heidi Hahn-Schroeder'],
#  ['Ana Kelly', 'Heidi Hahn-Schroeder'],
#  ['Ana Kelly', 'Heidi Hahn-Schroeder'],
#  ['Mary B Moran', 'Heidi Hahn-Schroeder'],
#  ['Mary B Moran', 'Heidi Hahn-Schroeder'],
#  ['Mary B Moran', 'Heidi Hahn-Schroeder'],
#  ['Natalie Voigt', 'Heidi Hahn-Schroeder'],
#  ['Natalie Voigt', 'Heidi Hahn-Schroeder'],
#  ['Natalie Voigt', 'Heidi Hahn-Schroeder'],
#  ['Mary B Moran', 'Heidi Hahn-Schroeder'],
#  ['Mary B Moran', 'Heidi Hahn-Schroeder'],
#  ['Mary B Moran', 'Heidi Hahn-Schroeder'],
#  ['Clare C McKegney', 'Jaime Panton'],
#  ['Jaime Panton', 'Clare C McKegney', 'Deanna M Schneider'],
#  ['Karol Dibello', 'Heidi Hahn-Schroeder'],
#  ['Lisa Iannacci-Manasia', 'Heidi Hahn-Schroeder'],
#  ['Elizabeth K Hall', 'Ellen M Fahey'],
#  ['Christian Cansino', 'Mona Patel'],
#  ['Amy Dzierba', 'Caroline Der-Nigoghossian'],
#  ['Rebekah L Ruppe', 'Maria R Corsaro'],
#  ['Laura Zeidenstein', 'Rebekah L Ruppe'],
#  ['Laura Zeidenstein', 'Rebekah L Ruppe'],
#  ['Laura Zeidenstein', 'Maria R Corsaro', 'Rebekah L Ruppe'],
#  ['Maria R Corsaro', 'Rebekah L Ruppe'],
#  ['Elizabeth K Hall', 'Marlene E Mc Hugh', 'Debra Miller-Saultz'],
#  ['Jeffrey Kwong', 'Brenda L Janotha'],
#  ['Elizabeth K Hall', 'Ellen M Fahey'],
#  ['Dara N Matseoane-Peterssen', 'Dana Feinberg'],
#  ['Dara N Matseoane-Peterssen', 'Dana Feinberg'],
#  ['Dara N Matseoane-Peterssen', 'Dana Feinberg'],
#  ['Dara N Matseoane-Peterssen', 'Dana Feinberg'],
#  ['Jennifer A Kalina', 'Lenin Grajo'],
#  ['Lora Glass', 'Gaby Y Novak'],
#  ['Lora Glass', 'Gaby Y Novak'],
#  ['Lora Glass', 'Gaby Y Novak'],
#  ['Lora Glass', 'Gaby Y Novak'],
#  ['Philip Kang', 'Sunil Wadhwa'],
#  ['Joshua E Hyman', 'Tamika Lynch'],
#  ['Joshua E Hyman', 'Tamika Lynch'],
#  ['Joshua E Hyman', 'Tamika Lynch'],
#  ['Joshua E Hyman', 'Tamika Lynch'],
#  ['Richard Baer', 'Anna Lasorella'],
#  ['Sarita D Martinez', 'Christina E Rho', 'Stephanie Jala'],
#  ['Jay H Lefkowitch',
#   'Sarita D Martinez',
#   'Christina E Rho',
#   'Patrice Spitalnik'],
#  ['Jonathan M Barasch', 'Sarita D Martinez', 'Christina E Rho'],
#  ['Paulette Sally Bernd', 'Sarita D Martinez'],
#  ['Ronald Liem', 'Zaia Sivo'],
#  ['Ronald Liem', 'Zaia Sivo'],
#  ['Jacqueline C Outlaw', 'Marina Catallozzi'],
#  ['Marina Catallozzi', 'Jacqueline C Outlaw'],
#  ['Jacqueline C Outlaw', 'Marina Catallozzi'],
#  ['Jacqueline C Outlaw', 'Marina Catallozzi'],
#  ['Dennis P Tarnow', 'James B Fine'],
#  ['Dennis P Tarnow', 'James B Fine'],
#  ['Susan F Steinberg', 'Karen J Allis'],
#  ['Michael R Rosen', 'Karen J Allis'],
#  ['Susan F Steinberg', 'Karen J Allis'],
#  ['Susan F Steinberg', 'Karen J Allis'],
#  ['Susan F Steinberg', 'Karen J Allis'],
#  ['James B Bolster', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Jesse Chapman', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Scott Donie', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder', 'Pepper Pavlish'],
#  ['Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Aphrodite Daphnis', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Theodore Cowling', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Caroline Blum', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Christopher Sachvie', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder', 'Michael Burr'],
#  ['Lauren Kahn', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Jeffrey Ryder', 'Belgica Ramirez', 'Anne M Skylis'],
#  ['Amber Cannady', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Allison Salter', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Seoungwoo Lee', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Jeffrey Ryder', 'Belgica Ramirez', 'Anne M Skylis', 'Nathaniel Clark'],
#  ['Tyler Cordell', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Sarah Perron', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Peggy Levine', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Colleen Irby', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Lauren Dudziak', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Tamara Sagadore', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Erik Supplee', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Jeffrey Ryder', 'Belgica Ramirez', 'Anne M Skylis', 'India C Choquette'],
#  ['Dan Tischler', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Maraya Slatter', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['Gustavo Leal', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Cassaundra Vondrak', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Demerae Christianson', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Brian Jines', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Joanne Schickerling', 'Jeffrey Ryder'],
#  ['Jumpie Harada', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Sara Negrette', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anastasia Kirtiklis', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Michael Aufrichtig', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Samantha R Warren', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Aliza Feuerstein', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Bonnie Baker', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Samantha Fahey',
#   'Belgica Ramirez',
#   'Anne M Skylis',
#   'Amphone Keovongmanysar'],
#  ['Joseph Nord', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Jennifer Spicer', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['Jessica M Harrington', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['Andrew Laiosa', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Amy Weeks', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['Kenneth Pollard', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['Jeffrey Ryder', 'Belgica Ramirez', 'Anne M Skylis'],
#  ['Gaurav Misra', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['James E McDermott', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Christie Bonn', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Cemi Abreu', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Derek Davis', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Brett Boretti', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Megan L Griffith', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['James Engles', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Emerson Curry', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Nicholas L Parker', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Scott Alwin', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Nicholas L Parker', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Scott Alwin', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Michael Aufrichtig', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Michael Aufrichtig', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Caroline Nichols', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Gregory C Lamb', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Amy Weeks', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['mueller', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Andrea Cofrin', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Tracey Bartholomew', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Kevin Anderson', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Jennifer Teague', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Diana Caskey', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['James B Bolster', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Ilene J Weintraub', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Howard M Endelman', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Daniel Ireland', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Daniel Ireland', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['Zachary Tanelli', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Jacques Swanepoel', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Jacques Swanepoel', 'Belgica Ramirez', 'Anne M Skylis', 'Jeffrey Ryder'],
#  ['Anne M Skylis', 'Belgica Ramirez', 'Jeffrey Ryder'],
#  ['Colleen Brough', 'Debra Krasinski', 'Mahlon K Stewart'],
#  ['Mahlon K Stewart', 'Debra Krasinski', 'Colleen Brough'],
#  ['Debra Krasinski', 'Stacy Kinirons'],
#  ['Colleen Brough', 'Debra Krasinski'],
#  ['Cynthia M Chiarello', 'Debra Krasinski', 'Fu Wing'],
#  ['Laurel D Abbruzzese', 'Debra Krasinski'],
#  ['Debra Krasinski', 'Laurel D Abbruzzese', 'Martha Sliwinski'],
#  ['Martha Sliwinski', 'Debra Krasinski'],
#  ['Colleen Brough', 'Debra Krasinski'],
#  ['Colleen Brough', 'Debra Krasinski'],
#  ['Clare C Bassile', 'Debra Krasinski', 'Martha Sliwinski'],
#  ['Christopher K Wong', 'Debra Krasinski'],
#  ['Ashwini Rao', 'Debra Krasinski'],
#  ['Martha Sliwinski', 'Debra Krasinski'],
#  ['Cynthia M Chiarello', 'Debra Krasinski'],
#  ['Clare C Bassile', 'Debra Krasinski'],
#  ['Martha Sliwinski', 'Debra Krasinski'],
#  ['Rami Said', 'Debra Krasinski', 'Jean Timmerberg'],
#  ['Laurel D Abbruzzese', 'Debra Krasinski'],
#  ['Laurel D Abbruzzese', 'Debra Krasinski'],
#  ['Stacy Kinirons', 'Debra Krasinski'],
#  ['Stacy Kinirons', 'Debra Krasinski'],
#  ['Jean Timmerberg',
#   'Cynthia M Chiarello',
#   'Debra Krasinski',
#   'Martha Sliwinski'],
#  ['Jacqueline Montes', 'Debra Krasinski'],
#  ['Jacqueline Montes', 'Debra Krasinski'],
#  ['Jacqueline Montes', 'Debra Krasinski'],
#  ['Mahlon K Stewart', 'Lisa H Yoon', 'Debra Krasinski', 'Colleen Brough'],
#  ['Mahlon K Stewart', 'Debra Krasinski', 'Colleen Brough'],
#  ['Christopher K Wong', 'Evan K Johnson', 'Debra Krasinski'],
#  ['Clare C Bassile', 'Debra Krasinski', 'Ashwini Rao'],
#  ['Lisa H Yoon', 'Debra Krasinski'],
#  ['Fu Wing', 'Debra Krasinski'],
#  ['Fu Wing', 'Debra Krasinski'],
#  ['Michael Johson', 'Debra Krasinski'],
#  ['Colleen Brough', 'Debra Krasinski', 'Mahlon K Stewart'],
#  ['Stiliana Savin', 'Faculty', 'Laura E Kay'],
#  ['Timothy J Halpin-Healy', 'Margaret F Kaye'],
#  ['Janna Levin', 'Rachel A Rosen'],
#  ['Andrew R Marks', 'Karen J Allis', 'Henry M Colecraft'],
#  ['Jane Dodd', 'Karen J Allis', 'Filippo Mancia'],
#  ['Andrew McGee', 'Jennifer Chang'],
#  ['Steven Bloom', 'Christopher W Munsell'],
#  ['Steven Bloom', 'Christopher W Munsell'],
#  ['Harold K Bell', 'Jessica A Stockton'],
#  ['Raquel Ramati', 'Jessica A Stockton'],
#  ['Mark Weidner', 'Jessica A Stockton', 'Michael G Clark'],
#  ['Jessica A Stockton', 'William Heishman'],
#  ['Jamie von Klemperer', 'Jessica A Stockton', 'Gene Kohn'],
#  ['Kate J Ascher', 'Christoph Kumpusch'],
#  ['Erica C Avrami', 'William F Raynolds'],
#  ['Marina Catallozzi', 'Stephanie A Grilo'],
#  ['Cassie Landers', 'Renata Schiavo'],
#  ['Linda F Cushman', 'Chelsea A Kolff'],
#  ['Theresa McGovern', 'Chelsea A Kolff'],
#  ['Natasha H Chriss', 'Judith E Mars'],
#  ['William C Tomlinson', 'Judith E Mars'],
#  ['Pamela Meersand', 'Judith E Mars'],
#  ['Holly A Schneier', 'Judith E Mars'],
#  ['Judith E Mars', 'Peter M Bookstein'],
#  ['Edward T Kenny', 'Judith E Mars'],
#  ['Larry Sandberg', 'Judith E Mars', 'Fredric Busch'],
#  ['Dionne R Powell', 'Judith E Mars'],
#  ['Robert A Glick', 'Gloria J Stern', 'Judith E Mars'],
#  ['Judith E Mars', 'Holly A Schneier'],
#  ['Holly A Schneier', 'Judith E Mars'],
#  ['Alison Brown', 'Judith E Mars'],
#  ['Fredric Busch', 'Judith E Mars'],
#  ['Ken Light', 'Peter D Balsam'],
#  ['Ken Light', 'Peter D Balsam'],
#  ['Ken Light', 'Peter D Balsam'],
#  ['Ari Shechter', 'Robert E Remez'],
#  ['Ari Shechter', 'Robert E Remez'],
#  ['Robert Brotherton', 'Tara Well'],
#  ['Robert Brotherton', 'Tara Well'],
#  ['Steven Stroessner', 'Katherine Thorson'],
#  ['Steven Stroessner', 'Katherine Thorson'],
#  ['Steven Stroessner', 'Manuel F Gonzalez'],
#  ['Christian G Habeck', 'Victoria Leavitt'],
#  ['Christopher Baldassano', 'Agnes Chang'],
#  ['Caroline B Marvin', 'Katherine T Fox-Glassman'],
#  ['Michael Johson', 'Christopher K Wong', 'Debra Krasinski'],
#  ['Christopher J Loso', 'Robert Boccio'],
#  ['James K Colgrove', 'Lauren A Westley'],
#  ['James K Colgrove', 'Lauren A Westley'],
#  ['James K Colgrove', 'Lauren A Westley'],
#  ['James K Colgrove', 'Lauren A Westley'],
#  ['Helen de Pinho', 'Marlyn M Delva'],
#  ['Dana March', 'Lauren A Westley'],
#  ['Dana March', 'Lauren A Westley'],
#  ['Dana March', 'Lauren A Westley'],
#  ['Dana March', 'Lauren A Westley'],
#  ['Greg A Freyer', 'Lauren A Westley'],
#  ['Greg A Freyer', 'Lauren A Westley'],
#  ['Greg A Freyer', 'Lauren A Westley'],
#  ['Greg A Freyer', 'Lauren A Westley'],
#  ['Samantha V Garbers', 'Lauren A Westley'],
#  ['Samantha V Garbers', 'Lauren A Westley'],
#  ['Samantha V Garbers', 'Lauren A Westley'],
#  ['Samantha V Garbers', 'Lauren A Westley'],
#  ['Helen de Pinho', 'Lauren A Westley'],
#  ['Helen de Pinho', 'Lauren A Westley'],
#  ['Helen de Pinho', 'Lauren A Westley'],
#  ['Helen de Pinho', 'Lauren A Westley'],
#  ['Michael S Sparer', 'Lauren A Westley'],
#  ['Michael S Sparer', 'Lauren A Westley'],
#  ['Michael S Sparer', 'Lauren A Westley'],
#  ['Michael S Sparer', 'Lauren A Westley'],
#  ['John Santelli', 'Lauren A Westley'],
#  ['John Santelli', 'Lauren A Westley'],
#  ['Matthew Perzanowski', 'Lauren A Westley'],
#  ['Leslie L Davidson', 'Lauren A Westley'],
#  ['Sara Abiola', 'Lauren A Westley'],
#  ['Darby W Jack', 'Lauren A Westley'],
#  ['Anne Paxton', 'Lauren A Westley'],
#  ['Matthew R Lamb', 'Lauren A Westley'],
#  ['Patrick A Wilson', 'Lauren A Westley'],
#  ['Thelma Mielenz', 'Lauren A Westley'],
#  ['Matthew Perzanowski', 'Lauren A Westley'],
#  ['Bill L Bower', 'Lauren A Westley'],
#  ['Julie Kornfeld', 'Lauren A Westley'],
#  ['Patrick A Wilson', 'Lauren A Westley'],
#  ['Lisa Bates', 'Lauren A Westley'],
#  ['Greg A Freyer', 'Lauren A Westley'],
#  ['Helen de Pinho', 'Lauren A Westley'],
#  ['Andrew G Rundle', 'Lauren A Westley'],
#  ['Heather M Butts', 'Lauren A Westley'],
#  ['Brandon Pearson', 'Lauren A Westley'],
#  ['John Santelli', 'Lauren A Westley'],
#  ['John Santelli', 'Lauren A Westley'],
#  ['Matthew Perzanowski', 'Lauren A Westley'],
#  ['Helen de Pinho', 'Lauren A Westley'],
#  ['Daniel Rosen', 'Bartly Carfagno'],
#  ['Rachel McDermott', 'John S Hawley'],
#  ['Lillian Morales', 'Carlos Correa'],
#  ['Lillian Morales', 'Carlos Correa'],
#  ['Ellen Morris', 'Paige West'],
#  ['Ellen Morris', 'Paige West'],
#  ['Connie Thanasoulis', 'Kenneth A Lawson'],
#  ['Marina A Metalios', 'Kenneth A Lawson'],
#  ['Sharon Small', 'Kenneth A Lawson'],
#  ['Patricia Samwick', 'Kenneth A Lawson'],
#  ['Mario Fernandez', 'Kenneth A Lawson'],
#  ['Holly White', 'Kenneth A Lawson'],
#  ['Connie Thanasoulis', 'Kenneth A Lawson'],
#  ['Holly White', 'Kenneth A Lawson'],
#  ['Sadaf G Sajwani', 'Kenneth A Lawson'],
#  ['Patricia Samwick', 'Kenneth A Lawson'],
#  ['Sharon Small', 'Kenneth A Lawson'],
#  ['Caroline C Ceniza-Levine', 'Kenneth A Lawson'],
#  ['Joanne L Heyman', 'Kenneth A Lawson'],
#  ['Sadaf G Sajwani', 'Kenneth A Lawson'],
#  ['Regina Angeles', 'Kenneth A Lawson'],
#  ['Joanne L Heyman', 'Kenneth A Lawson'],
#  ['Meg Heenehan', 'Kenneth A Lawson'],
#  ['Christina Ercole', 'Bader O Akacem'],
#  ['Christina Ercole', 'Bader O Akacem'],
#  ['Christina Ercole', 'Bader O Akacem'],
#  ['David J Helfand', 'Statia H Luszcz-Cook'],
#  ['Desmond Patton', 'Jaclyn M Sawyer', 'Courtney Cogburn'],
#  ['Yesika Montoya', 'Moira G Curtain', 'Monica A Joseph', 'Herbert Hugh'],
#  ['Yesika Montoya', 'Moira G Curtain', 'Monica A Joseph', 'Herbert Hugh'],
#  ['Faculty', 'Brittany K Larson'],
#  ['Armin Richard J Baier', 'Barbara A Feldmann'],
#  ['Todd Gitlin', 'Robert P Wolff'],
#  ['Shamus Khan', 'Tey Meadow'],
#  ['Shamus Khan', 'Peter Bearman'],
#  ['Peter Bearman', 'Shamus Khan'],
#  ['Andrea Constancio', 'Lillian Morales', 'Marita Murrman'],
#  ['Ronald Bayer', 'Andrea Constancio'],
#  ['David Rosner', 'Andrea Constancio'],
#  ['Adam Raiken', 'Robert Gerbe'],
#  ['Ronald Neath', 'Banu Baydil'],
#  ['Marco Avella', 'Linxi Liu', 'Thibault Vatter'],
#  ['Sumit Mukherjee', 'Victor H de la Pena'],
#  ['Marcel F Nutz', 'Philip Protter'],
#  ['Roman Nowygrod', 'Doris T Leddy'],
#  ['Roman Nowygrod', 'Doris T Leddy'],
#  ['Roman Nowygrod', 'Doris T Leddy'],
#  ['Roman Nowygrod', 'Doris T Leddy'],
#  ['John C Mutter', 'Sonali Deraniyagala'],
#  ['Douglas V Almond', 'John C Mutter'],
#  ['Julia L Brickell', 'Marilyn J Kunstler', 'Paul Lucido'],
#  ['Michael Passaro', 'Jack Rouse'],
#  ['Anne Bogart', 'John Dias', 'David H Hwang'],
#  ['Brian Kulick', 'Anne Bogart'],
#  ['Christopher G Burney', 'Susan Frost'],
#  ['Marcela Tovar', 'Pauline Claramunt Torche', 'Aline F Estefam'],
#  ['Gina M Badalato', 'Laura Vargas'],
#  ['Gina M Badalato', 'Laura Vargas'],
#  ['Gina M Badalato', 'Laura Vargas'],
#  ['Gina M Badalato', 'Laura Vargas'],
#  ['Manijeh Moradian', 'Jack Halberstam'],
#  ['Alexander Pittman', 'Kaegan A Sparks']]
