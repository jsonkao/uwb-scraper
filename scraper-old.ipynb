# %%
from collections import defaultdict
from bs4 import BeautifulSoup, Tag
import pandas as pd
import requests
import re

BASE_URL = 'http://www.columbia.edu'

# %%
def subjUrl(letter):
    return BASE_URL + '/cu/bulletin/uwb/sel/subj-{}.html'.format(letter)

def getSubjects(letter):
    r = requests.get(subjUrl(letter))
    r.raise_for_status()
    soup = BeautifulSoup(r.text, 'lxml')
    table = soup.table
    rows = table.find_all('tr')[3:-2]
    return rows

# %%
paths = []
for c in range(65, 91):
    rows = getSubjects(chr(c))
    for row in rows:
        anchors = row.findAll('a')
        for a in anchors:
            href = a['href']
            if 'subj/AU' in href: # auditing
                break
            if '__' in href: # seemingly invalid subjects
                continue
            if 'Fall2019' not in href:
                continue
            paths.append(href)

# %%
subjPattern = re.compile('subj\/(\w{4})')

def getSubjectFromPath(p):
    matches = subjPattern.findall(p)
    if len(matches) == 0:
        return None
    return matches[0]

# %%
def parseForSection(contents):   
    components = contents[2].contents 
    section = {
         'number': contents[0].a.string.replace('Section ', ''),
    }
    header = None
    for component in components:
        if header is not None:
            text = component.strip()
            try:
                text = int(text)
            except ValueError:
                pass # This is expected since not all values are integers (e.g. instructor names)
            section[header] = text
            header = None
        if isinstance(component, Tag) and component.name == 'b':
            header = component.string.replace(':', '').strip()
    return section

def getCoursesFromPath(p):
    r = requests.get(BASE_URL + p)
    r.raise_for_status()
    soup = BeautifulSoup(r.text, 'lxml')
    subject = getSubjectFromPath(p)
    course = None
    courses = []
    for tr in soup.table.find_all('tr')[2:-1]:
        if tr.td.get('colspan') is not None:        
            course = tr.td.b.contents[-1]
            continue
        section = parseForSection(tr.contents)
        section['course'] = course
        section['subject'] = subject
        courses.append(section)
    return courses

# %%
[c for c in courses if c['subject'].find('A') != 0]
# Out:
# [{'number': '083',
#   'Call Number': 14995,
#   'Points': 0,
#   'Enrollment': '99 students as of August 31, 2019',
#   'Instructor': 'Julie A Connolly',
#   'course': 'ETHICS',
#   'subject': 'BHSC'},
#  {'number': '083',
#   'Call Number': 14996,
#   'Points': 0,
#   'Enrollment': '98 students as of August 31, 2019',
#   'Instructor': 'Aaron G Myers',
#   'course': 'SPECIAL NEEDS ROTATION PEDIATRICS',
#   'subject': 'BHSC'},
#  {'number': '084',
#   'Call Number': 14968,
#   'Points': 0,
#   'Enrollment': '91 students as of August 31, 2019',
#   'Instructor': 'Gregory N Bunza',
#   'course': 'SPECIAL NEEDS ROTATION',
#   'subject': 'BHSC'},
#  {'number': '001',
#   'Call Number': 55365,
#   'Points': 4,
#   'Day/Time': 'TR 4:10pm-6:00pm',
#   'Location': '255 International Affairs Building',
#   'Enrollment': '8 students (20 max) as of August 31, 2019',
#   'Instructor': 'Dwijen Bhattacharjya',
#   'course': 'ELEMENTARY BENGALI I',
#   'subject': 'BENG'},
#  {'number': '001',
#   'Call Number': 55400,
#   'Points': 4,
#   'Day/Time': 'TR 6:10pm-8:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '5 students (20 max) as of August 31, 2019',
#   'Instructor': 'Dwijen Bhattacharjya',
#   'course': 'INTERMEDIATE BENGALI I',
#   'subject': 'BENG'},
#  {'number': '001',
#   'Call Number': 15347,
#   'Points': '15.5',
#   'Enrollment': '0 students as of August 31, 2019',
#   'course': 'FULL-TIME BERL CONSORTIUM PROG',
#   'subject': 'BERL'},
#  {'number': '001',
#   'Call Number': 52847,
#   'Points': 3,
#   'Day/Time': 'T 7:10pm-9:30pm',
#   'Location': '833 Seeley W. Mudd Building',
#   'Enrollment': '107 students (110 max) as of August 31, 2019',
#   'Notes': 'Prereq: 1 yr Intro Bio and G. Chem, 1 sem O. Chem',
#   'Instructor': 'Danny N Ho',
#   'course': 'BIOCHEMISTRY',
#   'subject': 'BCHM'},
#  {'number': '001',
#   'Call Number': 52816,
#   'Points': 4,
#   'Day/Time': 'TR 2:40pm-3:55pm',
#   'Location': '209 Havemeyer Hall',
#   'Enrollment': '102 students (100 max) as of August 31, 2019 / Full',
#   'Notes': 'Join waitlist to register. Required recitation BIOL UN3511',
#   'Instructor': 'Brent R Stockwell',
#   'course': 'BIOCHEM I-STRUCTURE/METABOLISM',
#   'subject': 'BCHM'},
#  {'number': '001',
#   'Call Number': 52795,
#   'Points': 0,
#   'Day/Time': 'M 4:30pm-5:30pm',
#   'Location': '1000 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '18 students (30 max) as of August 31, 2019',
#   'Instructor': 'Aubrianna M Decker',
#   'course': 'BIOCHEM I-STRUCT/METABOLSM-REC',
#   'subject': 'BCHM'},
#  {'number': '002',
#   'Call Number': 52796,
#   'Points': 0,
#   'Day/Time': 'M 5:45pm-6:45pm',
#   'Location': '1000 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '7 students (30 max) as of August 31, 2019',
#   'Instructor': 'Lauren C Tang',
#   'course': 'BIOCHEM I-STRUCT/METABOLSM-REC',
#   'subject': 'BCHM'},
#  {'number': '003',
#   'Call Number': 52797,
#   'Points': 0,
#   'Day/Time': 'T 4:30pm-5:30pm',
#   'Location': '1000 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '21 students (30 max) as of August 31, 2019',
#   'Instructor': 'Alfred N von Krusenstiern',
#   'course': 'BIOCHEM I-STRUCT/METABOLSM-REC',
#   'subject': 'BCHM'},
#  {'number': '004',
#   'Call Number': 52798,
#   'Points': 0,
#   'Day/Time': 'W 4:30pm-5:30pm',
#   'Location': '1000 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '14 students (30 max) as of August 31, 2019',
#   'Instructor': 'Hui Tan',
#   'course': 'BIOCHEM I-STRUCT/METABOLSM-REC',
#   'subject': 'BCHM'},
#  {'number': '001',
#   'Call Number': 17744,
#   'Points': '4.5',
#   'Enrollment': '2 students as of August 31, 2019',
#   'Notes': 'VEC 701A',
#   'Instructor': 'Arthur Palmer',
#   'course': 'MOLECULAR BIOPHYSICS',
#   'subject': 'BCHM'},
#  {'number': '001',
#   'Call Number': 52800,
#   'Points': 4,
#   'Day/Time': 'TR 1:10pm-2:25pm',
#   'Location': '320 Havemeyer Hall',
#   'Enrollment': '9 students (39 max) as of August 31, 2019',
#   'Instructors': 'John Hunt and Arthur Palmer',
#   'course': 'BIOPHYSICAL CHEMISTRY I',
#   'subject': 'BCHM'},
#  {'number': '001',
#   'Call Number': 52801,
#   'Points': 4,
#   'Day/Time': 'TR 2:40pm-3:55pm',
#   'Location': 'C01 80 Claremont Ave',
#   'Enrollment': '5 students (20 max) as of August 31, 2019',
#   'Notes': 'Join waitlist to register. Required recitation BIOL UN3511',
#   'Instructor': 'Brent R Stockwell',
#   'course': 'BIOCHEM I-STRUCTURE/METABOLISM',
#   'subject': 'BCHM'},
#  {'number': '001',
#   'Call Number': 14225,
#   'Points': '4.5',
#   'Day/Time': 'MW 3:00pm-5:00pm',
#   'Location': '1202 Vagelos Educ',
#   'Enrollment': '34 students as of August 31, 2019',
#   'Instructor': 'Stavros Lomvardas',
#   'course': 'BIOCHEM/MOLECULAR/CELL BIOL I',
#   'subject': 'BCHM'},
#  {'number': 'D01',
#   'Call Number': 29484,
#   'Points': 3,
#   'Day/Time': 'W 4:30pm-6:00pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '16 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. BIOETHICS & NURSING ONLY; OTHERS REQ APPROVL',
#   'Instructor': 'Jennifer M Gumer',
#   'course': 'SCIENCE FOR BIOETHICISTS',
#   'subject': 'BIET'},
#  {'number': 'D02',
#   'Call Number': 29483,
#   'Points': 3,
#   'Day/Time': 'W 4:30pm-6:00pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '4 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. NON-CREDIT BIOETHICS ONLY; OTHERS REQ APPROVL',
#   'Instructor': 'Jennifer M Gumer',
#   'course': 'SCIENCE FOR BIOETHICISTS',
#   'subject': 'BIET'},
#  {'number': '001',
#   'Call Number': 29492,
#   'Points': 3,
#   'Day/Time': 'R 12:10pm-2:40pm',
#   'Location': '602 Lewisohn Hall',
#   'Enrollment': '25 students (25 max) as of August 31, 2019 / Full',
#   'Notes': 'BIOETHICS & NURSING ONLY; OTHERS REQ APPROVAL',
#   'Instructor': 'Arthur Kuflik',
#   'course': 'PHILOSOPHY OF BIOETHICS',
#   'subject': 'BIET'},
#  {'number': '003',
#   'Call Number': 17927,
#   'Points': 3,
#   'Day/Time': 'T 12:10pm-2:40pm',
#   'Location': '212A Lewisohn Hall',
#   'Enrollment': '7 students (20 max) as of August 31, 2019',
#   'Notes': 'BIOETHICS STUDENTS ONLY',
#   'Instructor': 'Arthur Kuflik',
#   'course': 'PHILOSOPHY OF BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'D02',
#   'Call Number': 29491,
#   'Points': 3,
#   'Day/Time': 'W 6:10pm-8:00pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '25 students (25 max) as of August 31, 2019 / Full',
#   'Notes': 'MEETS ONLINE. BIOETHICS & NURSING ONLY; OTHERS REQ APPROVL',
#   'Instructor': 'Arthur Kuflik',
#   'course': 'PHILOSOPHY OF BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'D04',
#   'Call Number': 29489,
#   'Points': 3,
#   'Day/Time': 'M 7:30pm-9:30pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '25 students (25 max) as of August 31, 2019 / Full',
#   'Notes': 'MEETS ONLINE. BIOETHICS & NURSING ONLY; OTHERS REQ APPROVL',
#   'Instructor': 'Jennifer M Gumer',
#   'course': 'PHILOSOPHY OF BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'D07',
#   'Call Number': 29487,
#   'Points': 3,
#   'Day/Time': 'M 9:30am-11:30am',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '11 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. BIOETHICS & NURSING ONLY; OTHERS REQ APPROVL',
#   'Instructor': 'Arthur Kuflik',
#   'course': 'PHILOSOPHY OF BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'H06',
#   'Call Number': 29486,
#   'Points': 3,
#   'Enrollment': '1 student (25 max) as of August 31, 2019',
#   'Notes': 'MEETS FOR 2 MODULES SAN FRANCISCO THEN ONLINE',
#   'Instructor': 'Arthur Kuflik',
#   'course': 'PHILOSOPHY OF BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'D01',
#   'Call Number': 29471,
#   'Points': 3,
#   'Day/Time': 'T 8:10pm-10:00pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '25 students (25 max) as of August 31, 2019 / Full',
#   'Notes': 'MEETS ONLINE',
#   'Instructor': 'David N Hoffman',
#   'course': 'LAW & BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'D02',
#   'Call Number': 10346,
#   'Points': 0,
#   'Day/Time': 'T 8:10pm-10:00pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '4 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. NON-CREDIT BIOETHICS ONLY; OTHERS REQ APPROVL',
#   'course': 'LAW & BIOETHICS',
#   'subject': 'BIET'},
#  {'number': '001',
#   'Call Number': 10348,
#   'Points': 3,
#   'Day/Time': 'M 5:10pm-7:00pm',
#   'Location': '308A Lewisohn Hall',
#   'Enrollment': '7 students (25 max) as of August 31, 2019',
#   'Notes': 'BIOETHICS STUDENTS ONLY; OTHERS REQ APPROVAL',
#   'Instructor': 'Linda S Golding',
#   'course': 'PASTORAL CARE & ETHICS',
#   'subject': 'BIET'},
#  {'number': 'D01',
#   'Call Number': 29482,
#   'Points': 3,
#   'Day/Time': 'T 9:00am-10:30am',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '23 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. BIOETHICS & NURSING ONLY; OTHERS REQ APPROVL',
#   'Instructor': 'Barbra Rothschild',
#   'course': 'INTRO TO CLINICAL ETHICS',
#   'subject': 'BIET'},
#  {'number': 'D02',
#   'Call Number': 29481,
#   'Points': 0,
#   'Day/Time': 'T 9:00am-10:30am',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '0 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. NON-CREDIT BIOETHICS ONLY; OTHERS REQ APPROVL',
#   'Instructor': 'Barbra Rothschild',
#   'course': 'INTRO TO CLINICAL ETHICS',
#   'subject': 'BIET'},
#  {'number': 'D01',
#   'Call Number': 29470,
#   'Points': 3,
#   'Day/Time': 'R 8:10pm-10:00pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '21 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. BIOETHICS STUDENTS ONLY; OTHERS REQ APPROVAL',
#   'Instructor': 'David N Hoffman',
#   'course': 'ORGANIZATIONAL ETHICS AND COMPLIANCE',
#   'subject': 'BIET'},
#  {'number': '001',
#   'Call Number': 29480,
#   'Points': 3,
#   'Day/Time': 'R 4:10pm-6:00pm',
#   'Location': '103 Knox Hall',
#   'Enrollment': '14 students (25 max) as of August 31, 2019',
#   'Notes': 'BIOETHICS STUDENTS ONLY; OTHERS REQ APPROVAL',
#   'Instructor': 'Robert L Klitzman',
#   'course': 'RESEARCH ETHICS',
#   'subject': 'BIET'},
#  {'number': '002',
#   'Call Number': 29479,
#   'Points': 1,
#   'Day/Time': 'W 4:10pm-6:00pm',
#   'Location': '602 Lewisohn Hall',
#   'Enrollment': '13 students (25 max) as of August 31, 2019',
#   'Notes': 'LATER YEAR BIO PHD STUDENTS ONLY (MEETS LAST 5 WEEKS)',
#   'Instructor': 'Joel Roselin',
#   'course': 'RESEARCH ETHICS',
#   'subject': 'BIET'},
#  {'number': '003',
#   'Call Number': 29478,
#   'Points': 2,
#   'Day/Time': 'W 4:10pm-6:00pm',
#   'Location': '602 Lewisohn Hall',
#   'Enrollment': '20 students (25 max) as of August 31, 2019',
#   'Notes': '1ST YEAR PHD STUDENTS ONLY (MEETS FIRST 8 WEEKS)',
#   'Instructor': 'Joel Roselin',
#   'course': 'RESEARCH ETHICS',
#   'subject': 'BIET'},
#  {'number': 'D04',
#   'Call Number': 29477,
#   'Points': 3,
#   'Day/Time': 'T 6:15pm-7:45pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '23 students (25 max) as of August 31, 2019',
#   'Instructor': 'Robert L Klitzman',
#   'course': 'RESEARCH ETHICS',
#   'subject': 'BIET'},
#  {'number': 'D05',
#   'Call Number': 29476,
#   'Points': 0,
#   'Day/Time': 'T 6:15pm-7:45pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '2 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. NON-CREDIT BIOETHICS ONLY; OTHERS REQ APPROVL',
#   'Instructor': 'Robert L Klitzman',
#   'course': 'RESEARCH ETHICS',
#   'subject': 'BIET'},
#  {'number': 'H06',
#   'Call Number': 29475,
#   'Points': 3,
#   'Enrollment': '1 student (25 max) as of August 31, 2019',
#   'Notes': 'MEETS FOR 2 MODULES SAN FRANCISCO THEN ONLINE',
#   'Instructor': 'Robert L Klitzman',
#   'course': 'RESEARCH ETHICS',
#   'subject': 'BIET'},
#  {'number': '001',
#   'Call Number': 29473,
#   'Points': 3,
#   'Day/Time': 'M 12:10pm-2:00pm',
#   'Location': '602 Lewisohn Hall',
#   'Enrollment': '14 students (25 max) as of August 31, 2019',
#   'Notes': 'BIOETHICS STUDENTS ONLY; OTHERS REQ APPROVAL',
#   'Instructor': 'Jonathan Engel',
#   'course': 'HEALTH POLICY & BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'D01',
#   'Call Number': 10349,
#   'Points': 3,
#   'Day/Time': 'M 4:10pm-6:00pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '26 students (25 max) as of August 31, 2019 / Full',
#   'Notes': 'MEETS ONLINE. NURSING STUDENTS ONLY; OTHERS REQ APPROVAL',
#   'Instructor': 'David N Hoffman',
#   'course': 'CLINICAL ETHICS: END OF LIFE CARE',
#   'subject': 'BIET'},
#  {'number': 'D01',
#   'Call Number': 15194,
#   'Points': 3,
#   'Day/Time': 'W 8:30pm-10:00pm',
#   'Location': '424 Kent Hall',
#   'Enrollment': '12 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. BIOETHICS STUDENTS ONLY; OTHERS REQ APPROVAL',
#   'Instructor': 'Harriet A Washington',
#   'course': 'JOURNALISM & BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'H02',
#   'Call Number': 15195,
#   'Points': 3,
#   'Enrollment': '4 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS FOR 2 MODULES SAN FRANCISCO THEN ONLINE',
#   'Instructor': 'Harriet A Washington',
#   'course': 'JOURNALISM & BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'D01',
#   'Call Number': 29468,
#   'Points': 3,
#   'Day/Time': 'F 10:00am-11:30am',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '16 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. BIOETHICS STUDENTS ONLY; OTHERS REQ APPROVAL',
#   'Instructor': 'Jennifer P Cohen',
#   'course': 'RELIGION & BIOETHICS',
#   'subject': 'BIET'},
#  {'number': 'D01',
#   'Call Number': 29466,
#   'Points': 1,
#   'Day/Time': 'F 12:30pm-2:30pm',
#   'Location': 'ONLINE ONLY',
#   'Enrollment': '7 students (25 max) as of August 31, 2019',
#   'Notes': 'MEETS ONLINE. FOR BIOETHICS STUDENTS ONLY; TAKE WITH PS5992',
#   'Instructor': 'Arthur Kuflik',
#   'course': 'MASTER THESIS WORKSHOP',
#   'subject': 'BIET'},
#  {'number': '001',
#   'Call Number': 29474,
#   'Points': 2,
#   'Enrollment': '9 students (25 max) as of August 31, 2019',
#   'Notes': 'ONLY BIET STUDENTS REGD OR TAKEN 5991, OTHERS REG 5993',
#   'Instructor': 'Sameer H Ladha',
#   'course': 'MASTER THESIS (2 CREDIT)',
#   'subject': 'BIET'},
#  {'number': '001',
#   'Call Number': 29485,
#   'Points': 3,
#   'Enrollment': '5 students (25 max) as of August 31, 2019',
#   'Notes': 'BIOETHICS STUDENTS ONLY IF NOT TAKING BIET PS5991 & PS5992',
#   'Instructor': 'Sameer H Ladha',
#   'course': 'MASTER THESIS (3 CREDIT)',
#   'subject': 'BIET'},
#  {'number': '001',
#   'Call Number': 29472,
#   'Points': 3,
#   'Enrollment': '0 students (25 max) as of August 31, 2019',
#   'Notes': "COURSE REQUIRES PROGRAM DIRECTOR'S PERMISSION",
#   'Instructor': 'Robert L Klitzman',
#   'course': 'CLINICAL ETHICS PRACTICUM',
#   'subject': 'BIET'},
#  {'number': '001',
#   'Call Number': 29493,
#   'Points': '1-6',
#   'Enrollment': '1 student (25 max) as of August 31, 2019',
#   'Notes': "COURSE REQUIRES PROGRAM DIRECTOR'S PERMISSION",
#   'Instructor': 'Sameer H Ladha',
#   'course': 'INDEPENDENT STUDY',
#   'subject': 'BIET'},
#  {'number': '001',
#   'Call Number': 7289,
#   'Points': '4.5',
#   'Day/Time': 'TR 10:10am-11:25am',
#   'Location': '805 Altschul Hall (Barnard)',
#   'Enrollment': '35 students as of August 31, 2019',
#   'Notes': 'BIOL BC1012 lab is a required co-requisite.',
#   'Instructor': 'Diana L Heller',
#   'course': 'GLOBAL HEALTH AND ECOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7291,
#   'Points': 0,
#   'Day/Time': 'M 1:10pm-4:00pm',
#   'Location': '907 Altschul Hall (Barnard)',
#   'Enrollment': '6 students (16 max) as of August 31, 2019',
#   'Notes': 'Must also be enrolled in BIOL BC1002.',
#   'Instructors': 'Diana L Heller and Henry Truong',
#   'course': 'BIOL BC 1002 LAB',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 7292,
#   'Points': 0,
#   'Day/Time': 'T 1:10pm-4:00pm',
#   'Location': '907 Altschul Hall (Barnard)',
#   'Enrollment': '14 students (16 max) as of August 31, 2019',
#   'Notes': 'Must also be enrolled in BIOL BC1002.',
#   'Instructors': 'Diana L Heller and Henry Truong',
#   'course': 'BIOL BC 1002 LAB',
#   'subject': 'BIOL'},
#  {'number': '003',
#   'Call Number': 7293,
#   'Points': 0,
#   'Day/Time': 'F 10:00am-12:50pm',
#   'Location': '907 Altschul Hall (Barnard)',
#   'Enrollment': '11 students (16 max) as of August 31, 2019',
#   'Notes': 'Must also be enrolled in BIOL BC1002.',
#   'Instructors': 'Diana L Heller and Henry Truong',
#   'course': 'BIOL BC 1002 LAB',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7268,
#   'Points': 3,
#   'Day/Time': 'MWF 9:00am-9:50am',
#   'Location': '304 Barnard Hall',
#   'Enrollment': '235 students (245 max) as of August 31, 2019',
#   'Notes': 'This is a co-/pre-requisite for BIOL BC1501 & BIOL BC1511.',
#   'Instructors': 'Paul E Hertz and James P Casey',
#   'course': 'INTRO ORGANISMAL/EVOL BIOL',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7250,
#   'Points': 2,
#   'Day/Time': 'M 1:10pm-4:00pm',
#   'Location': '912 Altschul Hall (Barnard)',
#   'Enrollment': '13 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 7251,
#   'Points': 2,
#   'Day/Time': 'M 1:10pm-4:00pm',
#   'Location': '913 Altschul Hall (Barnard)',
#   'Enrollment': '15 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '003',
#   'Call Number': 7252,
#   'Points': 2,
#   'Day/Time': 'T 9:00am-11:50am',
#   'Location': '912 Altschul Hall (Barnard)',
#   'Enrollment': '16 students (16 max) as of August 31, 2019 / Full',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '004',
#   'Call Number': 7253,
#   'Points': 2,
#   'Day/Time': 'T 9:00am-11:50am',
#   'Location': '913 Altschul Hall (Barnard)',
#   'Enrollment': '14 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '005',
#   'Call Number': 7254,
#   'Points': 2,
#   'Day/Time': 'T 1:10pm-4:00pm',
#   'Location': '912 Altschul Hall (Barnard)',
#   'Enrollment': '15 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '006',
#   'Call Number': 7255,
#   'Points': 2,
#   'Day/Time': 'T 1:10pm-4:00pm',
#   'Location': '913 Altschul Hall (Barnard)',
#   'Enrollment': '16 students (16 max) as of August 31, 2019 / Full',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '007',
#   'Call Number': 7256,
#   'Points': 2,
#   'Day/Time': 'W 10:00am-12:50pm',
#   'Location': '912 Altschul Hall (Barnard)',
#   'Enrollment': '14 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '008',
#   'Call Number': 7257,
#   'Points': 2,
#   'Day/Time': 'W 10:00am-12:50pm',
#   'Location': '913 Altschul Hall (Barnard)',
#   'Enrollment': '13 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '009',
#   'Call Number': 7258,
#   'Points': 2,
#   'Day/Time': 'W 2:10pm-5:00pm',
#   'Location': '913 Altschul Hall (Barnard)',
#   'Enrollment': '11 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '010',
#   'Call Number': 7259,
#   'Points': 2,
#   'Day/Time': 'R 1:10pm-4:00pm',
#   'Location': '912 Altschul Hall (Barnard)',
#   'Enrollment': '12 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '011',
#   'Call Number': 7260,
#   'Points': 2,
#   'Day/Time': 'R 1:10pm-4:00pm',
#   'Location': '913 Altschul Hall (Barnard)',
#   'Enrollment': '11 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '012',
#   'Call Number': 7261,
#   'Points': 2,
#   'Day/Time': 'F 10:00am-12:50pm',
#   'Location': '912 Altschul Hall (Barnard)',
#   'Enrollment': '15 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '013',
#   'Call Number': 7262,
#   'Points': 2,
#   'Day/Time': 'F 10:00am-12:50pm',
#   'Location': '913 Altschul Hall (Barnard)',
#   'Enrollment': '9 students (16 max) as of August 31, 2019',
#   'Notes': 'Enrollment in BIOL BC1511 required; must attend first lab.',
#   'Instructors': 'Jessica Goldstein and James P Casey',
#   'course': 'INTRO LAB/ORGANISMAL&EVOL BIO',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7269,
#   'Points': 0,
#   'Day/Time': 'M 10:00am-10:50am',
#   'Location': '304 Barnard Hall',
#   'Enrollment': '88 students as of August 31, 2019',
#   'Notes': 'This recitation is a co-requisite for BIOL BC1501 lab.',
#   'Instructor': 'Jessica Goldstein',
#   'course': 'BIOL BC1501 RECITATION',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 7270,
#   'Points': 0,
#   'Day/Time': 'F 1:10pm-2:00pm',
#   'Location': '304 Barnard Hall',
#   'Enrollment': '79 students as of August 31, 2019',
#   'Notes': 'This recitation is a co-requisite for BIOL BC1501 lab.',
#   'Instructor': 'Jessica Goldstein',
#   'course': 'BIOL BC1501 RECITATION',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7271,
#   'Points': 1,
#   'Day/Time': 'M 12:00pm-1:00pm',
#   'Location': 'LL016 MILSTEIN CEN',
#   'Enrollment': '0 students (16 max) as of August 31, 2019 / Full',
#   'Notes': 'Limited to students in Science Pathways Scholars Program.',
#   'Instructor': 'Paul E Hertz',
#   'course': 'SCIENCE JOURNAL CLUB',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52844,
#   'Points': 1,
#   'Day/Time': 'W 2:40pm-3:40pm',
#   'Location': '601 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '45 students (70 max) as of August 31, 2019 / Full',
#   'Notes': 'Join waitlist to register',
#   'Instructor': 'Alice Heicklen',
#   'course': '1ST YEAR SEM IN MODERN BIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52817,
#   'Points': 4,
#   'Day/Time': 'TR 10:10am-11:25am',
#   'Location': '417 International Affairs Building',
#   'Enrollment': '175 students (400 max) as of August 31, 2019',
#   'Notes': 'STUDENTS MUST REGISTER FOR RECITATION SECTION: BIOL UN2015',
#   'Instructors': 'Deborah Mowshowitz and Lawrence A Chasin and Marko Jovanovic',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 52818,
#   'Points': 4,
#   'Day/Time': 'TR 4:10pm-5:25pm',
#   'Location': '309 Havemeyer Hall',
#   'Enrollment': '107 students (200 max) as of August 31, 2019',
#   'Notes': 'STUDENTS MUST REGISTER FOR RECITATION SECTION: BIOL UN2015',
#   'Instructors': 'Deborah Mowshowitz and Lawrence A Chasin and Marko Jovanovic',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52819,
#   'Points': 0,
#   'Day/Time': 'M 6:10pm-8:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '15 students (30 max) as of August 31, 2019',
#   'Notes': 'This is a recitation for BIOL UN2005 (Intro Bio I).',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 52820,
#   'Points': 0,
#   'Day/Time': 'M 6:10pm-8:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '0 students (30 max) as of August 31, 2019',
#   'Notes': 'This is a recitation for BIOL UN2005 (Intro Bio I).',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '003',
#   'Call Number': 52821,
#   'Points': 0,
#   'Day/Time': 'T 12:10pm-2:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '17 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '004',
#   'Call Number': 52822,
#   'Points': 0,
#   'Day/Time': 'T 12:10pm-2:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '4 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '005',
#   'Call Number': 52823,
#   'Points': 0,
#   'Day/Time': 'T 6:10pm-8:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '23 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '006',
#   'Call Number': 52824,
#   'Points': 0,
#   'Day/Time': 'T 6:10pm-8:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '4 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '007',
#   'Call Number': 52825,
#   'Points': 0,
#   'Day/Time': 'W 12:10pm-2:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '17 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '008',
#   'Call Number': 52826,
#   'Points': 0,
#   'Day/Time': 'W 12:10pm-2:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '3 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '009',
#   'Call Number': 52827,
#   'Points': 0,
#   'Day/Time': 'W 2:10pm-4:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '13 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '010',
#   'Call Number': 52828,
#   'Points': 0,
#   'Day/Time': 'W 2:10pm-4:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '4 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '011',
#   'Call Number': 52829,
#   'Points': 0,
#   'Day/Time': 'W 4:10pm-6:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '27 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '012',
#   'Call Number': 52830,
#   'Points': 0,
#   'Day/Time': 'W 4:10pm-6:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '1 student (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '013',
#   'Call Number': 52831,
#   'Points': 0,
#   'Day/Time': 'W 8:10pm-10:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '7 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '014',
#   'Call Number': 52832,
#   'Points': 0,
#   'Day/Time': 'R 12:10pm-2:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '21 students (30 max) as of August 31, 2019',
#   'Instructor': 'Jan Hammerquist',
#   'course': 'INTRO BIO I: BIOCHEM,GEN,MOLEC',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7286,
#   'Points': 3,
#   'Day/Time': 'TR 10:10am-11:25am',
#   'Location': 'LL103 Diana Center',
#   'Enrollment': '64 students (70 max) as of August 31, 2019',
#   'Notes': 'Pre-req: BIOL BC1500, BC1501, BC1502, BC1503 or equivalent.',
#   'Instructor': 'Brian Morton',
#   'course': 'MOLECULAR & MENDELIAN GENETICS',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7296,
#   'Points': 3,
#   'Day/Time': 'TR 1:10pm-2:25pm',
#   'Location': '514 Altschul Hall (Barnard)',
#   'Enrollment': '6 students as of August 31, 2019',
#   'Notes': 'Pre-req: BIOL BC1500, BC1501, BC1502, BC1503 or equivalent.',
#   'Instructor': 'Hilary Callahan',
#   'course': 'PLANT EVOLUTION & DIVERSITY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7266,
#   'Points': 3,
#   'Day/Time': 'W 1:10pm-6:00pm',
#   'Location': '1316 Altschul Hall (Barnard)',
#   'Enrollment': '8 students (16 max) as of August 31, 2019 / Full',
#   'Notes': 'Must attend 1st lab; pre-req: BIOL BC2280 Animal Behavior',
#   'Instructor': 'Alison Pischedda',
#   'course': 'LABORATORY IN ANIMAL BEHAVIOR',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52848,
#   'Points': 3,
#   'Day/Time': 'TR 4:10pm-5:25pm',
#   'Location': '309 Havemeyer Hall',
#   'Enrollment': '91 students (220 max) as of August 31, 2019',
#   'Notes': 'TWO HOUR RECITATION TO BE ARRANGED',
#   'Instructors': 'Deborah Mowshowitz and Lawrence A Chasin and Marko Jovanovic',
#   'course': 'CONTEMPORARY BIOLOGY I',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52802,
#   'Points': 3,
#   'Day/Time': 'M 1:10pm-5:00pm',
#   'Location': '922 Schermerhorn Hall [SCH]',
#   'Enrollment': '19 students (28 max) as of August 31, 2019',
#   'Instructor': 'Claire E Hazen',
#   'course': 'CONTEMPORARY BIOLOGY LAB',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 52803,
#   'Points': 3,
#   'Day/Time': 'T 1:10pm-5:00pm',
#   'Location': '922 Schermerhorn Hall [SCH]',
#   'Enrollment': '27 students (28 max) as of August 31, 2019',
#   'Instructor': 'Claire E Hazen',
#   'course': 'CONTEMPORARY BIOLOGY LAB',
#   'subject': 'BIOL'},
#  {'number': '003',
#   'Call Number': 52804,
#   'Points': 3,
#   'Day/Time': 'W 1:10pm-5:00pm',
#   'Location': '922 Schermerhorn Hall [SCH]',
#   'Enrollment': '27 students (28 max) as of August 31, 2019',
#   'Instructor': 'Claire E Hazen',
#   'course': 'CONTEMPORARY BIOLOGY LAB',
#   'subject': 'BIOL'},
#  {'number': '004',
#   'Call Number': 52805,
#   'Points': 3,
#   'Day/Time': 'R 6:40pm-10:30pm',
#   'Location': '511 Hamilton Hall',
#   'Enrollment': '28 students (28 max) as of August 31, 2019 / Full',
#   'Instructor': 'Claire E Hazen',
#   'course': 'CONTEMPORARY BIOLOGY LAB',
#   'subject': 'BIOL'},
#  {'number': '005',
#   'Call Number': 52806,
#   'Points': 3,
#   'Day/Time': 'F 1:10pm-5:00pm',
#   'Location': '224 Pupin Laboratories',
#   'Enrollment': '26 students (28 max) as of August 31, 2019',
#   'Instructor': 'Claire E Hazen',
#   'course': 'CONTEMPORARY BIOLOGY LAB',
#   'subject': 'BIOL'},
#  {'number': '006',
#   'Call Number': 52807,
#   'Points': 3,
#   'Day/Time': 'W 6:40pm-10:30pm',
#   'Location': '511 Hamilton Hall',
#   'Enrollment': '24 students (28 max) as of August 31, 2019',
#   'Instructor': 'Claire E Hazen',
#   'course': 'CONTEMPORARY BIOLOGY LAB',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7267,
#   'Points': 3,
#   'Day/Time': 'W 1:10pm-6:00pm',
#   'Location': '1214 Altschul Hall (Barnard)',
#   'Enrollment': '12 students (12 max) as of August 31, 2019 / Full',
#   'Notes': 'Must attend 1st lab; pre-/co-req: BIOL BC2100 M&M Genetics',
#   'Instructor': 'Brian Morton',
#   'course': 'LABORATORY IN GENETICS',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52849,
#   'Points': 4,
#   'Day/Time': 'TR 10:10am-11:25am',
#   'Location': 'B60 ALFRED LERNE',
#   'Enrollment': '115 students (120 max) as of August 31, 2019',
#   'Notes': 'Requirements: UN2005 and UN 2006, or instructor permission.',
#   'Instructor': 'Jian Yang',
#   'course': 'NEUROBIO I:CELLULAR & MOLECULR',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52833,
#   'Points': 3,
#   'Day/Time': 'TR 10:10am-11:25am',
#   'Location': '601 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '30 students (72 max) as of August 31, 2019',
#   'Instructor': 'Mary Ann Price',
#   'course': 'GENERAL PHYSIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52834,
#   'Points': 3,
#   'Day/Time': 'TR 1:10pm-2:25pm',
#   'Location': '601 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '53 students (70 max) as of August 31, 2019',
#   'Notes': 'Grad students should sign up for 4022',
#   'Instructor': 'Alice Heicklen',
#   'course': 'DEVELOPMENTAL BIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52857,
#   'Points': 3,
#   'Day/Time': 'TR 11:40am-12:55pm',
#   'Location': '601 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '26 students (70 max) as of August 31, 2019',
#   'Instructor': 'Jeannette C Bulinski',
#   'course': 'CELL BIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52856,
#   'Points': 5,
#   'Day/Time': 'TR 1:10pm-5:00pm',
#   'Location': '743 Seeley W. Mudd Building',
#   'Enrollment': '8 students (12 max) as of August 31, 2019',
#   'Instructor': 'Alexander A Tzagoloff',
#   'course': 'PROJECT LAB-MOLECULAR GENETICS',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52835,
#   'Points': 3,
#   'Day/Time': 'MW 2:40pm-3:55pm',
#   'Location': '312 Mathematics Building',
#   'Enrollment': '24 students (80 max) as of August 31, 2019',
#   'Notes': 'Join Waitlist to register',
#   'Instructor': 'Christian W Schindler',
#   'course': 'CELLULAR/MOLECULAR IMMUNOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7297,
#   'Points': 3,
#   'Day/Time': 'MW 11:40am-12:55pm',
#   'Location': '903 Altschul Hall (Barnard)',
#   'Enrollment': '45 students (50 max) as of August 31, 2019',
#   'Notes': 'Pre-req: BIOL BC1500, BC1501, BC1502, BC1503, & BC2100.',
#   'Instructor': 'Jonathan Snow',
#   'course': 'CELL BIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7294,
#   'Points': 3,
#   'Day/Time': 'R 1:10pm-6:00pm',
#   'Location': '1015 Altschul Hall (Barnard)',
#   'Enrollment': '0 students (16 max) as of August 31, 2019 / Full',
#   'Notes': 'Must attend 1st lab; pre-/co-req: BIOL BC3310 Cell Biology.',
#   'Instructor': 'Jonathan Snow',
#   'course': 'LABORATORY IN CELL BIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7274,
#   'Points': 3,
#   'Day/Time': 'TR 10:10am-11:25am',
#   'Location': '903 Altschul Hall (Barnard)',
#   'Enrollment': '25 students as of August 31, 2019',
#   'Notes': 'Pre-req: BIOL BC1500, BC1501, BC1502, BC1503, & BC2100.',
#   'Instructor': 'Jj L Miranda',
#   'course': 'MICROBIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7298,
#   'Points': 3,
#   'Day/Time': 'TR 11:40am-12:55pm',
#   'Location': '805 Altschul Hall (Barnard)',
#   'Enrollment': '10 students as of August 31, 2019',
#   'Notes': 'Pre-req: BIOL BC1500, BC1501, BC1502, BC1503, & BC2100.',
#   'Instructor': 'Jennifer H Mansfield',
#   'course': 'DEVELOPMENT',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7275,
#   'Points': 3,
#   'Day/Time': 'TR 11:40am-12:55pm',
#   'Location': '504 Diana Center',
#   'Enrollment': '60 students (70 max) as of August 31, 2019',
#   'Notes': 'Pre-req: BIOL BC1500, BC1501, BC1502, BC1503 & CHEM BC3230.',
#   'Instructor': 'Elizabeth P Bauer',
#   'course': 'MOLECULAR&CELLULAR NEUROSCI',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7299,
#   'Points': 3,
#   'Day/Time': 'W 1:10pm-6:00pm',
#   'Location': '1115 Altschul Hall (Barnard)',
#   'Enrollment': '14 students (16 max) as of August 31, 2019',
#   'Notes': 'Must attend 1st lab; Pre-/co-req: BIOL BC3362 M&C Neurosci',
#   'Instructor': 'Elizabeth P Bauer',
#   'course': 'LAB IN MOLEC & CELL NEUROSCI',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52808,
#   'Points': 3,
#   'Day/Time': 'T 12:10pm-2:00pm',
#   'Location': '424 Pupin Laboratories',
#   'Enrollment': '22 students (22 max) as of August 31, 2019 / Full',
#   'Instructor': 'Franklin Lowy',
#   'course': 'ANTIMICROBIAL RESISTANCE',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52845,
#   'Points': '2-4',
#   'Enrollment': '54 students (70 max) as of August 31, 2019',
#   'Instructor': 'Ron M Prywes',
#   'course': 'INDEP BIOLOGICAL RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52809,
#   'Points': 0,
#   'Day/Time': 'W 5:40pm-6:30pm',
#   'Location': '1000 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '18 students (35 max) as of August 31, 2019',
#   'Notes': 'STUDENTS MUST REGISTER FOR RECITATION SECTION: BIOL UN3510',
#   'Instructor': 'Ron M Prywes',
#   'course': 'INDEP BIOLOGICAL RESEARCH - REC',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 52810,
#   'Points': 0,
#   'Day/Time': 'T 5:40pm-6:30pm',
#   'Location': '1000 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '9 students (35 max) as of August 31, 2019',
#   'Instructor': 'Ron M Prywes',
#   'course': 'INDEP BIOLOGICAL RESEARCH - REC',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52855,
#   'Points': 4,
#   'Day/Time': 'TR 2:40pm-3:55pm',
#   'Location': '1000 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '6 students (25 max) as of August 31, 2019',
#   'Notes': 'Recitation meets Thursdays after lecture 4:10   6:00P',
#   'Instructors': 'Guy Sella and Peter Andolfatto',
#   'course': 'EVOL IN THE AGE OF GENOMICS',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7264,
#   'Points': 4,
#   'Day/Time': 'M 4:10pm-6:00pm',
#   'Location': 'LL016 MILSTEIN CEN',
#   'Enrollment': '10 students (12 max) as of August 31, 2019 / Full',
#   'Notes': 'Fall 2019 Topic: Data Intensive Approaches in Biology',
#   'Instructor': 'Hilary Callahan',
#   'course': 'SR SEM IN BIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7287,
#   'Points': 4,
#   'Day/Time': 'M 1:10pm-3:00pm',
#   'Location': '501 Diana Center',
#   'Enrollment': '11 students as of August 31, 2019',
#   'Notes': 'Full-year course: Must enroll in BIOL BC3592 in the spring.',
#   'Instructors': 'Jessica Goldstein and Alison Pischedda and Jj L Miranda',
#   'course': 'GUIDED RESEARCH & SEMINAR',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7265,
#   'Points': 4,
#   'Day/Time': 'M 1:10pm-3:00pm',
#   'Location': '318 Milbank Hall (Barnard)',
#   'Enrollment': '6 students as of August 31, 2019',
#   'Notes': 'Full-year course: Must enroll in BIOL BC3594 in the spring.',
#   'Instructors': 'Alison Pischedda and Jessica Goldstein and Jj L Miranda',
#   'course': 'SENIOR THESIS RESEARCH & SEMINAR',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 7300,
#   'Points': 4,
#   'Day/Time': 'M 1:10pm-3:00pm',
#   'Location': '530 Altschul Hall (Barnard)',
#   'Enrollment': '5 students as of August 31, 2019',
#   'Notes': 'Full-year course: Must enroll in BIOL BC3594 in the spring.',
#   'Instructors': 'Jj L Miranda and Jessica Goldstein and Alison Pischedda',
#   'course': 'SENIOR THESIS RESEARCH & SEMINAR',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 7276,
#   'Points': '1-4',
#   'Enrollment': '5 students as of August 31, 2019',
#   'Notes': 'Instructor approval & Project Approval Form required.',
#   'Instructor': 'Elizabeth P Bauer',
#   'course': 'GUIDED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 7277,
#   'Points': '1-4',
#   'Enrollment': '1 student as of August 31, 2019',
#   'Notes': 'Instructor approval & Project Approval Form required.',
#   'Instructor': 'Hilary Callahan',
#   'course': 'GUIDED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '003',
#   'Call Number': 7278,
#   'Points': '1-4',
#   'Enrollment': '6 students as of August 31, 2019',
#   'Notes': 'Instructor approval & Project Approval Form required.',
#   'Instructor': 'John Glendinning',
#   'course': 'GUIDED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '004',
#   'Call Number': 7279,
#   'Points': '1-4',
#   'Enrollment': '0 students as of August 31, 2019',
#   'Notes': 'Instructor approval & Project Approval Form required.',
#   'Instructor': 'Paul E Hertz',
#   'course': 'GUIDED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '005',
#   'Call Number': 7280,
#   'Points': '1-4',
#   'Enrollment': '2 students as of August 31, 2019',
#   'Notes': 'Instructor approval & Project Approval Form required.',
#   'Instructor': 'Jennifer H Mansfield',
#   'course': 'GUIDED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '006',
#   'Call Number': 7281,
#   'Points': '1-4',
#   'Enrollment': '1 student as of August 31, 2019',
#   'Notes': 'Instructor approval & Project Approval Form required.',
#   'Instructor': 'Alison Pischedda',
#   'course': 'GUIDED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '007',
#   'Call Number': 7282,
#   'Points': '1-4',
#   'Enrollment': '0 students as of August 31, 2019',
#   'Notes': 'Instructor approval & Project Approval Form required.',
#   'Instructor': 'Brian Morton',
#   'course': 'GUIDED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '008',
#   'Call Number': 7283,
#   'Points': '1-4',
#   'Enrollment': '4 students as of August 31, 2019',
#   'Notes': 'Instructor approval & Project Approval Form required.',
#   'Instructor': 'Jonathan Snow',
#   'course': 'GUIDED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '009',
#   'Call Number': 7284,
#   'Points': '1-4',
#   'Enrollment': '2 students as of August 31, 2019',
#   'Notes': 'Instructor approval & Project Approval Form required.',
#   'Instructor': 'Jj L Miranda',
#   'course': 'GUIDED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52837,
#   'Points': 3,
#   'Day/Time': 'M 1:10pm-4:00pm',
#   'Location': '1000 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '17 students (27 max) as of August 31, 2019',
#   'Notes': 'Only open to Ph.D. candidates and advanced undergraduates.',
#   'Instructor': 'Martin Chalfie',
#   'course': 'ADVANCED GENETIC ANALYSIS',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52846,
#   'Points': 4,
#   'Day/Time': 'TR 10:10am-11:25am',
#   'Location': 'B60 ALFRED LERNE',
#   'Enrollment': '14 students (20 max) as of August 31, 2019',
#   'Notes': 'Requirements: UN2005 and UN 2006, or instructor permission.',
#   'Instructor': 'Jian Yang',
#   'course': 'NEUROBIO I:CELLULAR & MOLECULR',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52811,
#   'Points': 3,
#   'Day/Time': 'TR 1:10pm-2:25pm',
#   'Location': '601 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '5 students (10 max) as of August 31, 2019 / Full',
#   'Notes': 'Undergrads must register for UN3022',
#   'Instructor': 'Alice Heicklen',
#   'course': 'DEVELOPMENTAL BIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52838,
#   'Points': 3,
#   'Day/Time': 'MW 4:10pm-5:25pm',
#   'Location': '601 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '32 students (50 max) as of August 31, 2019',
#   'Instructors': 'Daniel D Kalderon and Lawrence A Chasin',
#   'course': 'BIOTECHNOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52858,
#   'Points': 3,
#   'Day/Time': 'TR 11:40am-12:55pm',
#   'Location': '601 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '5 students (20 max) as of August 31, 2019',
#   'Instructor': 'Jeannette C Bulinski',
#   'course': 'CELL BIOLOGY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52812,
#   'Points': 3,
#   'Day/Time': 'F 1:00pm-4:00pm',
#   'Location': '301 Hamilton Hall',
#   'Enrollment': '5 students (8 max) as of August 31, 2019',
#   'Notes': 'Please join waitlist - priority: MA biotech students',
#   'Instructor': 'Lewis Brown',
#   'course': 'PROTEOMICS LABORATORY',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52851,
#   'Points': 3,
#   'Day/Time': 'MW 2:40pm-3:55pm',
#   'Location': '428 Pupin Laboratories',
#   'Enrollment': '45 students (65 max) as of August 31, 2019',
#   'Instructor': 'Lili Yamasaki',
#   'course': 'DRUGS AND DISEASE',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52852,
#   'Points': '3-6',
#   'Enrollment': '1 student (100 max) as of August 31, 2019',
#   'Instructor': 'Lili Yamasaki',
#   'course': 'SUPERVISED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52840,
#   'Points': '2-6',
#   'Enrollment': '1 student (100 max) as of August 31, 2019',
#   'Instructor': 'Lili Yamasaki',
#   'course': 'SUPERVISED RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52813,
#   'Points': 3,
#   'Day/Time': 'R 4:10pm-6:00pm',
#   'Location': '800 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '13 students (25 max) as of August 31, 2019',
#   'Instructor': 'Ron M Prywes',
#   'course': 'CELL SIGNALING',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 17302,
#   'Points': 3,
#   'Day/Time': 'MW 2:40pm-3:55pm',
#   'Location': 'To be announced',
#   'Enrollment': '1 student (10 max) as of August 31, 2019',
#   'Notes': 'GR5073 for grad students. UG students register for UN3073',
#   'Instructor': 'Christian W Schindler',
#   'course': 'CELLULAR/MOLECULAR IMMUNOLOGY',
#   'subject': 'BIOL'},
#  {'number': '002',
#   'Call Number': 52842,
#   'Points': 2,
#   'Day/Time': 'MW 9:15am-11:15am',
#   'Location': '601 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '0 students (35 max) as of August 31, 2019',
#   'Notes': 'FIRST HALF OF SEMESTER',
#   'Instructor': 'John Hunt',
#   'course': 'GRAD CORE II: MACROMOL STRC INTERACTION',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 10363,
#   'Points': 3,
#   'Day/Time': 'MW 9:30am-10:45am',
#   'Location': '800 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '21 students (25 max) as of August 31, 2019',
#   'Notes': 'Priority will be given to Biological Sciences PhD students',
#   'Instructors': 'James L Manley and Carol L Prives and Songtao Jia and Marko Jovanovic',
#   'course': 'The Central Dogma: Mechanisms and Regula',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52794,
#   'Points': 3,
#   'Day/Time': 'TR 6:10pm-7:25pm',
#   'Location': '800 Sherman Fairchild Life Sciences Building',
#   'Enrollment': '15 students (40 max) as of August 31, 2019',
#   'Instructor': 'Ron M Prywes',
#   'course': 'PRERESEARCH SEMINAR',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 52814,
#   'Points': '1-12',
#   'Enrollment': '93 students (200 max) as of August 31, 2019',
#   'Instructor': 'Ron M Prywes',
#   'course': 'SUPERVISED INDIVIDUAL RESEARCH',
#   'subject': 'BIOL'},
#  {'number': '001',
#   'Call Number': 43418,
#   'Points': 3,
#   'Day/Time': 'MW 10:10am-11:25am',
#   'Location': '413 Kent Hall',
#   'Enrollment': '43 students (65 max) as of August 31, 2019',
#   'Instructor': 'Qi Wang',
#   'course': 'BIOMEDICAL ENGINEERING I',
#   'subject': 'BMEN'},
#  {'number': '001',
#   'Call Number': 43405,
#   'Points': 3,
#   'Day/Time': 'W 1:10pm-3:55pm',
#   'Location': '382 Engineering Terrace',
#   'Enrollment': '20 students (20 max) as of August 31, 2019 / Full',
#   'Instructor': 'Aaron M Kyle',
#   'course': 'BIOMEDICAL ENGINEERING LAB I',
#   'subject': 'BMEN'},
#  {'number': '002',
#   'Call Number': 43406,
#   'Points': 3,
#   'Day/Time': 'R 1:10pm-3:55pm',
#   'Location': '382 Engineering Terrace',
#   'Enrollment': '19 students (20 max) as of August 31, 2019',
#   'Instructor': 'Aaron M Kyle',
#   'course': 'BIOMEDICAL ENGINEERING LAB I',
#   'subject': 'BMEN'},
#  {'number': '001',
#   'Call Number': 43403,
#   'Points': 4,
#   'Day/Time': 'TR 10:10am-11:25am',
#   'Location': '633 Seeley W. Mudd Building',
#   'Enrollment': '52 students (55 max) as of August 31, 2019',
#   'Instructor': 'Aaron M Kyle',
#   'course': 'BIOMEDICAL ENGINEERING DESIGN',
#   'subject': 'BMEN'},
#  {'number': '001',
#   'Call Number': 43310,
#   'Points': '1-3',
#   'Enrollment': '0 students (50 max) as of August 31, 2019',
#   'Instructor': 'Gerard H Ateshian',
#   'course': 'PROJECTS IN BIOMEDICAL ENGIN',
#   'subject': 'BMEN'},
#  {'number': '002',
#   'Call Number': 43311,
#   'Points': '1-3',
#   'Enrollment': '0 students (50 max) as of August 31, 2019',
#   'Instructor': 'Tal Danino',
#   'course': 'PROJECTS IN BIOMEDICAL ENGIN',
#   'subject': 'BMEN'},
#  {'number': '003',
#   'Call Number': 43312,
#   'Points': '1-3',
#   'Enrollment': '1 student (50 max) as of August 31, 2019',
#   'Instructor': 'X. Edward Guo',
#   'course': 'PROJECTS IN BIOMEDICAL ENGIN',
#   'subject': 'BMEN'},
#  {'number': '004',
#   'Call Number': 43313,
#   'Points': '1-3',
#   'Enrollment': '1 student (50 max) as of August 31, 2019',
#   'Instructor': 'Henry Hess',
#   'course': 'PROJECTS IN BIOMEDICAL ENGIN',
#   'subject': 'BMEN'},
#  {'number': '005',
#   'Call Number': 43314,
# ...
#   'Call Number': 29352,
#   'Points': 3,
#   'Day/Time': 'MTWRF 9:00am-5:00pm',
#   'Location': '302 Fayerweather',
#   'Enrollment': '7 students (30 max) as of August 31, 2019',
#   'Notes': 'OPEN TO SPS, PRIORITY TO SCOM. CLASS STARTS IN  SF 8/26',
#   'Instructor': 'Andrew Whitehouse',
#   'course': 'POLITICAL COMMUNICATIONS',
#   'subject': 'COMM'},
#  {'number': 'H01',
#   'Call Number': 29440,
#   'Points': 3,
#   'Enrollment': '11 students (30 max) as of August 31, 2019',
#   'Notes': 'EXEC SCHED; EXEC SCOM ONLY; OTHER SCOM W/ PROG PERMISSION',
#   'Instructor': 'Andrew Whitehouse',
#   'course': 'CRISIS COMMUNICATIONS',
#   'subject': 'COMM'},
#  {'number': '001',
#   'Call Number': 29351,
#   'Points': 3,
#   'Day/Time': 'W 6:10pm-8:00pm',
#   'Location': '602 Northwest Corner Building',
#   'Enrollment': '14 students (30 max) as of August 31, 2019',
#   'Notes': 'OPEN TO SPS, PRIORITY TO SCOM STUDENTS',
#   'Instructor': 'Rebecca Heino',
#   'course': 'CRITICAL CONVERSATIONS',
#   'subject': 'COMM'},
#  {'number': '002',
#   'Call Number': 13503,
#   'Points': 3,
#   'Day/Time': 'M 6:10pm-8:00pm',
#   'Location': '301M Fayerweather',
#   'Enrollment': '16 students (30 max) as of August 31, 2019',
#   'Notes': 'non-SCOM admitted w/program permission',
#   'Instructor': 'Joseph E Pantigoso',
#   'course': 'VALUE OF BRAND',
#   'subject': 'COMM'},
#  {'number': 'H01',
#   'Call Number': 29350,
#   'Points': 3,
#   'Enrollment': '7 students (30 max) as of August 31, 2019',
#   'Notes': 'EXEC SCHED; EXEC SCOM ONLY; OTHER SCOM W/ PROG PERMISSION',
#   'Instructor': 'Tasha Space',
#   'course': 'VALUE OF BRAND',
#   'subject': 'COMM'},
#  {'number': '001',
#   'Call Number': 29465,
#   'Points': 3,
#   'Day/Time': 'M 4:10pm-6:00pm',
#   'Location': '517 Hamilton Hall',
#   'Enrollment': '23 students (30 max) as of August 31, 2019',
#   'Notes': 'OPEN TO SPS, PRIORITY TO SCOM STUDENTS',
#   'course': 'STRATEGIC VISUAL COMMUNICATION',
#   'subject': 'COMM'},
#  {'number': 'H01',
#   'Call Number': 10042,
#   'Points': 3,
#   'Day/Time': 'R 8:10pm-10:00pm',
#   'Location': 'OTHR OTHER',
#   'Enrollment': '8 students (30 max) as of August 31, 2019',
#   'Notes': 'OPEN ONLY TO SF SCOM STUDENTS',
#   'course': 'COMMUNICATION RESEARCH & INSIGHTS',
#   'subject': 'COMM'},
#  {'number': '001',
#   'Call Number': 29454,
#   'Points': 3,
#   'Day/Time': 'R 6:10pm-9:00pm',
#   'Location': '212D Lewisohn Hall',
#   'Enrollment': '19 students (20 max) as of August 31, 2019 / Full',
#   'Notes': 'OPEN ONLY TO FT SCOM STUDENTS',
#   'Instructor': 'Thomas J Groppe',
#   'course': 'CAPSTONE',
#   'subject': 'COMM'},
#  {'number': '002',
#   'Call Number': 29453,
#   'Points': 3,
#   'Day/Time': 'R 6:10pm-9:00pm',
#   'Location': '201 80 Claremont Ave',
#   'Enrollment': '15 students (20 max) as of August 31, 2019',
#   'Notes': 'OPEN ONLY TO FT SCOM STUDENTS',
#   'Instructor': 'Richard J Cunningham',
#   'course': 'CAPSTONE',
#   'subject': 'COMM'},
#  {'number': 'H03',
#   'Call Number': 29452,
#   'Points': 3,
#   'Enrollment': '16 students (20 max) as of August 31, 2019',
#   'Notes': 'EXEC SCHED; EXEC SCOM ONLY; OTHER SCOM W/ PROG PERMISSION',
#   'Instructor': 'Mark Truss',
#   'course': 'CAPSTONE',
#   'subject': 'COMM'},
#  {'number': '081',
#   'Call Number': 14904,
#   'Points': 0,
#   'Enrollment': '0 students (83 max) as of August 31, 2019',
#   'Instructor': 'Burton L Edelstein',
#   'course': 'WORKSHOP ON POPULATION ORAL HEALTH',
#   'subject': 'COMH'},
#  {'number': '083',
#   'Call Number': 14997,
#   'Points': 0,
#   'Enrollment': '98 students as of August 31, 2019',
#   'Instructors': 'David Albert and C Kunzel',
#   'course': 'ORAL HEALTH CARE DELIVERY',
#   'subject': 'COMH'},
#  {'number': '001',
#   'Call Number': 15145,
#   'Points': 0,
#   'Enrollment': '0 students as of August 31, 2019',
#   'Instructor': 'Kavita Ahluwalia',
#   'course': 'PUB HLTH SCIENCES FOR DENTISTS',
#   'subject': 'COMH'},
#  {'number': '001',
#   'Call Number': 15146,
#   'Points': 0,
#   'Enrollment': '0 students as of August 31, 2019',
#   'Instructor': 'Kavita Ahluwalia',
#   'course': 'EPIDEMIOLOGY & SURVEILLANCE',
#   'subject': 'COMH'},
#  {'number': '001',
#   'Call Number': 7601,
#   'Points': 4,
#   'Day/Time': 'M 4:10pm-6:00pm',
#   'Location': '501 Diana Center',
#   'Enrollment': '12 students (12 max) as of August 31, 2019 / Full',
#   'Instructor': 'Faculty',
#   'course': 'GLOBAL LONG-FORM PHOTOGRAPHY: HISTORY AN',
#   'subject': 'CPLT'},
#  {'number': '001',
#   'Call Number': 7594,
#   'Points': 3,
#   'Day/Time': 'TR 11:40am-12:55pm',
#   'Location': '324 Milbank Hall (Barnard)',
#   'Enrollment': '30 students (35 max) as of August 31, 2019',
#   'Instructor': 'Emily Sun',
#   'course': 'INTRO TO COMPARATIVE LITERATUR',
#   'subject': 'CPLT'},
#  {'number': '001',
#   'Call Number': 7592,
#   'Points': 3,
#   'Day/Time': 'MW 2:40pm-3:55pm',
#   'Location': '405 Milbank Hall (Barnard)',
#   'Enrollment': '55 students (100 max) as of August 31, 2019',
#   'Notes': 'Prerequisite: Satisfaction of Barnard language requirement',
#   'Instructor': 'Peter T Connor',
#   'course': 'INTRO TO TRANSLATION STUDIES',
#   'subject': 'CPLT'},
#  {'number': '001',
#   'Call Number': 7595,
#   'Points': 3,
#   'Day/Time': 'TR 10:10am-11:25am',
#   'Location': '237 Milbank Hall (Barnard)',
#   'Enrollment': '9 students (30 max) as of August 31, 2019',
#   'Instructor': 'Erk Grimm',
#   'course': 'FRIEND/FOE?WRLD LIT&JUSTICE',
#   'subject': 'CPLT'},
#  {'number': '001',
#   'Call Number': 7590,
#   'Points': 3,
#   'Day/Time': 'TR 2:40pm-3:55pm',
#   'Location': '409 Barnard Hall',
#   'Enrollment': '24 students (30 max) as of August 31, 2019',
#   'Instructor': 'Emily Sun',
#   'course': 'INTRODUCTION TO NARRATIVE',
#   'subject': 'CPLT'},
#  {'number': '001',
#   'Call Number': 7593,
#   'Points': 4,
#   'Day/Time': 'T 2:10pm-4:00pm',
#   'Location': 'LL017 MILSTEIN CEN',
#   'Enrollment': '9 students (15 max) as of August 31, 2019 / Full',
#   'Notes': 'Instructor permission',
#   'Instructor': 'Hisham Matar',
#   'course': 'ARABIAN NIGHTS INFLUENCES',
#   'subject': 'CPLT'},
#  {'number': '001',
#   'Call Number': 18204,
#   'Points': 3,
#   'Day/Time': 'M 4:20pm-7:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '0 students (4 max) as of August 31, 2019 / Full',
#   'Notes': 'Instructor permission required for this course.',
#   'Instructor': 'Bernard Harcourt',
#   'course': 'Abolition: A Social Justice Practicum',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 20188,
#   'Points': 3,
#   'Day/Time': 'T 2:10pm-4:00pm',
#   'Location': '253 Engineering Terrace',
#   'Enrollment': '18 students (28 max) as of August 31, 2019 / Full',
#   'Instructor': 'Rishi K Goyal',
#   'course': 'SENIOR SEM-COMP LIT & SOCIETY',
#   'subject': 'CPLS'},
#  {'number': '002',
#   'Call Number': 18175,
#   'Points': '1-3',
#   'Enrollment': '0 students (1 max) as of August 31, 2019',
#   'Instructor': 'Alfred Mac Adam',
#   'course': 'INDEPENDENT STUDY',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 58853,
#   'Points': 4,
#   'Day/Time': 'W 10:10am-12:00pm',
#   'Location': '609 Hamilton Hall',
#   'Enrollment': '21 students (20 max) as of August 31, 2019 / Full',
#   'Instructor': 'David B Lurie',
#   'course': 'WORLD PHILOLOGY',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 20191,
#   'Points': 4,
#   'Day/Time': 'M 2:10pm-4:00pm',
#   'Location': '411 Kent Hall',
#   'Enrollment': '8 students (20 max) as of August 31, 2019',
#   'Instructor': 'Diane Rubenstein',
#   'course': 'FASCISM: AESTHETICS & POLITICS',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 58852,
#   'Points': 4,
#   'Day/Time': 'T 10:10am-12:00pm',
#   'Location': 'LL105 Diana Center',
#   'Enrollment': '10 students (20 max) as of August 31, 2019',
#   'Instructor': 'Hana Worthen',
#   'course': 'POLITICS OF PERFORMANCE',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 7599,
#   'Points': 4,
#   'Day/Time': 'T 2:10pm-4:00pm',
#   'Location': '227 Milbank Hall (Barnard)',
#   'Enrollment': '9 students (20 max) as of August 31, 2019',
#   'Notes': 'Prereq: CPLS BC3160, or instructor permission',
#   'Instructor': 'Nancy Worman',
#   'course': 'TRAGIC BODIES II: SURFACES, MATERIALITIE',
#   'subject': 'CPLS'},
#  {'number': '004',
#   'Call Number': 20183,
#   'Points': '1-3',
#   'Enrollment': '0 students (6 max) as of August 31, 2019',
#   'Instructor': 'Bernard Harcourt',
#   'course': 'INDEPENDENT STUDY',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 20177,
#   'Points': 3,
#   'Day/Time': 'W 2:10pm-4:00pm',
#   'Location': '201 80 Claremont Ave',
#   'Enrollment': '13 students (16 max) as of August 31, 2019',
#   'Notes': 'Contact Kelly Lemons kkl2116 to register, ICLSgrad only',
#   'Instructors': 'Gayatri C Spivak and Rosalind Morris',
#   'course': 'INTRO TO COMP LIT & SOCIETY',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 20192,
#   'Points': 3,
#   'Day/Time': 'R 4:10pm-6:00pm',
#   'Location': '612 Philosophy Hall',
#   'Enrollment': '20 students (20 max) as of August 31, 2019 / Full',
#   'Instructors': 'Xiaolu Guo and Karen R Van Dyck',
#   'course': 'The Hybrid Voice: Comparative Diasporas',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 58854,
#   'Points': 4,
#   'Day/Time': 'R 6:10pm-8:00pm',
#   'Location': 'B-100 Heyman Center for the Humanities (East Campus)',
#   'Enrollment': '11 students (18 max) as of August 31, 2019 / Full',
#   'Notes': 'APPLICATION REQUIRED: https://forms.gle/3Ha7kKc4opy5aYaj9',
#   'Instructor': 'Etienne Balibar',
#   'course': 'Socialism/Communism: Dilemma of the Past',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 58851,
#   'Points': 3,
#   'Day/Time': 'R 2:10pm-4:00pm',
#   'Location': '505 Casa Hispánica',
#   'Enrollment': '2 students (20 max) as of August 31, 2019',
#   'Instructor': 'Patricia E Grieve',
#   'course': 'BLOOD/LUST: EARLY MOD MEDIT',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 20174,
#   'Points': 3,
#   'Day/Time': 'W 6:10pm-8:00pm',
#   'Location': '502 Northwest Corner Building',
#   'Enrollment': '5 students (16 max) as of August 31, 2019',
#   'Instructor': 'Bernard Harcourt',
#   'course': 'S CONTEMP CRITICAL THOUGHT',
#   'subject': 'CPLS'},
#  {'number': '001',
#   'Call Number': 20190,
#   'Points': 3,
#   'Day/Time': 'R 4:10pm-6:00pm',
#   'Location': '201A Philosophy Hall',
#   'Enrollment': '18 students (20 max) as of August 31, 2019',
#   'Instructor': 'Marcus Coelen',
#   'course': 'FREUD',
#   'subject': 'CLPS'},
#  {'number': '001',
#   'Call Number': 20179,
#   'Points': 3,
#   'Day/Time': 'T 10:10am-12:00pm',
#   'Location': '511 Kent Hall',
#   'Enrollment': '7 students (15 max) as of August 31, 2019 / Full',
#   'Instructor': 'Karen Seeley',
#   'course': 'GLOBAL FREUD',
#   'subject': 'CLPS'},
#  {'number': '001',
#   'Call Number': 53914,
#   'Points': 3,
#   'Day/Time': 'TR 2:40pm-3:55pm',
#   'Location': '707 Hamilton Hall',
#   'Enrollment': '5 students (15 max) as of August 31, 2019',
#   'Instructor': 'Christopher W Harwood',
#   'course': 'THE WRITERS OF PRAGUE',
#   'subject': 'CLCZ'},
#  {'number': '001',
#   'Call Number': 40459,
#   'Points': 4,
#   'Day/Time': 'R 12:10pm-2:00pm',
#   'Location': 'To be announced',
#   'Enrollment': '9 students (18 max) as of August 31, 2019 / Full',
#   'Instructor': 'Bianca F Calabresi',
#   'course': 'EPIC FAILS & NEW WORLD DREAMS',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 40444,
#   'Points': 4,
#   'Day/Time': 'T 2:10pm-4:00pm',
#   'Location': '418 International Affairs Building',
#   'Enrollment': '17 students (18 max) as of August 31, 2019 / Full',
#   'Notes': 'INSTRUCTOR PERMISSION REQUIRED. SEE DEPT WEBSITE FOR DETAIL',
#   'Instructors': 'Bruce Robbins and Orhan Pamuk',
#   'course': 'THE BIG AMBITIOUS NOVEL',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 10008,
#   'Points': 4,
#   'Day/Time': 'TR 10:10am-12:00pm',
#   'Location': '522D Kent Hall',
#   'Enrollment': '12 students (12 max) as of August 31, 2019 / Full',
#   'Notes': 'INSTRUCTOR PERMISSION REQUIRED. SEE DEPT WEBSITE FOR DETAIL',
#   'Instructor': 'Christopher C Baswell',
#   'course': 'VERNACULAR PALEOGRAPHY',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 10177,
#   'Points': 4,
#   'Day/Time': 'W 6:10pm-8:00pm',
#   'Location': '201 80 Claremont Ave',
#   'Enrollment': '12 students (25 max) as of August 31, 2019 / Full',
#   'Instructor': 'Gayatri C Spivak',
#   'course': 'Du Bois, Gramsci, Ambedkar: Three Men on',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 10450,
#   'Points': 4,
#   'Day/Time': 'M 2:10pm-4:00pm',
#   'Location': '424 Pupin Laboratories',
#   'Enrollment': '18 students (18 max) as of August 31, 2019 / Full',
#   'Notes': 'INSTRUCTOR PERMISSION REQUIRED. SEE DEPT WEBSITE FOR DETAIL',
#   'Instructor': 'Jenny M Davidson',
#   'course': '18th Century Comparative Novel',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 10600,
#   'Points': 3,
#   'Day/Time': 'MW 1:10pm-2:25pm',
#   'Location': '304 Hamilton Hall',
#   'Enrollment': '18 students (35 max) as of August 31, 2019',
#   'Instructor': 'Mara G de Gennaro',
#   'course': 'World Poems',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 10205,
#   'Points': 3,
#   'Day/Time': 'MW 2:40pm-3:55pm',
#   'Location': '603 Hamilton Hall',
#   'Enrollment': '51 students (54 max) as of August 31, 2019',
#   'Instructor': 'Bruce Robbins',
#   'course': 'The Literary History of Atrocity',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 40445,
#   'Points': 3,
#   'Day/Time': 'TR 4:10pm-5:25pm',
#   'Location': '702 Hamilton Hall',
#   'Enrollment': '84 students (86 max) as of August 31, 2019',
#   'Instructor': 'Nicholas Dames',
#   'course': '19TH CENTURY EUROPEAN NOVEL',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 10603,
#   'Points': 3,
#   'Day/Time': 'TR 8:40am-9:55am',
#   'Location': '415 Schapiro [SCEP]',
#   'Enrollment': '17 students (35 max) as of August 31, 2019',
#   'Instructor': 'Carter Mathes',
#   'course': 'JAZZ & THE LITERARY IMAGINATN',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 40462,
#   'Points': 4,
#   'Day/Time': 'T 2:10pm-4:00pm',
#   'Location': '612 Philosophy Hall',
#   'Enrollment': '20 students (18 max) as of August 31, 2019 / Full',
#   'Instructor': 'Kathy H Eden',
#   'course': 'THE RHETORICAL TRADITION',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 13542,
#   'Points': 4,
#   'Day/Time': 'R 12:10pm-2:00pm',
#   'Location': '612 Philosophy Hall',
#   'Enrollment': '15 students (15 max) as of August 31, 2019 / Full',
#   'Instructor': 'Matthew Hart',
#   'course': 'The Problem of Late Modernism',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 40448,
#   'Points': 4,
#   'Day/Time': 'R 2:10pm-4:00pm',
#   'Location': '612 Philosophy Hall',
#   'Enrollment': '18 students (18 max) as of August 31, 2019 / Full',
#   'Instructor': 'Stathis Gourgouris',
#   'course': 'THE EPISTEMOLGY OF EDWARD SAID',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 13388,
#   'Points': 4,
#   'Day/Time': 'T 4:10pm-6:00pm',
#   'Location': '612 Philosophy Hall',
#   'Enrollment': '18 students (18 max) as of August 31, 2019 / Full',
#   'Instructor': 'Jack Halberstam',
#   'course': 'Queer Performance Studies',
#   'subject': 'CLEN'},
#  {'number': '001',
#   'Call Number': 10234,
#   'Points': 3,
#   'Day/Time': 'W 4:10pm-6:00pm',
#   'Location': '507 Philosophy Hall',
#   'Enrollment': '20 students (20 max) as of August 31, 2019 / Full',
#   'Instructor': 'Madeleine Dobie',
#   'course': 'Francophone Romance Love, Sex, Intimacy',
#   'subject': 'CLFR'},
#  {'number': '001',
#   'Call Number': 10310,
#   'Points': 3,
#   'Day/Time': 'W 4:10pm-6:00pm',
#   'Location': '411 Kent Hall',
#   'Enrollment': '17 students (25 max) as of August 31, 2019',
#   'Notes': 'In English',
#   'Instructor': 'Annie Pfeifer',
#   'course': 'Dangerous Passions: Collecting, Hoarding',
#   'subject': 'CLGR'},
#  {'number': '001',
#   'Call Number': 54556,
#   'Points': 3,
#   'Day/Time': 'T 2:10pm-4:00pm',
#   'Location': '420 Pupin Laboratories',
#   'Enrollment': '13 students (50 max) as of August 31, 2019',
#   'Instructor': 'Eva Geulen',
#   'course': "Hannah Arendt's Essays (in English)",
#   'subject': 'CLGR'},
#  {'number': '001',
#   'Call Number': 54557,
#   'Points': 3,
#   'Day/Time': 'T 4:10pm-6:00pm',
#   'Location': '302 Fayerweather',
#   'Enrollment': '16 students (30 max) as of August 31, 2019',
#   'Instructor': 'Claudia Breger',
#   'course': 'Aesthetics and Politics Today (in Englis',
#   'subject': 'CLGR'},
#  ...]

# %%
courses = []
for p in paths:    
    courses += getCoursesFromPath(p)
    print(f'Scanned courses for subject {getSubjectFromPath(p)}.')
# Out:
# Scanned courses for subject ACCT.
# Scanned courses for subject ACTU.
# Scanned courses for subject ADDN.
# Scanned courses for subject AFCV.
# Scanned courses for subject AFAS.
# Scanned courses for subject AFRS.
# Scanned courses for subject AFEN.
# Scanned courses for subject AKAD.
# Scanned courses for subject AMST.
# Scanned courses for subject ANAT.
# Scanned courses for subject ANCS.
# Scanned courses for subject ANES.
# Scanned courses for subject ANTH.
# Scanned courses for subject ANHS.
# Scanned courses for subject ANME.
# Scanned courses for subject APAN.
# Scanned courses for subject APCH.
# Scanned courses for subject APMA.
# Scanned courses for subject APPH.
# Scanned courses for subject APAM.
# Scanned courses for subject APBM.
# Scanned courses for subject ARAM.
# Scanned courses for subject ARCH.
# Scanned courses for subject AHIS.
# Scanned courses for subject ASCE.
# Scanned courses for subject ASCM.
# Scanned courses for subject AHUM.
# Scanned courses for subject AHMM.
# Scanned courses for subject ASST.
# Scanned courses for subject ASTR.
# Scanned courses for subject ACLS.
# Scanned courses for subject BHSC.
# Scanned courses for subject BENG.
# Scanned courses for subject BERL.
# Scanned courses for subject BCHM.
# Scanned courses for subject BIET.
# Scanned courses for subject BIOL.
# Scanned courses for subject BMEN.
# Scanned courses for subject BINF.
# Scanned courses for subject BMEB.
# Scanned courses for subject BIST.
# Scanned courses for subject BIOT.
# Scanned courses for subject BCRS.
# Scanned courses for subject BURM.
# Scanned courses for subject BUSI.
# Scanned courses for subject BUEC.
# Scanned courses for subject ECMG.
# Scanned courses for subject CANT.
# Scanned courses for subject CATL.
# Scanned courses for subject CMBS.
# Scanned courses for subject CHEN.
# Scanned courses for subject CHAP.
# Scanned courses for subject CHEE.
# Scanned courses for subject CHEM.
# Scanned courses for subject CHNS.
# Scanned courses for subject CEOR.
# Scanned courses for subject CIEN.
# Scanned courses for subject CIEE.
# Scanned courses for subject CLCV.
# Scanned courses for subject CLLT.
# Scanned courses for subject CLPH.
# Scanned courses for subject CGTH.
# Scanned courses for subject COMM.
# Scanned courses for subject COMH.
# Scanned courses for subject CPLT.
# Scanned courses for subject CPLS.
# Scanned courses for subject CLPS.
# Scanned courses for subject CLCZ.
# Scanned courses for subject CLEN.
# Scanned courses for subject CLFR.
# Scanned courses for subject CLGR.
# Scanned courses for subject CLME.
# Scanned courses for subject CLRS.
# Scanned courses for subject CLSL.
# Scanned courses for subject CLYD.
# Scanned courses for subject CMPM.
# Scanned courses for subject COMS.
# Scanned courses for subject CSEE.
# Scanned courses for subject CSOR.
# Scanned courses for subject CNAD.
# Scanned courses for subject COCI.
# Scanned courses for subject CUBA.
# Scanned courses for subject DNCE.
# Scanned courses for subject DROM.
# Scanned courses for subject DNSC.
# Scanned courses for subject EAEE.
# Scanned courses for subject EESC.
# Scanned courses for subject EAAS.
# Scanned courses for subject EARL.
# Scanned courses for subject EEEB.
# Scanned courses for subject ECON.
# Scanned courses for subject ECHS.
# Scanned courses for subject ECPS.
# Scanned courses for subject EDUC.
# Scanned courses for subject EGYP.
# Scanned courses for subject EEME.
# Scanned courses for subject ECBM.
# Scanned courses for subject ELEN.
# Scanned courses for subject EECS.
# Scanned courses for subject EEBM.
# Scanned courses for subject ENDO.
# Scanned courses for subject ENGI.
# Scanned courses for subject ENME.
# Scanned courses for subject ENGL.
# Scanned courses for subject ENTH.
# Scanned courses for subject ENTA.
# Scanned courses for subject ERMC.
# Scanned courses for subject ENVB.
# Scanned courses for subject EHSC.
# Scanned courses for subject ENVP.
# Scanned courses for subject EPID.
# Scanned courses for subject EXEP.
# Scanned courses for subject CSER.
# Scanned courses for subject EHPS.
# Scanned courses for subject EXSC.
# Scanned courses for subject EXEC.
# Scanned courses for subject EMPA.
# Scanned courses for subject FILI.
# Scanned courses for subject FILM.
# Scanned courses for subject FINC.
# Scanned courses for subject FINN.
# Scanned courses for subject FYSB.
# Scanned courses for subject FREN.
# Scanned courses for subject GSTR.
# Scanned courses for subject GENE.
# Scanned courses for subject GEND.
# Scanned courses for subject GERM.
# Scanned courses for subject GLHL.
# Scanned courses for subject GREK.
# Scanned courses for subject KREY.
# Scanned courses for subject HIFO.
# Scanned courses for subject HPMN.
# Scanned courses for subject HIST.
# Scanned courses for subject HSEA.
# Scanned courses for subject HSJR.
# Scanned courses for subject HSME.
# Scanned courses for subject HSPS.
# Scanned courses for subject HSPP.
# Scanned courses for subject HCM_.
# Scanned courses for subject HRTS.
# Scanned courses for subject HROH.
# Scanned courses for subject HUMA.
# Scanned courses for subject IAIA.
# Scanned courses for subject IMPL.
# Scanned courses for subject INDO.
# Scanned courses for subject IEME.
# Scanned courses for subject IEOR.
# Scanned courses for subject IKNS.
# Scanned courses for subject INSM.
# Scanned courses for subject INTC.
# Scanned courses for subject INAF.
# Scanned courses for subject IRSH.
# Scanned courses for subject ISCS.
# Scanned courses for subject JPNS.
# Scanned courses for subject JWST.
# Scanned courses for subject JOUR.
# Scanned courses for subject KHMR.
# Scanned courses for subject KORN.
# Scanned courses for subject LATN.
# Scanned courses for subject LACV.
# Scanned courses for subject LCRS.
# Scanned courses for subject LAW_.
# Scanned courses for subject LING.
# Scanned courses for subject MGMT.
# Scanned courses for subject MRKT.
# Scanned courses for subject MSAE.
# Scanned courses for subject MATH.
# Scanned courses for subject MATS.
# Scanned courses for subject MTFC.
# Scanned courses for subject MEBM.
# Scanned courses for subject MECH.
# Scanned courses for subject MECE.
# Scanned courses for subject MECS.
# Scanned courses for subject MEDI.
# Scanned courses for subject MRST.
# Scanned courses for subject MICR.
# Scanned courses for subject MDES.
# Scanned courses for subject MUSI.
# Scanned courses for subject NMED.
# Scanned courses for subject NECR.
# Scanned courses for subject NBHV.
# Scanned courses for subject NEUR.
# Scanned courses for subject NSBV.
# Scanned courses for subject NOPM.
# Scanned courses for subject CNNS.
# Scanned courses for subject NURS.
# Scanned courses for subject OBSG.
# Scanned courses for subject OCCT.
# Scanned courses for subject ORCA.
# Scanned courses for subject OPDN.
# Scanned courses for subject OPHT.
# Scanned courses for subject ORBL.
# Scanned courses for subject OHMA.
# Scanned courses for subject ORSG.
# Scanned courses for subject ORTH.
# Scanned courses for subject ORTS.
# Scanned courses for subject PATH.
# Scanned courses for subject PEDI.
# Scanned courses for subject PEDS.
# Scanned courses for subject PDNT.
# Scanned courses for subject PHAR.
# Scanned courses for subject PHIL.
# Scanned courses for subject PHED.
# Scanned courses for subject PHYT.
# Scanned courses for subject PHYS.
# Scanned courses for subject PSLG.
# Scanned courses for subject PLAN.
# Scanned courses for subject POLI.
# Scanned courses for subject POLS.
# Scanned courses for subject POPF.
# Scanned courses for subject PORT.
# Scanned courses for subject PEPM.
# Scanned courses for subject PROS.
# Scanned courses for subject PSCA.
# Scanned courses for subject PSYC.
# Scanned courses for subject PUAF.
# Scanned courses for subject PUBH.
# Scanned courses for subject QMSS.
# Scanned courses for subject RADI.
# Scanned courses for subject REGN.
# Scanned courses for subject EARS.
# Scanned courses for subject REGI.
# Scanned courses for subject REID.
# Scanned courses for subject RELI.
# Scanned courses for subject RSRH.
# Scanned courses for subject RSCH.
# Scanned courses for subject RESI.
# Scanned courses for subject RMAN.
# Scanned courses for subject RUSS.
# Scanned courses for subject SODB.
# Scanned courses for subject SIPA.
# Scanned courses for subject SCNC.
# Scanned courses for subject SCPP.
# Scanned courses for subject SINH.
# Scanned courses for subject SLCL.
# Scanned courses for subject SLLT.
# Scanned courses for subject SOCW.
# Scanned courses for subject SOCI.
# Scanned courses for subject SOSC.
# Scanned courses for subject SOAR.
# Scanned courses for subject SASS.
# Scanned courses for subject SPAN.
# Scanned courses for subject SPJS.
# Scanned courses for subject SPRT.
# Scanned courses for subject STAT.
# Scanned courses for subject STOM.
# Scanned courses for subject SURG.
# Scanned courses for subject SUMA.
# Scanned courses for subject SUSC.
# Scanned courses for subject SDEV.
# Scanned courses for subject SWHL.
# Scanned courses for subject TMGT.
# Scanned courses for subject THTR.
# Scanned courses for subject THEA.
# Scanned courses for subject TIBT.
# Scanned courses for subject UKRN.
# Scanned courses for subject URBS.
# Scanned courses for subject UROL.
# Scanned courses for subject VIET.
# Scanned courses for subject VIAR.
# Scanned courses for subject WLOF.
# Scanned courses for subject WMST.
# Scanned courses for subject YIDD.

# %% [markdown]
# Faculty

# %%
instructors = defaultdict(int)
for s in courses:
    if 'REC' in s['course']:
        continue
    i = s.get('Instructor', None)
    instructors[i] += 1
sortedInstructors = sorted(instructors.items(), key=lambda kv: kv[1], reverse=True)
sortedInstructors
# Out:
# [(None, 1370),
#  ('Faculty', 27),
#  ('Giuseppina C Cambareri', 23),
#  ('Sahng Gyoon Kim', 20),
#  ('Nurit Bittner', 18),
#  ('Jing Chen', 17),
#  ('Sunil Wadhwa', 15),
#  ('Jan Hammerquist', 14),
#  ('David G Vallancourt', 13),
#  ('Hyoseon Lee', 13),
#  ('Sinisa Vukelic', 13),
#  ('Guanhao Sun', 12),
#  ('Kenneth A Lawson', 12),
#  ('Philip Kang', 11),
#  ('Katherine T Fox-Glassman', 11),
#  ('Gerard H Ateshian', 10),
#  ('Kenneth Shepard', 10),
#  ('Matthew E Buckingham', 10),
#  ('Kevin Fellezs', 9),
#  ('Helen Lu', 9),
#  ('Zoran Kostic', 9),
#  ('Gregory M Eirich', 9),
#  ('Michael Como', 9),
#  ('Roseanna Graham', 8),
#  ('Aaron M Kyle', 8),
#  ('Edward F Leonard', 8),
#  ('Katherine Reuther', 8),
#  ('Anna Ghurbanyan', 8),
#  ('Richard W Longman', 8),
#  ('Xiaodong Wang', 8),
#  ('Henry Lam', 8),
#  ('Robert Gooding-Williams', 7),
#  ('Marcus Folch', 7),
#  ('Brian Boyd', 7),
#  ('Lance Kam', 7),
#  ('Elisa Konofagou', 7),
#  ('Medini Singh', 7),
#  ('Christopher J Durning', 7),
#  ('Ioannis Kymissis', 7),
#  ('Christine P Hendon', 7),
#  ('Predrag R Jelenkovic', 7),
#  ('Debasis Mitra', 7),
#  ('Gil Hochberg', 7),
#  ('Gail R Archer', 7),
#  ('Taylor Carman', 7),
#  ('Tamar A Lando', 7),
#  ('Haim Gaifman', 7),
#  ('Judith E Mars', 7),
#  ('Jessica Soursourian', 6),
#  ('Frank Guridy', 6),
#  ('Darcy Krasne', 6),
#  ('Elizabeth Povinelli', 6),
#  ('Daniel Bienstock', 6),
#  ('Matthew P McKelway', 6),
#  ('Arthur Kuflik', 6),
#  ('Claire E Hazen', 6),
#  ('Qi Wang', 6),
#  ('Henry Hess', 6),
#  ('Andreas Hielscher', 6),
#  ('Clark T Hung', 6),
#  ('Christoph Juchem', 6),
#  ('Kam W Leong', 6),
#  ('Paul Sajda', 6),
#  ('Samuel Sia', 6),
#  ('Karthik Natarajan', 6),
#  ('Aurel A Lazar', 6),
#  ('Donna M Hitscherich', 6),
#  ('Robert G Bozic', 6),
#  ('Rachel Austin', 6),
#  ('Raimondo Betti', 6),
#  ('Ethan Katz-Bassett', 6),
#  ('Mingoo Seok', 6),
#  ('Carol Rovane', 6),
#  ('Jill S Shapiro', 6),
#  ('Javad Ghaderi Dehkordi', 6),
#  ('Xiaofan Jiang', 6),
#  ('Dion Khodagholy', 6),
#  ('Michal Lipson', 6),
#  ('Matthias Preindl', 6),
#  ('James Teherani', 6),
#  ('John Wright', 6),
#  ('Andrew C Lipman', 6),
#  ('Dhananjay Jagannathan', 6),
#  ('Julia Doe', 6),
#  ('Elaine Sisman', 6),
#  ('Christopher J Washburne', 6),
#  ('Walter M Frisch', 6),
#  ('Mariusz Kozak', 6),
#  ('Antonius B Dieker', 6),
#  ('Daniel Lacker', 6),
#  ('Shipra Agrawal', 6),
#  ('Ali Hirsa', 6),
#  ('Uday Menon', 6),
#  ('Yi Zhang', 6),
#  ("Christine O'Hea", 6),
#  ('Ilene Strauss', 6),
#  ('Michael W Morris', 6),
#  ('Kristin Myers', 6),
#  ('Matei T Ciocarlie', 6),
#  ('Hod Lipson', 6),
#  ('Aaron A Fox', 6),
#  ('Benjamin A Steege', 6),
#  ('Joseph P Dubiel', 6),
#  ('Mara Berta', 6),
#  ('Panos N Papapanou', 6),
#  ('Christopher Peacocke', 6),
#  ('Justin Clarke-Doane', 6),
#  ('Lydia Goehr', 6),
#  ('Jessica Collins', 6),
#  ('Katja Vogt', 6),
#  ('Lisa K Northrop', 6),
#  ('Kate Thompson', 6),
#  ('Najam I Haider', 6),
#  ('Karina Winn', 6),
#  ('David A Rios', 6),
#  ('Kristie Stack', 6),
#  ('Steven Gregory', 5),
#  ('Elizabeth W Scharffenberger', 5),
#  ('Paraskevi Martzavou', 5),
#  ('John T Ma', 5),
#  ('Kathy H Eden', 5),
#  ('Gareth Williams', 5),
#  ('Joseph A Howley', 5),
#  ('Audra Simpson', 5),
#  ('Myron L Cohen', 5),
#  ("Terence N D'Altroy", 5),
#  ('Marilyn Ivy', 5),
#  ('Michael Taussig', 5),
#  ('Karen Seeley', 5),
#  ('Lila Abu-Lughod', 5),
#  ('Mahmood Mamdani', 5),
#  ('Nadia Abu El-Haj', 5),
#  ('Oleg Gang', 5),
#  ('Siu-Wai Chan', 5),
#  ('Michael J Waters', 5),
#  ('Ioannis Mylonopoulos', 5),
#  ('Diane Bodart', 5),
#  ('Frederique Baumgartner', 5),
#  ('Zoe S Strother', 5),
#  ('Barry G Bergdoll', 5),
#  ('Kellie Jones', 5),
#  ('Vidya Dehejia', 5),
#  ('Janet L Kraynak', 5),
#  ('Laura E Kay', 5),
#  ('Robert L Klitzman', 5),
#  ('Brian Morton', 5),
#  ('Tal Danino', 5),
#  ('X. Edward Guo', 5),
#  ('Elizabeth Hillman', 5),
#  ('Shunichi Homma', 5),
#  ('Joshua Jacobs', 5),
#  ('Andrew Laine', 5),
#  ('Barclay Morrison', 5),
#  ('Nandan L Nerurkar', 5),
#  ('Elizabeth Olson', 5),
#  ('Milan N Stojanovic', 5),
#  ('Stavros Thomopoulos', 5),
#  ('John T Vaughan', 5),
#  ('Gordana Vunjak-Novakovic', 5),
#  ('Nicholas Tatonetti', 5),
#  ('Chunhua Weng', 5),
#  ('Bruce M Usher', 5),
#  ('Andrea Prat', 5),
#  ('Pierre Yared', 5),
#  ('Eli M Noam', 5),
#  ('Kyle Bishop', 5),
#  ('Vivian F McNeill', 5),
#  ('Allie Obermeyer', 5),
#  ("Ben O'Shaughnessy", 5),
#  ('Ah-Hyung Alissa Park', 5),
#  ('Christina Vizcarra', 5),
#  ('Christian Rojas', 5),
#  ('Ioannis Kougioumtzoglou', 5),
#  ('Julius Chang', 5),
#  ('Gautam Dasgupta', 5),
#  ('Hoe I Ling', 5),
#  ('Huiming Yin', 5),
#  ('Shiho Kawashima', 5),
#  ('Bernard Harcourt', 5),
#  ('Donald F Ferguson', 5),
#  ('Gil Zussman', 5),
#  ('Jing Dong', 5),
#  ('Hardeep Johar', 5),
#  ('Vicky Evangelidis-Sakellson', 5),
#  ('Yin Yip Ngai', 5),
#  ('Susan M Elmes', 5),
#  ('Nima Mesgarani', 5),
#  ('Wen I Wang', 5),
#  ('Yannis P Tsividis', 5),
#  ('Harish Krishnaswamy', 5),
#  ('John W Paisley', 5),
#  ('Paola M Valenti', 5),
#  ('Jose Moya', 5),
#  ('Adam Kosto', 5),
#  ('Wolfgang R Mann', 5),
#  ('Agostino Capponi', 5),
#  ('Emanuel Derman', 5),
#  ('Dylan Possamai', 5),
#  ('Karl Sigman', 5),
#  ('Michael Miller', 5),
#  ('Mariana Newman', 5),
#  ('Dongil Keum', 5),
#  ('Nicolas W Chbat', 5),
#  ('Michael Burke', 5),
#  ('Sunil Agrawal', 5),
#  ('Peter J. Schuck', 5),
#  ('James Hone', 5),
#  ('Jeffrey W Kysar', 5),
#  ('Qiao Lin', 5),
#  ('Vijay Modi', 5),
#  ('Fred R Stolfi', 5),
#  ('Y. Lawrence Yao', 5),
#  ('Peter M Susser', 5),
#  ('Akeel Bilgrami', 5),
#  ('Christia Mercer', 5),
#  ('Karen Lewis', 5),
#  ('Axel Honneth', 5),
#  ('Michele Moody-Adams', 5),
#  ('Christopher Caes', 5),
#  ('Sheri Berman', 5),
#  ('Janet Metcalfe', 5),
#  ('Lillian Morales', 5),
#  ('Ronald Mincy', 5),
#  ('Miya Masaoka', 5),
#  ('Ronald Neath', 5),
#  ('Tian Zheng', 5),
#  ('Regina Dolgoarshinnykh', 5),
#  ('Gabriel Camnitzer', 5),
#  ('Tomas Vu Daniel', 5),
#  ('Lina Xu', 4),
#  ('Josef Sorett', 4),
#  ('Deborah Steiner', 4),
#  ('John Pemberton', 4),
#  ('Lesley Sharp', 4),
#  ('Camilla Sturm', 4),
#  ('Rosalind Morris', 4),
#  ('Maria Jos de Abreu', 4),
#  ('Zoe Crossland', 4),
#  ('Paige West', 4),
#  ('Ellen Marakowitz', 4),
#  ('Brinkley Messick', 4),
#  ('David Scott', 4),
#  ('chris wiggins', 4),
#  ('Nanfang Yu', 4),
#  ('Michael E Mauel', 4),
#  ('Alexander Gaeta', 4),
#  ('Gregory Bryda', 4),
#  ('Zeynep Celik', 4),
#  ('Jonathan Reynolds', 4),
#  ('Rosalyn Deutsche', 4),
#  ('Alexander Alberro', 4),
#  ('Elizabeth Hutchinson', 4),
#  ('Michael Cole', 4),
#  ('Rosalind Krauss', 4),
#  ('John Rajchman', 4),
#  ('Branden W Joseph', 4),
#  ('Avinoam Shalem', 4),
#  ('Rachel McDermott', 4),
#  ('Ron M Prywes', 4),
#  ('Olena Mamykina', 4),
#  ('Adler J Perotte', 4),
#  ('Suzanne Bakken', 4),
#  ('Yufeng Shen', 4),
#  ('Jonas K Hjort', 4),
#  ('Amit K Khandelwal', 4),
#  ('Scott Banta', 4),
#  ('Alexander Urban', 4),
#  ('Christopher M Boyce', 4),
#  ('Jingguang Chen', 4),
#  ('Daniel Esposito', 4),
#  ('Sanat Kumar', 4),
#  ('Dan Steingart', 4),
#  ('Venkat Venkatasubramanian', 4),
#  ('Alan West', 4),
#  ('Aaron Moment', 4),
#  ('Luis A Avila', 4),
#  ('Dina C Merrer', 4),
#  ('Andrew C Crowther', 4),
#  ('Xuan Di', 4),
#  ('Maria Q Feng', 4),
#  ('Upmanu Lall', 4),
#  ('Haim Waisman', 4),
#  ('Jacob Fish', 4),
#  ('Waiching Sun', 4),
#  ('Marco Giometto', 4),
#  ('Adrian Brugger', 4),
#  ('Ibrahim Odeh', 4),
#  ('Kartik Chandran', 4),
#  ('Ethan Pew', 4),
#  ('Liza Knapp', 4),
#  ('Yuri Shevchuk', 4),
#  ('Agnieszka Legutko', 4),
#  ('Tony B Dear', 4),
#  ('Clifford Stein', 4),
#  ('Courtney Bender', 4),
#  ('Michael F Stanislawski', 4),
#  ('Daniel J Russo', 4),
#  ('Omar Besbes', 4),
#  ('Ciamac Moallemi', 4),
#  ('Jennifer P Bassiur', 4),
#  ('James B Fine', 4),
#  ('Terryanne Maenza-Gmelch', 4),
#  ('Sedelia Rodriguez', 4),
#  ('Bernard Faure', 4),
#  ('Dimitris Anastassiou', 4),
#  ('Keren Bergman', 4),
#  ('Shih-Fu Chang', 4),
#  ('Peter Kinget', 4),
#  ('Charles A Zukowski', 4),
#  ('Richard A Pena', 4),
#  ('Maureen A Ryan', 4),
#  ('Jack Lechner', 4),
#  ('Ira Deutchman', 4),
#  ('Lisa K Son', 4),
#  ('Marc Van de Mieroop', 4),
#  ('Lisa Tiersten', 4),
#  ('Samuel K Jr Roberts', 4),
#  ('George Chauncey', 4),
#  ('Lien-Hang Nguyen', 4),
#  ('Natasha J Lightfoot', 4),
#  ('Rashid I Khalidi', 4),
#  ('Clemence C Boulouque', 4),
#  ('Vineet Goyal', 4),
#  ('Adam N Elmachtoub', 4),
#  ('Donald Goldfarb', 4),
#  ('Soulaymane Kachani', 4),
#  ('Jay Sethuraman', 4),
#  ('Ward Whitt', 4),
#  ('David D Yao', 4),
#  ('Xunyu Zhou', 4),
#  ('Dana L Wolf', 4),
#  ('Folarin Odusola', 4),
#  ('Sidney Eisig', 4),
#  ('Hyunkyu Yi', 4),
#  ('Norman Bartczak', 4),
#  ('Brett Dignam', 4),
#  ('Richard Slusarczyk', 4),
#  ('Michael J Massimino', 4),
#  ('Arvind Narayanaswamy', 4),
#  ('Karen Kasza', 4),
#  ('Bradford G Garton', 4),
#  ('Rashaun White', 4),
#  ("E'Mett McCaskill", 4),
#  ('Ivana N Hughes', 4),
#  ('Arlene M Smaldone', 4),
#  ('Patricia Kitcher', 4),
#  ('Sebastian Will', 4),
#  ('Matthew A Carr', 4),
#  ('Donald P Casler', 4),
#  ('Adam M Parker', 4),
#  ('Severine Autesserre', 4),
#  ('Kathleen M Taylor', 4),
#  ('Kara Pham', 4),
#  ('Danielle L Sussan', 4),
#  ('Nim L Tottenham', 4),
#  ('Mark C Taylor', 4),
#  ('Gale L Kenny', 4),
#  ('Derek Mancini-Lander', 4),
#  ('Tiffany Hale', 4),
#  ('John S Hawley', 4),
#  ('Kenyon S Saverance', 4),
#  ('Emanuele Gerratana', 4),
#  ('John G Robertson', 4),
#  ('Rick Greenberg', 4),
#  ('Wadda Rios-Font', 4),
#  ('Seth R Kimmel', 4),
#  ('Banu Baydil', 4),
#  ('Wayne Lee', 4),
#  ('Gabriel Young', 4),
#  ('Thibault Vatter', 4),
#  ('Gisela D Cardenas Ojeda', 4),
#  ('Renee Cox', 4),
#  ('Susanna Coffey', 4),
#  ('Dana M Deguilio', 4),
#  ('Joseph J Peet', 4),
#  ('Jon Kessler', 4),
#  ('Jennifer Nuss', 4),
#  ('Gregory Amenoff', 4),
#  ('Shelly Silver', 4),
#  ('Rirkrit Tiravanija', 4),
#  ('Matthias Breuer', 3),
#  ('Jonathan Glover', 3),
#  ('Farah Griffin', 3),
#  ('Casey Blake', 3),
#  ('Hilary-Anne Hallett', 3),
#  ('Elizabeth K Irwin', 3),
#  ('Severin Fowles', 3),
#  ('Naor H Ben-Yehoyada', 3),
#  ('Nan A Rothschild', 3),
#  ('Partha Chatterjee', 3),
#  ('Claudio Lomnitz', 3),
#  ('Brian Larkin', 3),
#  ('David Kreutter', 3),
#  ('Francois Scharffe', 3),
#  ('David Shilane', 3),
#  ('Jessica E Oehrlein', 3),
#  ('Chanyang Ryoo', 3),
#  ('Hwi Lee', 3),
#  ('Yuan He', 3),
#  ('Michael I Weinstein', 3),
#  ('Qiang Du', 3),
#  ('Kui Ren', 3),
#  ('Lorenzo M Polvani', 3),
#  ('Latha Venkataraman', 3),
#  ('Cheng S Wuu', 3),
#  ('William Bailey', 3),
#  ('Katayun Barmak', 3),
#  ('Simon Billinge', 3),
#  ('Chris A Marianetti', 3),
#  ('Anooradha I Siddiqi', 3),
#  ('Anne Higonnet', 3),
#  ('Jonathan K Crary', 3),
#  ('Francesco de Angelis', 3),
#  ('Dawn H Delbanco', 3),
#  ('David A Freedberg', 3),
#  ('Meredith Gamer', 3),
#  ('Robert Harrist', 3),
#  ('Eleonora Pistis', 3),
#  ('Zainab Bahrani', 3),
#  ('Holger A Klein', 3),
#  ('Noam M Elcott', 3),
#  ('Ulug Kuzuoglu', 3),
#  ('Nathanael P Shelley', 3),
#  ('Jue Guo', 3),
#  ('Nicholas A Bartlett', 3),
#  ('Jennifer M Gumer', 3),
#  ('David N Hoffman', 3),
#  ('Jonathan Engel', 3),
#  ('Sameer H Ladha', 3),
#  ('Alice Heicklen', 3),
#  ('Hilary Callahan', 3),
#  ('Christian W Schindler', 3),
#  ('Jonathan Snow', 3),
#  ('Elizabeth P Bauer', 3),
#  ('John Glendinning', 3),
#  ('Lili Yamasaki', 3),
#  ('Dennis Vitkup', 3),
#  ('David K Vawdrey', 3),
#  ('Predrag Obucina', 3),
#  ('Gur Huberman', 3),
#  ('Marco Viola', 3),
#  ('John Donaldson', 3),
#  ('Charles Angelucci', 3),
#  ('Shang-Jin Wei', 3),
#  ('Elsa Ubeda', 3),
#  ('Jingyue Ju', 3),
#  ('Lauren E Marbella', 3),
#  ('Ponisseril Somasundaran', 3),
#  ('Vesna Gasperov', 3),
#  ('Marisa C Buzzeo', 3),
#  ('Michael Campbell', 3),
#  ('Patricia J Culligan', 3),
#  ('Helene P Foley', 3),
#  ('Saskia J Sassen', 3),
#  ('Jesse L Scinto', 3),
#  ('Kavita Ahluwalia', 3),
#  ('Alfred Mac Adam', 3),
#  ('Adam H Cannon', 3),
#  ('Xi Chen', 3),
#  ('Yassine Benajiba', 3),
#  ('Carl Vondrick', 3),
#  ('Alexandr Andoni', 3),
#  ('Eleni Drinea', 3),
#  ('Nadia Urbinati', 3),
#  ('Ana P Lee', 3),
#  ('Richard John', 3),
#  ('Matthew Engelke', 3),
#  ('Mary Carpenter', 3),
#  ('Caitlin Trainor', 3),
#  ('Marjorie Folkman', 3),
#  ('Maguette Camara', 3),
#  ('Colleen Thomas', 3),
#  ('Charles R Guetta', 3),
#  ('Letty Moss-Salentijn', 3),
#  ('Michael A Perrino', 3),
#  ('Vasilis Fthenakis', 3),
#  ('Paul E Olsen', 3),
#  ('Peter Kelemen', 3),
#  ('Peter M Bower', 3),
#  ('Matthew I Palmer', 3),
#  ('Prajit K Dutta', 3),
#  ('Tamrat Gashaw', 3),
#  ('Randall Reback', 3),
#  ('Alan Dye', 3),
#  ('Pierre-Andre Chiappori', 3),
#  ('Olivier M Darmouni', 3),
#  ('Alessandra Casella', 3),
#  ('Lisa Edstrom', 3),
#  ('Janet Kayfetz', 3),
#  ('Meredith A Benjamin', 3),
#  ('Andrew L Lynn', 3),
#  ('Benjamin M Breyer', 3),
#  ('Alexandra P Watson', 3),
#  ('Wendy C Schor-Haim', 3),
#  ('Margaret R Ellsberg', 3),
#  ('Margaret S Vandenburg', 3),
#  ('Patricia D Denison', 3),
#  ('William B Worthen', 3),
#  ('Shayoni Mitra', 3),
#  ('James Bone', 3),
#  ('David J Romoff', 3),
#  ('Batya O Elul', 3),
#  ('Elizabeth Blackmar', 3),
#  ('Lucius J Riccio', 3),
#  ('Richard K Betts', 3),
#  ('Ronald Gregg', 3),
#  ('Annette Insdorf', 3),
#  ('James A Schamus', 3),
#  ('Jane Gaines', 3),
#  ('Kairong Xiao', 3),
#  ('Daniel Wolfenzon', 3),
#  ('Mahadevan S Sundaresan', 3),
#  ('Harry Mamaysky', 3),
#  ('Paul Tetlock', 3),
#  ('Stijn G Van Nieuwerburgh', 3),
#  ('Laurie Postlewate', 3),
#  ('Holly Myers', 3),
#  ('Hadley T Suter', 3),
#  ('Sarah J Lazur', 3),
#  ('Hayet Sellami', 3),
#  ('Pascale Crepon', 3),
#  ('Eric T Matheis', 3),
#  ('Sophie Queuniet', 3),
#  ('Brian S Kilgo-Kelly', 3),
#  ('Karen Santos da Silva', 3),
#  ("Brian D O'Keeffe", 3),
#  ('Gabriela Badea', 3),
#  ('Christopher B Wood', 3),
#  ('Alexandra Borer', 3),
#  ('Silja Weber', 3),
#  ('Peter A Muennig', 3),
#  ('Joel Kaye', 3),
#  ('Deborah Valenze', 3),
#  ('Camille A Robcis', 3),
#  ('Matthew L Jones', 3),
#  ('Matthew J Connelly', 3),
#  ('Gregory Mann', 3),
#  ('Kenneth T Jackson', 3),
#  ('Christopher L Brown', 3),
#  ('Lara J Nettelfield', 3),
#  ('Ana M Fernandez Cebrian', 3),
#  ('Magdalena Baczewska', 3),
#  ('Hisham Aidi', 3),
#  ('Efrat Nechushtai', 3),
#  ('Yuri Faenza', 3),
#  ('Garud Iyengar', 3),
#  ('Cedric Josz', 3),
#  ('Jenny S Mak', 3),
#  ('Van Anh Truong', 3),
#  ('Allan M Malz', 3),
#  ('Maria Ignac Mercadal Albornoz', 3),
#  ('Timothy Mitchell', 3),
#  ('S. Akbar Zaidi', 3),
#  ('Yuka Nakazato', 3),
#  ('Kyoko M Loetscher', 3),
#  ('Naofumi Tatsumi', 3),
#  ('Shigeru Eguchi', 3),
#  ('Michael Schudson', 3),
#  ('Ji-Young Jung', 3),
#  ('Beom Lee', 3),
#  ('Hunter Whaley', 3),
#  ('Elena D Neascu', 3),
#  ('Alice Izumo', 3),
#  ('Mark Barenberg', 3),
#  ('Michael Gerrard', 3),
#  ('Lori F Damrosch', 3),
#  ('Jane M Spinak', 3),
#  ('Alexandra B Carter', 3),
#  ('Aharon Levy', 3),
#  ('Vanessa Burbano', 3),
#  ('William R Duggan', 3),
#  ('Todd D Jick', 3),
#  ('Silvia Bellezza', 3),
#  ('Keith Wilcox', 3),
#  ('Dusa McDuff', 3),
#  ('Lars T Nielsen', 3),
#  ('Charry Karamanoukian', 3),
#  ('Tyler M Richard', 3),
#  ('Illan Gonen', 3),
#  ('Aftab Ahmad', 3),
#  ('Michelle M Quay', 3),
#  ('Saeed Honarmand', 3),
#  ('Georg Friedrich Haas', 3),
#  ('Jose Pascal da Rocha', 3),
#  ('Peter D Balsam', 3),
#  ('Carlos Ponce', 3),
#  ('Erwin Vincent de Leon', 3),
#  ('Gregory Witkowski', 3),
#  ('Heidi Hahn-Schroeder', 3),
#  ('Ana I Esteban Gonzalez', 3),
#  ('Judy Honig', 3),
#  ('Christian Cansino', 3),
#  ('Sabrina Petrillo', 3),
#  ('Deanna M Schneider', 3),
#  ('Maribeth L Massie', 3),
#  ('Eileen J Carter', 3),
#  ('Donald R Jr Boyd', 3),
#  ('Maureen George', 3),
#  ('Patricia Stone', 3),
#  ('Jacqueline C Merrill-Matzner', 3),
#  ('Dawn Nilsen', 3),
#  ('Sharon Gutman', 3),
#  ('Lenin Grajo', 3),
#  ('Katherine Dimitropoulou', 3),
#  ('Amy A Starecheski', 3),
#  ('Kyle Driggers', 3),
#  ('Laura Masone', 3),
#  ('Debra Krasinski', 3),
#  ('Jeremy R Dodd', 3),
#  ('Lance M Freeman', 3),
#  ('Nikhar Gaikwad', 3),
#  ('Jon Elster', 3),
#  ('Jose A Castellanos-Pazos', 3),
#  ('Ana P Huback', 3),
#  ('Alfredo Spagna', 3),
#  ('Norma V Graham', 3),
#  ('Mariam Aly', 3),
#  ('Caroline B Marvin', 3),
#  ('Valerie J Purdie-Greenaway', 3),
#  ('Glenn Denning', 3),
#  ('Michael Parrott', 3),
#  ('Gil Anidjar', 3),
#  ('Beth A Berkowitz', 3),
#  ('Elizabeth Castelli', 3),
#  ('David R Kittay', 3),
#  ('Thomas F Yarnall', 3),
#  ('Melanie Barrett', 3),
#  ('Alan S Yang', 3),
#  ('Doru Cojoc', 3),
#  ('Neeraj Kaushal', 3),
#  ('Qin Gao', 3),
#  ('Ada C Mui', 3),
#  ('Mashura Akilova', 3),
#  ('Richard T Hara', 3),
#  ('Jalana Harris', 3),
#  ('Amy S Kapadia', 3),
#  ('Yamile M Marti Haidar', 3),
#  ('Deborah Becher', 3),
#  ('Elizabeth Bernstein', 3),
#  ('Debra Minkoff', 3),
#  ('Jonathan Rieder', 3),
#  ('Denise Milstein', 3),
#  ('Kim J Hopper', 3),
#  ('Francisca Aguilo Mora', 3),
#  ('Juan P Jimenez-Caicedo', 3),
#  ('Francisco Rosales-Varo', 3),
#  ('Guadalupe Ruiz-Fajardo', 3),
#  ('Antoni Fernandez Parera', 3),
#  ('Juan Pablo Cominguez', 3),
#  ('Diana Romero', 3),
#  ('Irene Alonso-Aparicio', 3),
#  ('Francisco Meizoso', 3),
#  ('Dolores Barbazan Capeans', 3),
#  ('Reyes Llopis-Garcia', 3),
#  ('Maria E Lozano', 3),
#  ('Leonor Pons Coll', 3),
#  ('Lorena Garcia Barroso', 3),
#  ('Leyre Alejaldre Biel', 3),
#  ('Maria I Arce-Fernandez', 3),
#  ('Ronald D Briggs', 3),
#  ('Karen Benezra', 3),
#  ('Alberto Medina', 3),
#  ('Graciela Montaldo', 3),
#  ('Grant J Son', 3),
#  ('Hammou Elbarmi', 3),
#  ('Demissie Alemayehu', 3),
#  ('Abdul Nanji', 3),
#  ('Michael Banta', 3),
#  ('Sonam Tsering', 3),
#  ('Christian Siener', 3),
#  ('Mary Rocco', 3),
#  ('Nathan N Catlin', 3),
#  ('Mariame S Sy', 3),
#  ('Trevor S Harris', 2),
#  ('Alon Kalay', 2),
#  ('Mortiz Hiemannn', 2),
#  ('Thomas Bourveau', 2),
#  ('Joseph M Mc Manus Jr', 2),
#  ('Elleni Zeleke', 2),
#  ('Abosede A George', 2),
#  ('Kim F Hall', 2),
#  ('Kaiama L Glover', 2),
#  ('Colin Leach', 2),
#  ('Bernabe S Mendoza', 2),
#  ('Manu M Vimalassery', 2),
#  ('Roosevelt Montas', 2),
#  ('Chisa Hidaka', 2),
#  ('Gretchen Pfeil', 2),
#  ('Vanessa L Agard-Jones', 2),
#  ('Patrick F Nason', 2),
#  ('J.C. Salyer', 2),
#  ('Catherine Fennell', 2),
#  ('Ralph L Holloway', 2),
#  ('Lori Cenci', 2),
#  ('Guilherme de Oliveira', 2),
#  ('Shekhar Pradhan', 2),
#  ('Siddhartha Dalal', 2),
#  ('Paula Darling', 2),
#  ('Murwa Farah', 2),
#  ('Drew C Youngren', 2),
#  ('Marc W Spiegelman', 2),
#  ('Kyle Mandli', 2),
#  ('Andrew Cole', 2),
#  ('Peter Caracappa', 2),
#  ('Aron Pinczuk', 2),
#  ('Gerald A Navratil', 2),
#  ('Klaus A Hamacher', 2),
#  ('Irving P Herman', 2),
#  ('Ismail C Noyan', 2),
#  ('Yuan Yang', 2),
#  ('Stephane A Charitos', 2),
#  ('Kadambari Baxi', 2),
#  ('Danielle S Smoller', 2),
#  ('Ana Puigjaner Barbera', 2),
#  ('Hilary M Sample-Meredith', 2),
#  ('Joshua D Uhl', 2),
#  ('Andrew S Dolkart', 2),
#  ('Mark Wasiuta', 2),
#  ('Mabel O Wilson', 2),
#  ('David E Benjamin', 2),
#  ('Richard A Plunz', 2),
#  ('Reinhold Martin', 2),
#  ('Mark Wigley', 2),
#  ('Paul Segal', 2),
#  ('Felicity Scott', 2),
#  ('Enrique Walker', 2),
#  ('John H Locke', 2),
#  ('Angel Jiang', 2),
#  ('Irena Haiduk', 2),
#  ('John Miller', 2),
#  ('Simon Schama', 2),
#  ('Lisa Trever', 2),
#  ('Christopher F Kim', 2),
#  ('Chuan Xu', 2),
#  ('Tenzin Y Dongchung', 2),
#  ('David B Lurie', 2),
#  ('John D Phan', 2),
#  ('Nicolle M Bertozzi', 2),
#  ('Chun Kiang I Tan', 2),
#  ('Lanxin Zhang', 2),
#  ('Cameron Foltz', 2),
#  ('No Name Given Palden', 2),
#  ('Dongming Wu', 2),
#  ('Matthew L Keegan', 2),
#  ('Elaine Van Dalen', 2),
#  ('Seong-Uk Kim', 2),
#  ('Caleb Scharf', 2),
#  ('Zoltan Haiman', 2),
#  ('Dwijen Bhattacharjya', 2),
#  ('Brent R Stockwell', 2),
#  ('Barbra Rothschild', 2),
#  ('Joel Roselin', 2),
#  ('Harriet A Washington', 2),
#  ('Paul E Hertz', 2),
#  ('Alison Pischedda', 2),
#  ('Jian Yang', 2),
#  ('Jeannette C Bulinski', 2),
#  ('Jj L Miranda', 2),
#  ('Jennifer H Mansfield', 2),
#  ('Sivan Kinberg', 2),
#  ('Noemie Elhadad', 2),
#  ('Raul Rabadan', 2),
#  ('Rita Kukafka', 2),
#  ('Qixuan Chen', 2),
#  ("Debra D'Angelo", 2),
#  ('Ran Kivetz', 2),
#  ('Andreas Kakolyris', 2),
#  ('Edward F Pasquina', 2),
#  ('Jacqueline Strayer', 2),
#  ('Ric Oslin', 2),
#  ('Michael E Jr McGuire', 2),
#  ('Joris Magenti', 2),
#  ('Perry Beaumont', 2),
#  ('Matthew Frederick', 2),
#  ('Delores Amorelli', 2),
#  ('Guy St. Clair', 2),
#  ('Kamel Jedidi', 2),
#  ('Bruce Kogut', 2),
#  ('Elizabeth Elam', 2),
#  ('Geoffrey M Heal', 2),
#  ('Patrice Spitalnik', 2),
#  ('Kenneth Spall', 2),
#  ('Karen E Phillips', 2),
#  ('Fay W Ng', 2),
#  ('Jean Vadakkan', 2),
#  ('Subhasish Chatterjee', 2),
#  ('Chen Wu', 2),
#  ('Lingjun Hu', 2),
#  ('Tianqi Jiang', 2),
#  ('Ling Yan', 2),
#  ('Hailong Wang', 2),
#  ('Jia Xu', 2),
#  ('Shaoyan Qi', 2),
#  ('Junli Shen', 2),
#  ('Zhirong Wang', 2),
#  ('Zhong Qi Shi', 2),
#  ('Yuan-Yuan Meng', 2),
#  ('Lening Liu', 2),
#  ('Feng Li', 2),
#  ('Tom T Panayotidi', 2),
#  ('George Deodatis', 2),
#  ('Philip White', 2),
#  ('Ellen Morris', 2),
#  ('Joe Sheppard', 2),
#  ('Alexandra M Merceron', 2),
#  ('Kaireem D Wright', 2),
#  ('Juli Falkoff', 2),
#  ('Frank J Oswald', 2),
#  ('Kevin Visconti', 2),
#  ('Andrew Whitehouse', 2),
#  ('Emily Sun', 2),
#  ('Erk Grimm', 2),
#  ('Hisham Matar', 2),
#  ('Hana Worthen', 2),
#  ('Nancy Worman', 2),
#  ('Etienne Balibar', 2),
#  ('Christopher C Baswell', 2),
#  ('Jenny M Davidson', 2),
#  ('Nicholas Dames', 2),
#  ('Matthew Hart', 2),
#  ('Annie Pfeifer', 2),
#  ('Claudia Breger', 2),
#  ('Muhsin Al-Musawi', 2),
#  ('Sarah Bin Tyeer', 2),
#  ('Paul S Blaer', 2),
#  ('Robert E Coyne', 2),
#  ('Gary Zamchick', 2),
#  ('Daniel Bauer', 2),
#  ('Jae W Lee', 2),
#  ('Ansaf Salleb-Aouissi', 2),
#  ('Omri Weinstein', 2),
#  ('Roxana Geambasu', 2),
#  ('Jason Nieh', 2),
#  ('Suman Jana', 2),
#  ('Tal Malkin', 2),
#  ('Daniel Hsu', 2),
#  ('Kriste Krstovski', 2),
#  ('Tristan Boutros', 2),
#  ('Iddo Drori', 2),
#  ('Salvatore J Stolfo', 2),
#  ('Steven M Bellovin', 2),
#  ('Homayoon S Beigi', 2),
#  ('Martha A Kim', 2),
#  ('Charles J McNamara', 2),
#  ('Jason Z Resnikoff', 2),
#  ('Adam Leeds', 2),
#  ('Ruairidh J Macleod', 2),
#  ('Dennis Tenen', 2),
#  ('Julie Crawford', 2),
#  ('Lamyu M Bo', 2),
#  ('Thomas Dodman', 2),
#  ('Nicole A Callahan', 2),
#  ('Gal Katz', 2),
#  ('Richard A Billows', 2),
#  ('Susan Pedersen', 2),
#  ('Catherine Evtuhov', 2),
#  ('Daniel M del Nido', 2),
#  ('Lars T Heisenberg', 2),
#  ('Michelle Chun', 2),
#  ('Emmanuelle Saada', 2),
#  ('Vincent McCloskey', 2),
#  ('Kathryn Sullivan', 2),
#  ('Katiti King', 2),
#  ('Caroline Fermin', 2),
#  ('Margaret J Morrison', 2),
#  ('Antonio Carmena', 2),
#  ('Ashley Tuttle', 2),
#  ('Cynthia Anderson', 2),
#  ('Uttara Coorlawala', 2),
#  ('Gabri Christa', 2),
#  ('Assaf Zeevi', 2),
#  ('Linda V Green', 2),
#  ('David A Albert', 2),
#  ('King Chan', 2),
#  ('Athanasios Bourtsalas', 2),
#  ('Peter Eisenberger', 2),
#  ('Robert Farrauto', 2),
#  ('Pierre Gentine', 2),
#  ('Brian Mailloux', 2),
#  ('Martin Stute', 2),
#  ('Kaleigh B Matthews', 2),
#  ('Ying Qian', 2),
#  ('Gregory Pflugfelder', 2),
#  ('Takuya Tsunoda', 2),
#  ('Tomi Suzuki', 2),
#  ('Sara Kross', 2),
#  ('Sunil K Gulati', 2),
#  ('Rajiv Sethi', 2),
#  ('Homa S Zarghamee', 2),
#  ('Sharon Harrison', 2),
#  ('Anja Tolonen', 2),
#  ('Belinda Archibong', 2),
#  ('Martina Jasova', 2),
#  ('Wouter R Vergote', 2),
#  ('Xavier Sala-I-Martin', 2),
#  ('Ronald Miller', 2),
#  ('Seyhan Erden', 2),
#  ('Jushan Bai', 2),
#  ('Irasema Alonso', 2),
#  ('Tri Vi Dang', 2),
#  ('John Marshall', 2),
#  ('Serena Ng', 2),
#  ('Lena Edlund', 2),
#  ('Matthieu Gomez', 2),
#  ('Michael C Best', 2),
#  ('Chandler Miranda', 2),
#  ('Erika Kitzmiller', 2),
#  ('Amelia S Herbert', 2),
#  ('Corinne D Kentor', 2),
#  ('Thea Abu El-Haj', 2),
#  ('Rachel Throop', 2),
#  ('Alexei Ashikhmin', 2),
#  ('Ching-Yung Lin', 2),
#  ('Alan S Kennedy', 2),
#  ('Allen C Durgin', 2),
#  ('Alessia Palanti', 2),
#  ('Rebecca Wisor', 2),
#  ('Kristie Schlauraff', 2),
#  ('Valeria A Tsygankova', 2),
#  ('Vanessa D Guida', 2),
#  ('Penelope Usher', 2),
#  ('Cecelia B Lie-Spahn', 2),
#  ('Vrinda Condillac', 2),
#  ('Duyga Ula', 2),
#  ('Mary Gordon', 2),
#  ('Nellie G Hermann', 2),
#  ('Rachel Eisendrath', 2),
#  ('Ross T Hamilton', 2),
#  ('Timea Szell', 2),
#  ('Rebecca J Hildebrand', 2),
#  ('Lisa Gordis', 2),
#  ('Monica F Cohen', 2),
#  ('Maura L Spiegel', 2),
#  ('Atefeh Akbari Shahmirzadi', 2),
#  ('Maria D Hinojosa', 2),
#  ('Lauren E Robertson', 2),
#  ('Molly Murray', 2),
#  ('Edward Mendelson', 2),
#  ('David M Yerkes', 2),
#  ('Kristin Carter', 2),
#  ('Joseph Albernaz', 2),
#  ('Ross Posnock', 2),
#  ('Hannah Weaver', 2),
#  ('John H McWhorter', 2),
#  ('James E Adams', 2),
#  ('Michael Zwecher', 2),
#  ('Christakis Droussiotis', 2),
#  ('Sim Segal', 2),
#  ('Jay Newberry', 2),
#  ('Rich Lauria', 2),
#  ('Violet Diamant', 2),
#  ('Julianne M Kasinow', 2),
#  ('Jennifer Hoffman', 2),
#  ('Daniel D Walker', 2),
#  ('Patricio Contreras', 2),
#  ('Kamyar K Moud', 2),
#  ('Greg A Freyer', 2),
#  ('Jeremy Porter', 2),
#  ('Adela J Gondek', 2),
#  ('Sara Tjossem', 2),
#  ('Steven Cohen', 2),
#  ('Silvia Martins', 2),
#  ('Thelma Mielenz', 2),
#  ('Stephen S Morse', 2),
#  ('Anne Paxton', 2),
#  ('Sharon B Schwartz', 2),
#  ('Sayantani T Dasgupta', 2),
#  ('Karl Jacoby', 2),
#  ('Tsveta A Petrova', 2),
#  ('Matthew J Neidell', 2),
#  ('Jeanne M Stellman', 2),
#  ('Yuna S Lee', 2),
#  ('Paul W Thurman', 2),
#  ('Yumiko T Shimabukuro', 2),
#  ('William B Eimicke', 2),
#  ('Rubeintz Philippe', 2),
#  ('Breixo Viejo Vinas', 2),
#  ('Andrew S Bienen', 2),
#  ('Jamal Joseph', 2),
#  ('Susan Korda', 2),
#  ('Michael J Cacioppo Belantara', 2),
#  ('Adam Marchand', 2),
#  ('Hanna Seifu', 2),
#  ('Katherine Dieckmann', 2),
#  ('Christina Lazaridi', 2),
#  ('Lance Weiler', 2),
#  ('Geert Bekaert', 2),
#  ('Paul Johnson', 2),
#  ('Angela W Lee', 2),
#  ('Jay Dahya', 2),
#  ('Edward Zimmerman', 2),
#  ('Mark S Vecchio', 2),
#  ('Brian P Lancaster', 2),
#  ('Michael Johannes', 2),
#  ('Heli Sirvioe', 2),
#  ('Patricia D Stokes', 2),
#  ('Alexandre Bournery', 2),
#  ('Elsa Stephan', 2),
#  ('Pascale Hubert-Leibler', 2),
#  ('Laurence Marie', 2),
#  ...]

# %%
[c for c in courses if c.get('Instructor', None) == 'Helen Lu']
# Out:
# [{'number': '017',
#   'Call Number': 43326,
#   'Points': '1-3',
#   'Enrollment': '0 students (50 max) as of August 31, 2019',
#   'Instructor': 'Helen Lu',
#   'course': 'PROJECTS IN BIOMEDICAL ENGIN',
#   'subject': 'BMEN'},
#  {'number': '001',
#   'Call Number': 43420,
#   'Points': '1-2',
#   'Enrollment': '0 students (45 max) as of August 31, 2019',
#   'Instructor': 'Helen Lu',
#   'course': 'UNDERGRADUATE FIELDWORK',
#   'subject': 'BMEN'},
#  {'number': '001',
#   'Call Number': 43412,
#   'Points': '1-2',
#   'Enrollment': '1 student (45 max) as of August 31, 2019',
#   'Instructor': 'Helen Lu',
#   'course': 'FIELDWORK',
#   'subject': 'BMEN'},
#  {'number': '001',
#   'Call Number': 43415,
#   'Points': 3,
#   'Day/Time': 'T 10:10am-12:40pm',
#   'Location': '343 Seeley W. Mudd Building',
#   'Enrollment': '25 students (25 max) as of August 31, 2019 / Full',
#   'Instructor': 'Helen Lu',
#   'course': 'ADV SCAFFOLD DES/COMPLX TISSUE',
#   'subject': 'BMEN'},
#  {'number': '017',
#   'Call Number': 43437,
#   'Points': '1-6',
#   'Enrollment': '2 students (50 max) as of August 31, 2019',
#   'Instructor': 'Helen Lu',
#   'course': 'MASTERS RESEARCH',
#   'subject': 'BMEN'},
#  {'number': '017',
#   'Call Number': 43361,
#   'Points': '1-6',
#   'Enrollment': '1 student (50 max) as of August 31, 2019',
#   'Instructor': 'Helen Lu',
#   'course': 'DOCTORAL RESEARCH',
#   'subject': 'BMEN'},
#  {'number': '017',
#   'Call Number': 43390,
#   'Points': '3-12',
#   'Enrollment': '0 students (50 max) as of August 31, 2019',
#   'Instructor': 'Helen Lu',
#   'course': 'DOCTORAL RESEARCH INSTRUCTION',
#   'subject': 'BMEN'},
#  {'number': '017',
#   'Call Number': 43466,
#   'Points': 0,
#   'Enrollment': '0 students (50 max) as of August 31, 2019',
#   'Instructor': 'Helen Lu',
#   'course': 'DOCTORAL DISSERTATION',
#   'subject': 'BMEN'},
#  {'number': '001',
#   'Call Number': 56456,
#   'Points': 1,
#   'Day/Time': 'F 10:10am-12:00pm',
#   'Location': '524 Seeley W. Mudd Building',
#   'Enrollment': '20 students (20 max) as of August 31, 2019 / Full',
#   'Instructor': 'Helen Lu',
#   'course': 'EGLESTON SCHOLAR ENGINEERING',
#   'subject': 'ENGI'}]

# %%
locations = defaultdict(int)
ignored = {
    'ONLINE ONLY': [],
    'To be announced': [],
    'undefined': [],
    'OTHR OTHER': [],
}

for s in courses:
    loc = s.get('Location', 'undefined')
    if loc in ignored:
        ignored[loc].append(s)
    else:
        locations[s['Location']] += 1
                
ignoredCourses = sum(ignored.values(), []) # sums values into an initially empty list
print(f'Found {len(locations)} locations, but forced to ignore {len(ignoredCourses)}.')
# Out:
# Found 501 locations, but forced to ignore 3784.

# %%
sortedLocs = sorted(locations.items(), key=lambda kv: kv[1], reverse=True)
sortedLocs
# Out:
# [('5TH FLR Pupin Laboratories', 32),
#  ('320 Havemeyer Hall', 31),
#  ('405 International Affairs Building', 28),
#  ('404 International Affairs Building', 26),
#  ('302 Fayerweather', 25),
#  ('317 Hamilton Hall', 23),
#  ('903 School of Social Work', 23),
#  ('309 Havemeyer Hall', 23),
#  ('467 EXT Schermerhorn Hall [SCH]', 22),
#  ('207 Mathematics Building', 22),
#  ('409 International Affairs Building', 22),
#  ('311 Fayerweather', 22),
#  ('312 Mathematics Building', 21),
#  ('407 International Affairs Building', 21),
#  ('407 Mathematics Building', 20),
#  ('963 EXT Schermerhorn Hall [SCH]', 20),
#  ('716 Philosophy Hall', 20),
#  ('627 Seeley W. Mudd Building', 20),
#  ('633 Seeley W. Mudd Building', 20),
#  ('1102 International Affairs Building', 20),
#  ('402 Chandler', 20),
#  ('801 International Affairs Building', 20),
#  ('508 Dodge Hall', 20),
#  ('711 International Affairs Building', 20),
#  ('301M Fayerweather', 19),
#  ('420 Pupin Laboratories', 19),
#  ('402B International Affairs Building', 19),
#  ('507 Dodge Hall', 19),
#  ('501A International Affairs Building', 18),
#  ('503 Hamilton Hall', 18),
#  ('603 Hamilton Hall', 18),
#  ('517 Hamilton Hall', 18),
#  ('209 Fayerweather', 18),
#  ('417 International Affairs Building', 18),
#  ('501 Schermerhorn Hall [SCH]', 18),
#  ('413 International Affairs Building', 18),
#  ('403 International Affairs Building', 18),
#  ('401 Chandler', 17),
#  ('614 Schermerhorn Hall [SCH]', 17),
#  ('307 Pupin Laboratories', 17),
#  ('214 Pupin Laboratories', 17),
#  ('833 Seeley W. Mudd Building', 17),
#  ('417 Mathematics Building', 17),
#  ('607 Hamilton Hall', 17),
#  ('418 International Affairs Building', 17),
#  ('201 80 Claremont Ave', 17),
#  ('203 Mathematics Building', 17),
#  ('301 Pupin Laboratories', 17),
#  ('411 International Affairs Building', 17),
#  ('313 Fayerweather', 16),
#  ('209 Havemeyer Hall', 16),
#  ('601 Sherman Fairchild Life Sciences Building', 16),
#  ('501 Diana Center', 16),
#  ('428 Pupin Laboratories', 16),
#  ('602 Hamilton Hall', 16),
#  ('501 Northwest Corner Building', 16),
#  ('11 Barnard Hall', 16),
#  ('410 International Affairs Building', 16),
#  ('304 Hamilton Hall', 15),
#  ('401 Hamilton Hall', 15),
#  ('227 Seeley W. Mudd Building', 15),
#  ('516 Hamilton Hall', 15),
#  ('414 Pupin Laboratories', 15),
#  ('327 Seeley W. Mudd Building', 15),
#  ('413 Kent Hall', 15),
#  ('545 Seeley W. Mudd Building', 15),
#  ('702 Hamilton Hall', 15),
#  ('1101 International Affairs Building', 15),
#  ('408A Philosophy Hall', 15),
#  ('201B Philosophy Hall', 15),
#  ('402 International Affairs Building', 15),
#  ('504 Dodge Hall', 15),
#  ('717 Hamilton Hall', 14),
#  ('613 Hamilton Hall', 14),
#  ('652 Schermerhorn Hall [SCH]', 14),
#  ('303 Hamilton Hall', 14),
#  ('520 Mathematics Building', 14),
#  ('602 Lewisohn Hall', 14),
#  ('602 Northwest Corner Building', 14),
#  ('507 Philosophy Hall', 14),
#  ('305 Barnard Hall', 14),
#  ('201D Philosophy Hall', 14),
#  ('308 Diana Center', 14),
#  ('405 Dodge Hall', 14),
#  ('405 Schermerhorn Hall [SCH]', 14),
#  ('303 Uris Hall', 13),
#  ('212D Lewisohn Hall', 13),
#  ('404 Barnard Hall', 13),
#  ('304 Barnard Hall', 13),
#  ('227 Milbank Hall (Barnard)', 13),
#  ('703 Hamilton Hall', 13),
#  ('451 Computer Science Building', 13),
#  ('834 Seeley W. Mudd Building', 13),
#  ('113 Avery Hall', 13),
#  ('310 Fayerweather', 13),
#  ('318 Milbank Hall (Barnard)', 13),
#  ('329 Pupin Laboratories', 13),
#  ('601B Sherman Fairchild Life Sciences Building', 13),
#  ('C01 Knox Hall', 13),
#  ('326 Uris Hall', 13),
#  ('309 Hamilton Hall', 13),
#  ('402 Hamilton Hall', 13),
#  ('510A International Affairs Building', 13),
#  ('405A International Affairs Building', 13),
#  ('324 International Affairs Building', 13),
#  ('513F Dodge Hall', 13),
#  ('608 Schermerhorn Hall [SCH]', 13),
#  ('604 Schermerhorn Hall [SCH]', 13),
#  ('501B International Affairs Building', 13),
#  ('B60 ALFRED LERNE', 12),
#  ('206 Broadway Residence Hall', 12),
#  ('111 MILSTEIN CEN', 12),
#  ('524 Seeley W. Mudd Building', 12),
#  ('644 Seeley W. Mudd Building', 12),
#  ('930 Schermerhorn Hall [SCH]', 12),
#  ('LL016 MILSTEIN CEN', 12),
#  ('301 Hamilton Hall', 12),
#  ('1127 Seeley W. Mudd Building', 12),
#  ('502 Northwest Corner Building', 12),
#  ('201A Philosophy Hall', 12),
#  ('709 Hamilton Hall', 12),
#  ('111 Carman Hall', 12),
#  ('1027 International Affairs Building', 12),
#  ('307 Mathematics Building', 12),
#  ('511 Dodge Hall', 12),
#  ('310 W & J Warren Hall', 12),
#  ('404 Dodge Hall', 12),
#  ('STU2 Barnard Hall', 12),
#  ('404 School of Social Work', 12),
#  ('502 Diana Center', 11),
#  ('113 MILSTEIN CEN', 11),
#  ('403 Barnard Hall', 11),
#  ('214 Milbank Hall (Barnard)', 11),
#  ('C01 80 Claremont Ave', 11),
#  ('212A Lewisohn Hall', 11),
#  ('337 Seeley W. Mudd Building', 11),
#  ('832 Schermerhorn Hall [SCH]', 11),
#  ('405 Milbank Hall (Barnard)', 11),
#  ('306 Milbank Hall (Barnard)', 11),
#  ('622 Dodge Hall', 11),
#  ('424 Kent Hall', 11),
#  ('116 Knox Hall', 11),
#  ('141 Uris Hall', 11),
#  ('522C Kent Hall', 11),
#  ('306 Hamilton Hall', 11),
#  ('412 Pupin Laboratories', 11),
#  ('325 Pupin Laboratories', 11),
#  ('522B Kent Hall', 11),
#  ('328 Milbank Hall (Barnard)', 11),
#  ('LL017 MILSTEIN CEN', 11),
#  ('612 Philosophy Hall', 11),
#  ('1201 International Affairs Building', 11),
#  ('616 Hamilton Hall', 11),
#  ('110 Barnard Hall', 11),
#  ('406 Barnard Hall', 11),
#  ('407 Barnard Hall', 11),
#  ('407 Hamilton Hall', 11),
#  ('607 Schermerhorn Hall [SCH]', 11),
#  ('410 Milbank Hall (Barnard)', 11),
#  ('C06 School of Social Work', 11),
#  ('C03 School of Social Work', 11),
#  ('C05 School of Social Work', 11),
#  ('305 School of Social Work', 11),
#  ('405 School of Social Work', 11),
#  ('315 Prentis Hall at 632 W 125th St', 11),
#  ('210 Dodge Hall', 11),
#  ('207 W & J Warren Hall', 10),
#  ('209 W & J Warren Hall', 10),
#  ('222 Pupin Laboratories', 10),
#  ('825 Seeley W. Mudd Building', 10),
#  ('115 Avery Hall', 10),
#  ('620 Dodge Hall', 10),
#  ('415 Schapiro [SCEP]', 10),
#  ('308A Lewisohn Hall', 10),
#  ('LL103 Diana Center', 10),
#  ('233 Seeley W. Mudd Building', 10),
#  ('609 Hamilton Hall', 10),
#  ('313 Hamilton Hall', 10),
#  ('411 Kent Hall', 10),
#  ('411 Hamilton Hall', 10),
#  ('707 Hamilton Hall', 10),
#  ('413 Hamilton Hall', 10),
#  ('302 Hamilton Hall', 10),
#  ('318 Hamilton Hall', 10),
#  ('222 Milbank Hall (Barnard)', 10),
#  ('323 Milbank Hall (Barnard)', 10),
#  ('202 Milbank Hall (Barnard)', 10),
#  ('403 Dodge Hall', 10),
#  ('605 Dodge Hall', 10),
#  ('716 Hamilton Hall', 10),
#  ('207 Milbank Hall (Barnard)', 10),
#  ('204 Fayerweather', 10),
#  ('200C Schermerhorn Hall [SCH]', 10),
#  ('302 School of Social Work', 10),
#  ('311 School of Social Work', 10),
#  ('406 School of Social Work', 10),
#  ('304 School of Social Work', 10),
#  ('311 W & J Warren Hall', 9),
#  ('405 Barnard Hall', 9),
#  ('307 Milbank Hall (Barnard)', 9),
#  ('504 Diana Center', 9),
#  ('300 S Buell Hall', 9),
#  ('LL104 Diana Center', 9),
#  ('119 MILSTEIN CEN', 9),
#  ('103 Knox Hall', 9),
#  ('805 Altschul Hall (Barnard)', 9),
#  ('424 Pupin Laboratories', 9),
#  ('405 Kent Hall', 9),
#  ('316 Hamilton Hall', 9),
#  ('505 Casa Hispánica', 9),
#  ('109 Hartley Hall', 9),
#  ('315 Hamilton Hall', 9),
#  ('1015 EXT Schermerhorn Hall [SCH]', 9),
#  ('LL018 MILSTEIN CEN', 9),
#  ('325 Milbank Hall (Barnard)', 9),
#  ('225 Milbank Hall (Barnard)', 9),
#  ('101 Knox Hall', 9),
#  ('601C Journalism Building', 9),
#  ('502 Journalism Building', 9),
#  ('206 Casa Hispánica', 9),
#  ('301 School of Social Work', 9),
#  ('312 School of Social Work', 9),
#  ('109 Watson Hall', 9),
#  ('401 Dodge Hall', 9),
#  ('1024 Seeley W. Mudd Building', 8),
#  ('203 Diana Center', 8),
#  ('600 Avery Hall', 8),
#  ('202 Altschul Hall (Barnard)', 8),
#  ('1000 Sherman Fairchild Life Sciences Building', 8),
#  ('224 Pupin Laboratories', 8),
#  ('530 Altschul Hall (Barnard)', 8),
#  ('142 Uris Hall', 8),
#  ('208 W & J Warren Hall', 8),
#  ('423 Kent Hall', 8),
#  ('253 Engineering Terrace', 8),
#  ('106B Lewisohn Hall', 8),
#  ('1302 International Affairs Building', 8),
#  ('101 Prentis Hall at 632 W 125th St', 8),
#  ('302 Milbank Hall (Barnard)', 8),
#  ('425 Pupin Laboratories', 8),
#  ('501 International Affairs Building', 8),
#  ('511C Journalism Building', 8),
#  ('114 Knox Hall', 8),
#  ('814 Dodge Hall', 8),
#  ('202 Fayerweather', 8),
#  ('201 Casa Hispánica', 8),
#  ('229 Milbank Hall (Barnard)', 8),
#  ('324 Milbank Hall (Barnard)', 7),
#  ('511 Hamilton Hall', 7),
#  ('114 Avery Hall', 7),
#  ('408 Avery Hall', 7),
#  ('934 Schermerhorn Hall [SCH]', 7),
#  ('903 Altschul Hall (Barnard)', 7),
#  ('255 International Affairs Building', 7),
#  ('913 Altschul Hall (Barnard)', 7),
#  ('332 Uris Hall', 7),
#  ('313 Pupin Laboratories', 7),
#  ('254 International Affairs Building', 7),
#  ('237 Milbank Hall (Barnard)', 7),
#  ('409 Barnard Hall', 7),
#  ('403 Altschul Hall (Barnard)', 7),
#  ('558 EXT Schermerhorn Hall [SCH]', 7),
#  ('823 International Affairs Building', 7),
#  ('802 International Affairs Building', 7),
#  ('307 Uris Hall', 7),
#  ('253 International Affairs Building', 7),
#  ('202 Journalism Building', 7),
#  ('601A Journalism Building', 7),
#  ('507 Mathematics Building', 7),
#  ('200B Schermerhorn Hall [SCH]', 7),
#  ('101 80 Claremont Ave', 7),
#  ('802 School of Social Work', 7),
#  ('401 School of Social Work', 7),
#  ('5 NASH BUILDIN', 7),
#  ('6 NASH BUILDIN', 7),
#  ('754 EXT Schermerhorn Hall [SCH]', 7),
#  ('333 Uris Hall', 6),
#  ('758 EXT Schermerhorn Hall [SCH]', 6),
#  ('LL001 MILSTEIN CEN', 6),
#  ('412 Avery Hall', 6),
#  ('409 Avery Hall', 6),
#  ('912 Altschul Hall (Barnard)', 6),
#  ('302 Havemeyer Hall', 6),
#  ('202 Havemeyer Hall', 6),
#  ('202A Havemeyer Hall', 6),
#  ('207 Knox Hall', 6),
#  ('406 Hamilton Hall', 6),
#  ('328 Uris Hall', 6),
#  ('603 Schermerhorn Hall [SCH]', 6),
#  ('LL002 MILSTEIN CEN', 6),
#  ('420 Hamilton Hall', 6),
#  ('KOB LENFEST CENT', 6),
#  ('3 NASH BUILDIN', 6),
#  ('B15 Schapiro [SCEP]', 6),
#  ('329 Uris Hall', 6),
#  ('618 Hamilton Hall', 6),
#  ('303 Seeley W. Mudd Building', 6),
#  ('607B Journalism Building', 6),
#  ('607C Journalism Building', 6),
#  ('307 Journalism Building', 6),
#  ('294 Engineering Terrace', 6),
#  ('805 School of Social Work', 6),
#  ('LL200 Diana Center', 6),
#  ('106 Watson Hall', 6),
#  ('501 Dodge Hall', 6),
#  ('COTC Riverside Church', 5),
#  ('655 Schermerhorn Hall [SCH]', 5),
#  ('612 Schermerhorn Hall [SCH]', 5),
#  ('402 Diana Center', 5),
#  ('404 MILSTEIN CEN', 5),
#  ('606 Lewisohn Hall', 5),
#  ('610 Lewisohn Hall', 5),
#  ('408 Hamilton Hall', 5),
#  ('LL105 Diana Center', 5),
#  ('208 Knox Hall', 5),
#  ('555 Schermerhorn Hall [SCH]', 5),
#  ('327 Milbank Hall (Barnard)', 5),
#  ('302 Barnard Hall', 5),
#  ('330 Uris Hall', 5),
#  ('252 Engineering Terrace', 5),
#  ('301 Journalism Building', 5),
#  ('501A Journalism Building', 5),
#  ('511B Journalism Building', 5),
#  ('511A Journalism Building', 5),
#  ('701C Dodge Hall', 5),
#  ('LL103 Armand Hammer Health Sciences Center', 5),
#  ('LL203 Armand Hammer Health Sciences Center', 5),
#  ('509 Knox Hall', 5),
#  ('603 Dodge Hall', 5),
#  ('1 NASH BUILDIN', 5),
#  ('507 Hamilton Hall', 4),
#  ('404 Diana Center', 4),
#  ('300 N Buell Hall', 4),
#  ('203 Fayerweather', 4),
#  ('505 Avery Hall', 4),
#  ('807 Schermerhorn Hall [SCH]', 4),
#  ('813 Altschul Hall (Barnard)', 4),
#  ('522D Kent Hall', 4),
#  ('509 Hamilton Hall', 4),
#  ('416 W & J Warren Hall', 4),
#  ('417 Schermerhorn Hall [SCH]', 4),
#  ('1206 Seeley W. Mudd Building', 4),
#  ('702 School of Social Work', 4),
#  ('1219 International Affairs Building', 4),
#  ('104 Knox Hall', 4),
#  ('312 Armand Hammer Health Sciences Center', 4),
#  ('2 Russ Berrie Medical Science Pavillion', 4),
#  ('301 Armand Hammer Health Sciences Center', 4),
#  ('301 Georgian Residence at 617 W 168th St (School of Nursing)', 4),
#  ('717 Havemeyer Hall', 4),
#  ('1109 School of Social Work', 4),
#  ('303 Altschul Hall (Barnard)', 3),
#  ('951 Schermerhorn Hall [SCH]', 3),
#  ('214 Seeley W. Mudd Building', 3),
#  ('322 Armand Hammer Health Sciences Center', 3),
#  ('504 Avery Hall', 3),
#  ('806 Schermerhorn Hall [SCH]', 3),
#  ('1332 Pupin Laboratories', 3),
#  ('907 Altschul Hall (Barnard)', 3),
#  ('514 Altschul Hall (Barnard)', 3),
#  ('922 Schermerhorn Hall [SCH]', 3),
#  ('800 Sherman Fairchild Life Sciences Building', 3),
#  ('REN KRAFT CENTER', 3),
#  ('20-200 Presbyterian Hospital', 3),
#  ('301 Uris Hall', 3),
#  ('507 Lewisohn Hall', 3),
#  ('716 Altschul Hall (Barnard)', 3),
#  ('711 Havemeyer Hall', 3),
#  ('604 Butler Library', 3),
#  ('140 Uris Hall', 3),
#  ('1235 Seeley W. Mudd Building', 3),
#  ('505 Lewisohn Hall', 3),
#  ('609 Lewisohn Hall', 3),
#  ('506 Lewisohn Hall', 3),
#  ('508 Lewisohn Hall', 3),
#  ('LL106 Armand Hammer Health Sciences Center', 3),
#  ('AA 1 Black Building (Health Sciences)', 3),
#  ('327 Uris Hall', 3),
#  ('A-36 Union Theological Seminary', 3),
#  ('112 Knox Hall', 3),
#  ('601B Journalism Building', 3),
#  ('607A Journalism Building', 3),
#  ('706 Journalism Building', 3),
#  ('418 Knox Hall', 3),
#  ('320H Prentis Hall at 632 W 125th St', 3),
#  ('803 Dodge Hall', 3),
#  ('LL202 Armand Hammer Health Sciences Center', 3),
#  ('LL204 Armand Hammer Health Sciences Center', 3),
#  ('LL205 Armand Hammer Health Sciences Center', 3),
#  ('LL208A/B Armand Hammer Health Sciences Center', 3),
#  ('LL210 Armand Hammer Health Sciences Center', 3),
#  ('FITN Barnard Hall', 3),
#  ('6TH FLR Pupin Laboratories', 3),
#  ('516 MILSTEIN CEN', 3),
#  ('705 School of Social Work', 3),
#  ('1025 School of Social Work', 3),
#  ('2 NASH BUILDIN', 3),
#  ('1115 Altschul Hall (Barnard)', 2),
#  ('K306 JEWISH THEOL', 2),
#  ('K506 JEWISH THEOL', 2),
#  ('116B Lewisohn Hall', 2),
#  ('5AB KRAFT CENTER', 2),
#  ('382 Engineering Terrace', 2),
#  ('343 Seeley W. Mudd Building', 2),
#  ('202B Havemeyer Hall', 2),
#  ('522A Kent Hall', 2),
#  ('624 Kent Hall', 2),
#  ('511 Kent Hall', 2),
#  ('LL020 MILSTEIN CEN', 2),
#  ('506 Schermerhorn Hall [SCH]', 2),
#  ('101 Kent Hall', 2),
#  ('1205 Seeley W. Mudd Building', 2),
#  ('608 Lewisohn Hall', 2),
#  ('607 Lewisohn Hall', 2),
#  ('331 Uris Hall', 2),
#  ('352C International Affairs Building', 2),
#  ('262 MACY HALL', 2),
#  ('261 MACY HALL', 2),
#  ('352A International Affairs Building', 2),
#  ('622 Mathematics Building', 2),
#  ('701A Dodge Hall', 2),
#  ('LL107 Armand Hammer Health Sciences Center', 2),
#  ('LL209A/B Armand Hammer Health Sciences Center', 2),
#  ('303 Armand Hammer Health Sciences Center', 2),
#  ('814 Pupin Laboratories', 2),
#  ('101 JEROME L GRE', 2),
#  ('351A International Affairs Building', 2),
#  ('230 Milbank Hall (Barnard)', 2),
#  ('12T Riverside Church', 2),
#  ('B10 Schapiro [SCEP]', 2),
#  ('457 Schermerhorn Hall [SCH]', 1),
#  ('9T Riverside Church', 1),
#  ('330 Riverside Church', 1),
#  ('200 N Buell Hall', 1),
#  ('320M Fayerweather', 1),
#  ('301 Fayerweather', 1),
#  ('206 Fayerweather', 1),
#  ('1402 Pupin Laboratories', 1),
#  ('1202 Vagelos Educ', 1),
#  ('1316 Altschul Hall (Barnard)', 1),
#  ('1214 Altschul Hall (Barnard)', 1),
#  ('743 Seeley W. Mudd Building', 1),
#  ('1015 Altschul Hall (Barnard)', 1),
#  ('353 Engineering Terrace', 1),
#  ('20-101 Presbyterian Hospital', 1),
#  ('817 Irving Cancer Research Center', 1),
#  ('107 JEROME L GRE', 1),
#  ('718 Hamilton Hall', 1),
#  ('K406 JEWISH THEOL', 1),
#  ('222 Havemeyer Hall', 1),
#  ('537 Grace Dodge Hall (TC)', 1),
#  ('543 Grace Dodge Hall (TC)', 1),
#  ('B-100 Heyman Center for the Humanities (East Campus)', 1),
#  ('202 Hamilton Hall', 1),
#  ('306 Uris Hall', 1),
#  ('B100 Heyman Center for the Humanities (East Campus)', 1),
#  ('1012 Schermerhorn Hall [SCH]', 1),
#  ('750 Schapiro [SCEP]', 1),
#  ('1224 Seeley W. Mudd Building', 1),
#  ('607 School of Social Work', 1),
#  ('AUD Earl Hall', 1),
#  ('319 Hamilton Hall', 1),
#  ('105 MILSTEIN CEN', 1),
#  ('413 Dodge Hall', 1),
#  ('4 NASH BUILDIN', 1),
#  ('227 THOMPSON HAL', 1),
#  ('436 HORACE MANN', 1),
#  ('807 Jerome L. Greene Hall (Law)', 1),
#  ('420 Kent Hall', 1),
#  ('511A/B Journalism Building', 1),
#  ('709 Journalism Building', 1),
#  ('716A Hamilton Hall', 1),
#  ('415 W & J Warren Hall', 1),
#  ('311 Knox Hall', 1),
#  ('311 Riverside Church', 1),
#  ('414 Knox Hall', 1),
#  ('403 Knox Hall', 1),
#  ('112 Dodge Hall', 1),
#  ('317H Prentis Hall at 632 W 125th St', 1),
#  ('324 Prentis Hall at 632 W 125th St', 1),
#  ('305 Armand Hammer Health Sciences Center', 1),
#  ('114 Irving Cancer Research Center', 1),
#  ('202A Armand Hammer Health Sciences Center', 1),
#  ('A1 Physicians and Surgeons (Health Sciences)', 1),
#  ('LL109A/B Armand Hammer Health Sciences Center', 1),
#  ('LL201 Armand Hammer Health Sciences Center', 1),
#  ('321 Georgian Residence at 617 W 168th St (School of Nursing)', 1),
#  ('306 Armand Hammer Health Sciences Center', 1),
#  ('510B Altschul Hall (Barnard)', 1),
#  ('LL110 Armand Hammer Health Sciences Center', 1),
#  ('270B International Affairs Building', 1),
#  ('103C 80 Claremont Ave', 1),
#  ('147 Horace Mann (TC)', 1),
#  ('205A Union Theological Seminary', 1),
#  ('207 Union Theological Seminary', 1),
#  ('C02 School of Social Work', 1),
#  ('501D Knox Hall', 1),
#  ('707 Knox Hall', 1),
#  ('601C Sherman Fairchild Life Sciences Building', 1),
#  ('103 JEROME L GRE', 1),
#  ('B20 Schapiro [SCEP]', 1)]
